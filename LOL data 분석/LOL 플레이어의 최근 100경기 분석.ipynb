# %% [markdown]
# ### 경희대학교 산업경영공학과 2015100915 김태호

# %% [markdown]
# # LOL 플레이어의 실력 분석

# %% [markdown]
# BeautifulSoup와 urllib, selenium을 사용하여 플레이어의 데이터가 있는 op.gg에서 데이터를 가져와 LOL플레이어의 최근 100경기의 데이터 분석한다.

# %% [markdown]
# ### 사용방법
# 1. 상단의 'Togle Toolbar'에 '>>'모양의 버튼을 누르고 빨간버튼(Restart the kernel)을 눌러주세요.
# 2. 아래에 "소환사명을 입력해주세요.: "가 나오면 소환사명을 입력해 주세요.(ex. 황토매트)

# %%
username = input("소환사명을 입력해주세요.: ")
# Out:
# 소환사명을 입력해주세요.: 황토매트

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import pandas as pd
from tqdm import tqdm_notebook
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib import font_manager, rc
path = "c:/Windows/Fonts/malgun.ttf"
font_name = font_manager.FontProperties(fname=path).get_name()
rc('font', family=font_name)
import seaborn as sns
from selenium import webdriver
import urllib.request
import urllib.parse
import time

# %%
url1 = "http://www.op.gg/summoner/userName=" #한글을 제외한 주소를 url1에 저장
#parse모듈을 사용해 한글부분을 유니코드로 치환
url2 = urllib.parse.quote_plus(str(username)) 
url = url1 + url2
driver = webdriver.Chrome('chromedriver.exe')
driver.get(url)

# %%
xpath = """//*[@id="SummonerRefreshButton"]"""
driver.find_element_by_xpath(xpath).click()

time.sleep(10)

# %%
while True:
    try:
        xpath = """//*[@id="SummonerLayoutContent"]/div[2]/div[2]/div/div[2]/div[4]/a"""
        driver.find_element_by_xpath(xpath).click()
        break
    except:
        continue
while True:
    try:
        xpath = """//*[@id="SummonerLayoutContent"]/div[2]/div[2]/div/div[2]/div[5]/a"""
        driver.find_element_by_xpath(xpath).click()
        break
    except:
        continue
while True:
    try:
        xpath = """//*[@id="SummonerLayoutContent"]/div[2]/div[2]/div/div[2]/div[6]/a"""
        driver.find_element_by_xpath(xpath).click()
        break
    except:
        continue
while True:
    try:
        xpath = """//*[@id="SummonerLayoutContent"]/div[2]/div[2]/div/div[2]/div[7]/a"""
        driver.find_element_by_xpath(xpath).click()
        break
    except:
        continue
        
time.sleep(10)

# %%
page = driver.page_source
soup = BeautifulSoup(page, "html.parser")

print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <!--
# 	  ,ad8888ba,   88888888ba         ,ad8888ba,    ,ad8888ba,
# 	 d8"'    `"8b  88      "8b       d8"'    `"8b  d8"'    `"8b
# 	d8'        `8b 88      ,8P      d8'           d8'
# 	88          88 88aaaaaa8P'      88            88
# 	88          88 88""""""'        88      88888 88      88888
# 	Y8,        ,8P 88               Y8,        88 Y8,        88
# 	 Y8a.    .a8P  88                Y8a.    .a88  Y8a.    .a88
# 	  `"Y8888Y"'   88     dev@op.gg   `"Y88888P"    `"Y88888P"
#
# 		 Copyright © 2013-2019 OP.GG. All rights reserved.
# -->
# <html class=" js localstorage" lang="ko_KR" xmlns="http://www.w3.org/1999/xhtml">
#  <head>
#   <meta content="황토매트 - 게임 전적 - League of Legends" name="title"/>
#   <meta content="황토매트 - 게임 전적 - League of Legends" property="og:title"/>
#   <meta content="황토매트 / Bronze 2 15LP / 14승 12패 승률 54% / 아리 - 12승 8패 승률 60%, 징크스 - 4승 8패 승률 33%, 오른 - 3승 6패 승률 33%, 레오나 - 4승 1패 승률 80%, 트리스타나 - 2승 3패 승률 40%" name="description"/>
#   <meta content="황토매트 / Bronze 2 15LP / 14승 12패 승률 54% / 아리 - 12승 8패 승률 60%, 징크스 - 4승 8패 승률 33%, 오른 - 3승 6패 승률 33%, 레오나 - 4승 1패 승률 80%, 트리스타나 - 2승 3패 승률 40%" property="og:description"/>
#   <meta content="롤 전적 검색, LOL 승률, 리플 녹화, 챔피언 가이드, 통계, 프로게이머 관전, 실시간 랭킹, 롤챔스, LOLKing, LOLNexus" name="keywords"/>
#   <meta content="#4285f4" name="theme-color"/>
#   <title>
#    황토매트 - 게임 전적 - League of Legends
#   </title>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="app-id=gg.op.lol.android" name="google-play-app"/>
#   <meta content="677811765617932" property="fb:app_id"/>
#   <meta content="OP.GG Korea" property="og:site_name"/>
#   <meta content="website" property="og:type"/>
#   <meta content="//opgg-static.akamaized.net/images/logo/2015/reverse.rectangle.png" property="og:image"/>
#   <link href="http://www.op.gg/summoner/userName=%ED%99%A9%ED%86%A0%EB%A7%A4%ED%8A%B8" rel="canonical"/>
#   <link href="http://www.op.gg/" hreflang="x-default" rel="alternate"/>
#   <link href="http://www.op.gg/l=en_US" hreflang="en-us" rel="alternate"/>
#   <link href="http://www.op.gg/l=ko_KR" hreflang="ko-kr" rel="alternate"/>
#   <link href="http://www.op.gg/l=ja" hreflang="ja" rel="alternate"/>
#   <link href="http://www.op.gg/l=pl" hreflang="pl" rel="alternate"/>
#   <link href="http://www.op.gg/l=fr" hreflang="fr" rel="alternate"/>
#   <link href="http://www.op.gg/l=de" hreflang="de" rel="alternate"/>
#   <link href="http://www.op.gg/l=es" hreflang="es" rel="alternate"/>
#   <link href="http://www.op.gg/l=nl" hreflang="nl" rel="alternate"/>
#   <link href="http://www.op.gg/l=da" hreflang="da" rel="alternate"/>
#   <link href="http://www.op.gg/l=sv" hreflang="sv" rel="alternate"/>
#   <link href="http://www.op.gg/l=no" hreflang="no" rel="alternate"/>
#   <link href="http://www.op.gg/l=ru" hreflang="ru" rel="alternate"/>
#   <link href="http://www.op.gg/l=hu" hreflang="hu" rel="alternate"/>
#   <link href="http://www.op.gg/l=fi" hreflang="fi" rel="alternate"/>
#   <link href="http://www.op.gg/l=tr" hreflang="tr" rel="alternate"/>
#   <link href="http://www.op.gg/l=ro" hreflang="ro" rel="alternate"/>
#   <link href="http://www.op.gg/l=pt" hreflang="pt" rel="alternate"/>
#   <link href="http://www.op.gg/l=zh_CN" hreflang="zh-cn" rel="alternate"/>
#   <link href="http://www.op.gg/l=zh_TW" hreflang="zh-tw" rel="alternate"/>
#   <link href="http://www.op.gg/l=sr" hreflang="sr" rel="alternate"/>
#   <link href="http://www.op.gg/l=it" hreflang="it" rel="alternate"/>
#   <link href="http://www.op.gg/l=th_TH" hreflang="th-th" rel="alternate"/>
#   <link href="http://www.op.gg/l=vi_VN" hreflang="vi-vn" rel="alternate"/>
#   <link href="/favicon.ico?4" rel="icon" type="image/x-icon"/>
#   <link href="//opgg-static.akamaized.net/icon/Icon-72.png?v2" rel="apple-touch-icon-precomposed"/>
#   <link href="//opgg-static.akamaized.net/icon/Icon-72.png?v2" rel="apple-touch-icon-precomposed" sizes="72x72"/>
#   <link href="//opgg-static.akamaized.net/icon/Icon@2x.png?v2" rel="apple-touch-icon-precomposed" sizes="114x114"/>
#   <link href="//opgg-static.akamaized.net/icon/Icon-144.png?v2" rel="apple-touch-icon-precomposed" sizes="144x144"/>
#   <meta content="black" name="apple-mobile-web-app-status-bar-style"/>
#   <meta content="telephone=no" name="format-detection"/>
#   <meta content="off" name="autocomplete"/>
#   <script src="https://bam.nr-data.net/1/8159f4d5fa?a=78634178&amp;v=1118.0c07c19&amp;to=b1ZTYBdWWxVWUUZcV1YcckEWQ1oLGEFHWFVXXVRGSg%3D%3D&amp;rst=214731&amp;ref=http://www.op.gg/summoner/userName%3D%25ED%2599%25A9%25ED%2586%25A0%25EB%25A7%25A4%25ED%258A%25B8&amp;ap=1428&amp;be=1846&amp;fe=213946&amp;dc=75336&amp;af=err,xhr,stn,ins&amp;perf=%7B%22timing%22:%7B%22of%22:1549299950045,%22n%22:0,%22f%22:14,%22dn%22:83,%22dne%22:83,%22c%22:83,%22ce%22:128,%22rq%22:128,%22rp%22:1825,%22rpe%22:4675,%22dl%22:1830,%22di%22:75336,%22ds%22:75336,%22de%22:75503,%22dc%22:213946,%22l%22:213946,%22le%22:213954%7D,%22navigation%22:%7B%7D%7D&amp;at=QxFQFl9MSBs%3D&amp;jsonp=NREUM.setToken" type="text/javascript">
#   </script>
#   <script src="https://js-agent.newrelic.com/nr-1118.min.js">
#   </script>
#   <script src="http://www.googletagservices.com/activeview/js/current/osd.js?cb=%2Fr20100101">
#   </script>
#   <script src="https://cdn.ampproject.org/rtv/011901222107370/amp4ads-host-v0.js">
#   </script>
#   <script src="https://securepubads.g.doubleclick.net/gpt/pubads_impl_rendering_299.js">
#   </script>
#   <script async="" src="https://www.google-analytics.com/analytics.js" type="text/javascript">
#   </script>
#   <script async="" src="https://djtflbt20bdde.cloudfront.net/" type="text/javascript">
#   </script>
#   <script async="" src="http://www.statcounter.com/counter/counter.js" type="text/javascript">
#   </script>
#   <script async="" src="//www.google-analytics.com/analytics.js">
#   </script>
#   <script async="" src="https://connect.facebook.net/signals/config/1366379470122349?v=2.8.39&amp;r=stable">
#   </script>
#   <script async="" src="https://connect.facebook.net/en_US/fbevents.js">
#   </script>
#   <script src="https://hm.baidu.com/hm.js?29884b6641f1b5709cc89a8ce5a99366">
#   </script>
#   <script id="facebook-jssdk" src="//connect.facebook.net/en_US/sdk.js">
#   </script>
#   <script type="text/javascript">
#    (window.NREUM||(NREUM={})).loader_config={xpid:"VQcEVlFSDBAHXFdRAwAAXg=="};window.NREUM||(NREUM={}),__nr_require=function(t,n,e){function r(e){if(!n[e]){var o=n[e]={exports:{}};t[e][0].call(o.exports,function(n){var o=t[e][1][n];return r(o||n)},o,o.exports)}return n[e].exports}if("function"==typeof __nr_require)return __nr_require;for(var o=0;o&lt;e.length;o++)r(e[o]);return r}({1:[function(t,n,e){function r(t){try{s.console&amp;&amp;console.log(t)}catch(n){}}var o,i=t("ee"),a=t(16),s={};try{o=localStorage.getItem("__nr_flags").split(","),console&amp;&amp;"function"==typeof console.log&amp;&amp;(s.console=!0,o.indexOf("dev")!==-1&amp;&amp;(s.dev=!0),o.indexOf("nr_dev")!==-1&amp;&amp;(s.nrDev=!0))}catch(c){}s.nrDev&amp;&amp;i.on("internal-error",function(t){r(t.stack)}),s.dev&amp;&amp;i.on("fn-err",function(t,n,e){r(e.stack)}),s.dev&amp;&amp;(r("NR AGENT IN DEVELOPMENT MODE"),r("flags: "+a(s,function(t,n){return t}).join(", ")))},{}],2:[function(t,n,e){function r(t,n,e,r,s){try{p?p-=1:o(s||new UncaughtException(t,n,e),!0)}catch(f){try{i("ierr",[f,c.now(),!0])}catch(d){}}return"function"==typeof u&amp;&amp;u.apply(this,a(arguments))}function UncaughtException(t,n,e){this.message=t||"Uncaught error with no additional information",this.sourceURL=n,this.line=e}function o(t,n){var e=n?null:c.now();i("err",[t,e])}var i=t("handle"),a=t(17),s=t("ee"),c=t("loader"),f=t("gos"),u=window.onerror,d=!1,l="nr@seenError",p=0;c.features.err=!0,t(1),window.onerror=r;try{throw new Error}catch(h){"stack"in h&amp;&amp;(t(8),t(7),"addEventListener"in window&amp;&amp;t(5),c.xhrWrappable&amp;&amp;t(9),d=!0)}s.on("fn-start",function(t,n,e){d&amp;&amp;(p+=1)}),s.on("fn-err",function(t,n,e){d&amp;&amp;!e[l]&amp;&amp;(f(e,l,function(){return!0}),this.thrown=!0,o(e))}),s.on("fn-end",function(){d&amp;&amp;!this.thrown&amp;&amp;p&gt;0&amp;&amp;(p-=1)}),s.on("internal-error",function(t){i("ierr",[t,c.now(),!0])})},{}],3:[function(t,n,e){t("loader").features.ins=!0},{}],4:[function(t,n,e){function r(t){}if(window.performance&amp;&amp;window.performance.timing&amp;&amp;window.performance.getEntriesByType){var o=t("ee"),i=t("handle"),a=t(8),s=t(7),c="learResourceTimings",f="addEventListener",u="resourcetimingbufferfull",d="bstResource",l="resource",p="-start",h="-end",m="fn"+p,v="fn"+h,w="bstTimer",y="pushState",g=t("loader");g.features.stn=!0,t(6);var b=NREUM.o.EV;o.on(m,function(t,n){var e=t[0];e instanceof b&amp;&amp;(this.bstStart=g.now())}),o.on(v,function(t,n){var e=t[0];e instanceof b&amp;&amp;i("bst",[e,n,this.bstStart,g.now()])}),a.on(m,function(t,n,e){this.bstStart=g.now(),this.bstType=e}),a.on(v,function(t,n){i(w,[n,this.bstStart,g.now(),this.bstType])}),s.on(m,function(){this.bstStart=g.now()}),s.on(v,function(t,n){i(w,[n,this.bstStart,g.now(),"requestAnimationFrame"])}),o.on(y+p,function(t){this.time=g.now(),this.startPath=location.pathname+location.hash}),o.on(y+h,function(t){i("bstHist",[location.pathname+location.hash,this.startPath,this.time])}),f in window.performance&amp;&amp;(window.performance["c"+c]?window.performance[f](u,function(t){i(d,[window.performance.getEntriesByType(l)]),window.performance["c"+c]()},!1):window.performance[f]("webkit"+u,function(t){i(d,[window.performance.getEntriesByType(l)]),window.performance["webkitC"+c]()},!1)),document[f]("scroll",r,{passive:!0}),document[f]("keypress",r,!1),document[f]("click",r,!1)}},{}],5:[function(t,n,e){function r(t){for(var n=t;n&amp;&amp;!n.hasOwnProperty(u);)n=Object.getPrototypeOf(n);n&amp;&amp;o(n)}function o(t){s.inPlace(t,[u,d],"-",i)}function i(t,n){return t[1]}var a=t("ee").get("events"),s=t(19)(a,!0),c=t("gos"),f=XMLHttpRequest,u="addEventListener",d="removeEventListener";n.exports=a,"getPrototypeOf"in Object?(r(document),r(window),r(f.prototype)):f.prototype.hasOwnProperty(u)&amp;&amp;(o(window),o(f.prototype)),a.on(u+"-start",function(t,n){var e=t[1],r=c(e,"nr@wrapped",function(){function t(){if("function"==typeof e.handleEvent)return e.handleEvent.apply(e,arguments)}var n= ...
#   </script>
#   <link href="//opgg-static.akamaized.net/css3/common.css?t=1549204283" rel="stylesheet" type="text/css"/>
#   <link href="//opgg-static.akamaized.net/css3/sprite.css?t=1549204283" rel="stylesheet" type="text/css"/>
#   <link href="//opgg-static.akamaized.net/css3/forum.css?t=1549204283" rel="stylesheet" type="text/css"/>
#   <link href="//opgg-static.akamaized.net/css3/new.css?t=1549204283" rel="stylesheet" type="text/css"/>
#   <link href="//opgg-static.akamaized.net/css3/summoner.css?t=1549204283" rel="stylesheet" type="text/css"/>
#   <!--[if gt IE 9]><!-->
#   <link href="//opgg-cdn.akamaized.net/nanumgothic/font_nanumgothic.css" rel="stylesheet" type="text/css"/>
#   <!--<![endif]-->
#   <script src="//opgg-static.akamaized.net/js3/head.js?2">
#   </script>
#   <script src="//opgg-cdn.akamaized.net/moment-2.5.0/moment.js" type="text/javascript">
#   </script>
#   <script src="//opgg-cdn.akamaized.net/moment-2.5.0/lang/ko.js" type="text/javascript">
#   </script>
#   <script>
#    _i18n.stringList = {"SUMMONER_FAVORITE_LIMIT_EXCEED_IELOW":"Internet Explorer\ub294 {{limit}}\uba85\uae4c\uc9c0\ub9cc \uc800\uc7a5\uc774 \uac00\ub2a5\ud569\ub2c8\ub2e4. \ub354 \ub9ce\uc740 \uc218\ub97c \uc990\uaca8\ucc3e\uae30 \ud558\ub824\uba74 \uad6c\uae00\ud06c\ub86c\uc774\ub098 \ub354 \ub192\uc740 \ubc84\uc804\uc758 Internet Explorer \ub97c \uc774\uc6a9\ud558\uc138\uc694.","NOTICE_WONDERINGABOUTMMR":"\uc758\ubb38\uc810\uc774 \uc788\uc73c\uba74 &lt;a href=\"\/help\/mmr\/\"&gt;\ub3c4\uc6c0\ub9d0&lt;\/a&gt;\uc744 \uba3c\uc800 \ud655\uc778\ud574\uc8fc\uc138\uc694.","MMR_SUBTITLE":"\uc774 \uc11c\ube44\uc2a4\ub294 \uc18c\ud658\uc0ac\ub2d8\ub4e4\uacfc \ub9e4\uce6d\ub418\ub294 \ub2e4\ub978 \uc18c\ud658\uc0ac\ub2d8\ub4e4\uc758 \ud2f0\uc5b4 \uc815\ubcf4\ub97c \ube44\uad50\/\ubd84\uc11d \ud558\uc5ec \uc77c\uc815\ud55c \uc54c\uace0\ub9ac\uc998\uc73c\ub85c \ub77c\uc774\uc5c7 \ub0b4\ubd80\uc5d0\uc11c \uc9c0\uc815\ud55c MMR\uc744 \ucd94\uce21\ud558\ub294 \uc11c\ube44\uc2a4\uc785\ub2c8\ub2e4.","MMR \uc815\ud655\ub3c4":"MMR \uc815\ud655\ub3c4","\uc11c\ubc84\uc5d0 \ubd80\ud558\uac00 \uc2ec\ud574 \ub370\uc774\ud130\ub97c \uac00\uc838\uc62c \uc218 \uc5c6\uc2b5\ub2c8\ub2e4. \ub2e4\uc2dc \uc2dc\ub3c4\ud574\uc8fc\uc2dc\uae30 \ubc14\ub78d\ub2c8\ub2e4.":"\uc11c\ubc84\uc5d0 \ubd80\ud558\uac00 \uc2ec\ud574 \ub370\uc774\ud130\ub97c \uac00\uc838\uc62c \uc218 \uc5c6\uc2b5\ub2c8\ub2e4. \ub2e4\uc2dc \uc2dc\ub3c4\ud574\uc8fc\uc2dc\uae30 \ubc14\ub78d\ub2c8\ub2e4.","\uc5bc\ub9c8\ub098 \ubbff\uc744\ub9cc\ud55c\uc9c0\uc758 \uc218\uce58\uc785\ub2c8\ub2e4.":"\uc5bc\ub9c8\ub098 \ubbff\uc744\ub9cc\ud55c\uc9c0\uc758 \uc218\uce58\uc785\ub2c8\ub2e4.","SPECTATE_SETLOLDIRECTORY_PROMPT":"\ub9ac\uadf8\uc624\ube0c\ub808\uc804\ub4dc\uac00 \uc124\uce58\ub41c \uacbd\ub85c\ub97c \uc785\ub825\ud574\uc8fc\uc138\uc694. RADS \ud3f4\ub354\uac00 \uc788\ub294 \ub514\ub809\ud1a0\ub9ac\ub97c \uc785\ub825\ud558\uc2dc\uba74 \ub429\ub2c8\ub2e4. \uc608: D:\\Game\\Riot Games\\League of Legends KR","SPECTATE_SETLOLDIRECTORY_REMOVED":"\uacbd\ub85c \uc124\uc815\uc774 \uc9c0\uc6cc\uc84c\uc2b5\ub2c8\ub2e4.","SPECTATE_SETLOLDIRECTORY_SETTED":"\uacbd\ub85c\uac00 [{{directoryPath}}] \uc73c\ub85c \uc124\uc815\ub418\uc5c8\uc2b5\ub2c8\ub2e4.","FAVORITE_SUMMONERS_TITLE":"\uc990\uaca8\ucc3e\uae30","CHART_NOTICE_ABOVE_BRONZE":"\ubaa8\ub4e0 \ube0c\ub860\uc988 \uc774\uc0c1 \uc18c\ud658\uc0ac \uae30\uc900","CHART_NOTICE_ABOVE_IRON":"\ubaa8\ub4e0 \uc544\uc774\uc5b8 \uc774\uc0c1 \uc18c\ud658\uc0ac \uae30\uc900","CHART_TITLE_PICK_RATE_PER_GAME":"\uac8c\uc784\ub2f9 \ud53d\ub960","CHART_TITLE_BAN_RATE_PER_GAME":"\uac8c\uc784\ub2f9 \ubc34\ub960","CHART_TITLE_KDA_PER_GAME":"\uac8c\uc784\ub2f9 KDA","CHART_TITLE_CS_PER_GAME":"\uac8c\uc784\ub2f9 CS","CHART_TITLE_AVG_EA_PER_GAME":"\uac8c\uc784\ub2f9 \ud3c9\uade0 {{count}}\uac1c","CHART_TITLE_AVG_GOLD_PER_GAME":"\uac8c\uc784\ub2f9 \ud3c9\uade0 {{gold}}\uace8\ub4dc","CHART_TITLE_GOLD_OBTAIN_PER_GAME":"1 \uac8c\uc784\ub2f9 \ud68d\ub4dd \uace8\ub4dc","CHART_TITLE_WARDS_OBTAIN_PER_GAME":"1 \uac8c\uc784\ub2f9 \uad6c\ub9e4\ud55c \uc640\ub4dc","CHART_TITLE_LEAVE_PER_10K_GAMES":"1\ub9cc \uac8c\uc784\ub2f9 \ud0c8\uc8fc \ud68c\uc218","CHART_NOTICE_NO_DATA_THIS_OPTION":"\uc774 \uc124\uc815\uc740 \ub370\uc774\ud130\uac00 \uc5c6\uc2b5\ub2c8\ub2e4. \ub2e4\ub978 \uc124\uc815\uc744 \uc120\ud0dd\ud574\uc8fc\uc138\uc694.","CHART_TITLE_ACCUM_PLAY_COUNT":"\ud50c\ub808\uc774\uc218 \ub204\uacc4","CHART_NOTICE_ORDER_BY_WINRATE_MOUSE_HOVER_TO_SEE_CHAMP_PLAYCOUNT":"\uc2b9\ub960 \uc21c\uc11c\ub85c \uc815\ub82c \ub418\uc5c8\uc73c\uba70, \ub9c8\uc6b0\uc2a4\ub97c \uc62c\ub9ac\uba74 \uac01 \ucc54\ud504 \ud50c\ub808\uc774 \uc218\ub97c \ubcfc \uc218 \uc788\uc2b5\ub2c8\ub2e4.","CHART_TITLE_PLAY_COUNT":"\ud50c\ub808\uc774\uc218","CHART_TIERSHARE_LABEL":"\uc810\uc720\uc728","CHART_TIERSHARE_TOOLTIP":"\uc774 \ud2f0\uc5b4\uc5d0\uc11c\uc758 \ub7ad\ud06c \uc810\uc720\uc728","COMMON_AVERAGE":"\ud3c9\uade0","STATISTICS_FILTER_CHART_WINRATIO":"\uc2b9\ub960","TIER_RANK_DISTRIBUTION_CHART_TITLE":"\ud2f0\uc5 ...
# 		moment.diffLocal = Math.round(new Date().getTime() / 1000) - 1549299952 -1;
# 		_isMobile = false;
#   </script>
#   <!--[if lt IE 9]>
# 	<script src="//opgg-cdn.akamaized.net/jquery-1.11.2/jquery-1.11.2.min.js"></script>
# 	<script src="//opgg-cdn.akamaized.net/jquery-migrate-1.2.1/jquery-migrate-1.2.1.min.js"></script>    <![endif]-->
#   <!--[if gte IE 9]><!-->
#   <script src="//opgg-cdn.akamaized.net/jquery-2.1.3/jquery-2.1.3.min.js">
#   </script>
#   <!--<![endif]-->
#   <!--[if lte IE 9]>
# 	<script src="//opgg-cdn.akamaized.net/jquery.placeholder-2.1.2/jquery.placeholder.min.js"></script>
# 	<script>
# 		$(function(){
# 			$("input, textarea").placeholder();
# 		});
# 	</script>    <![endif]-->
#   <script src="//opgg-cdn.akamaized.net/modernizr-2.7.1/modernizr.js">
#   </script>
#   <script src="//opgg-static.akamaized.net/lib/browserdetect.js?1549204283">
#   </script>
#   <script src="//opgg-static.akamaized.net/lib/jquery.scrolltofixed-1.0.8-custom.js?1549204283">
#   </script>
#   <script src="//opgg-cdn.akamaized.net/jquery.cookie-1.3.1/jquery.cookie.js">
#   </script>
#   <script src="//opgg-cdn.akamaized.net/jquery.tablesorter-2.23.3/jquery.tablesorter.min.js">
#   </script>
#   <script src="//opgg-cdn.akamaized.net/jquery.tablesorter-2.23.3/jquery.tablesorter.widgets.js">
#   </script>
#   <script src="//opgg-cdn.akamaized.net/jquery.jcf-1.1.3/js/jcf.js">
#   </script>
#   <script src="//opgg-cdn.akamaized.net/jquery.jcf-1.1.3/js/jcf.select.js">
#   </script>
#   <script src="//opgg-cdn.akamaized.net/jquery.jcf-1.1.3/js/jcf.radio.js">
#   </script>
#   <script src="//opgg-cdn.akamaized.net/jquery.jcf-1.1.3/js/jcf.checkbox.js">
#   </script>
#   <script src="//opgg-cdn.akamaized.net/jquery.autocomplete-1.3.0/jquery.autocomplete-1.3.0.min.js">
#   </script>
#   <script src="//opgg-cdn.akamaized.net/tipped-4.6.1/js/tipped/tipped.js">
#   </script>
#   <script src="//opgg-static.akamaized.net/js3/common.js?1549204283">
#   </script>
#   <script src="//opgg-static.akamaized.net/js3/layout.js?1549204283">
#   </script>
#   <script src="//opgg-static.akamaized.net/js3/sidebar.js?1549204283">
#   </script>
#   <script src="//opgg-static.akamaized.net/js3/tracker.js?1549204283">
#   </script>
#   <script src="//opgg-static.akamaized.net/js3/mobile.js?1549204283">
#   </script>
#   <script src="//opgg-static.akamaized.net/js3/detectAds.js?1549204283">
#   </script>
#   <script src="//opgg-static.akamaized.net/js3/jquery.bxslider.min.js?1549204283">
#   </script>
#   <script src="//opgg-static.akamaized.net/js3/suggest.js?1549204283">
#   </script>
#   <script src="//opgg-cdn.akamaized.net/jquery.sparkline-2.1.2/jquery.sparkline.js">
#   </script>
#   <script src="//opgg-cdn.akamaized.net/highcharts-4.2.3/highcharts.js">
#   </script>
#   <script src="//opgg-cdn.akamaized.net/highcharts-4.2.3/highcharts-more.js">
#   </script>
#   <script src="//opgg-static.akamaized.net/lib/zepto.dragswap.js?1549204283">
#   </script>
#   <script src="//opgg-static.akamaized.net/lib/MutationObserver-0.3.2.js?1549204283">
#   </script>
#   <script src="//opgg-static.akamaized.net/js3/spectate.js?1549204283">
#   </script>
#   <script src="//opgg-static.akamaized.net/js3/summoner.js?1549204283">
#   </script>
#   <script>
#    $(function () {
#             $.OP.GG.common.GNBAutoComplete.init();
#
#             $('.gnb-btn-dropdown').click(function () {
#                 var dropdownButton = $(this),
#                     dropdownItem = dropdownButton.closest('.gnb-list-item-dropdown');
#
#                 dropdownItem.toggleClass('gnb-list-item-dropdown--acitve');
#
#                 $(document).on('click', function (event) {
#                     var target = event.target || event.srcElement;
#                     var $target = $(target);
#
#                     if (!$target.closest('.gnb-list-item-dropdown').length) {
#                         dropdownItem.removeClass('gnb-list-item-dropdown--acitve');
#                     }
#                 });
#             });
#
#             $('.gnb-btn-setting').on('click', function () {
#                 if (typeof fbq == 'function') {
#                     $.OP.GG.tracker.combine.sendEvent([
#                         'FB', 'Pixel'
#                     ], 'Index', 'ShowChangeRegion', {Referral: 'GNB'});
#                 }
#             });
#             $('.site a').on('click', function (evt) {
#                 var $site = $(evt.target).closest('.site');
#                 $.OP.GG.tracker.combine.sendEvent([
#                     'FB', 'Pixel'
#                 ], 'Index', 'ClickGlobalMenu', {MenuType: $site.data('site')});
#             });
#         })
#   </script>
#   <script>
#    $.OP.GG.summoner.properties = {
# 			TierRank: 'B2', // FB Analytics 에서 1글자짜리는 '알 수 없음'으로 나오는 것 같아서 바꿔본다.
# 			IsMy: false,
# 			IsPlus: false
# 		};
#
# 		$.plusTooltipMessage = 'OP.GG Plus에 대해 알아보세요!';
#
# 		$(function(){
#
# 						$.OP.GG.summoner.checkSpectateStatus('황토매트', $(".SpectateTabButton"));
# 								});
#   </script>
#   <script>
#    var _hmt = _hmt || [];
# 		(function(){
# 			var hm = document.createElement("script");
# 			hm.src = "https://hm.baidu.com/hm.js?29884b6641f1b5709cc89a8ce5a99366";
# 			var s = document.getElementsByTagName("script")[0];
# 			s.parentNode.insertBefore(hm, s);
# 		})();
#   </script>
#   <!-- Facebook Pixel Code -->
#   <script>
#    !function(f, b, e, v, n, t, s){
# 			if (f.fbq) return;
# 			n = f.fbq = function(){
# 				n.callMethod ?
# 					n.callMethod.apply(n, arguments) : n.queue.push(arguments)
# 			};
# 			if (!f._fbq) f._fbq = n;
# 			n.push = n;
# 			n.loaded = !0;
# 			n.version = '2.0';
# 			n.queue = [];
# 			t = b.createElement(e);
# 			t.async = !0;
# 			t.src = v;
# 			s = b.getElementsByTagName(e)[0];
# 			s.parentNode.insertBefore(t, s)
# 		}(window,
# 			document, 'script', 'https://connect.facebook.net/en_US/fbevents.js');
# 		fbq('init', '1366379470122349');
# 		fbq('track', 'PageView', null);
#   </script>
#   <script>
#    if (Facebook) {
# 			Facebook.init(function(FB){
# 								FB.AppEvents.logPageView();
# 			});
# 		}
#   </script>
#   <noscript>
#    &lt;img height="1" width="1" style="display:none"
# 	               src="https://www.facebook.com/tr?id=1366379470122349&amp;ev=PageView&amp;noscript=1"
# 		/&gt;
#   </noscript>
#   <!-- DO NOT MODIFY -->
#   <!-- End Facebook Pixel Code -->
#   <style>
#   </style>
#   <style type="text/css">
#    .jqstooltip { position: absolute;left: 0px;top: 0px;visibility: hidden;background: rgb(0, 0, 0) transparent;background-color: rgba(0,0,0,0.6);filter:progid:DXImageTransform.Microsoft.gradient(startColorstr=#99000000, endColorstr=#99000000);-ms-filter: "progid:DXImageTransform.Microsoft.gradient(startColorstr=#99000000, endColorstr=#99000000)";color: white;font: 10px arial, san serif;text-align: left;white-space: nowrap;padding: 5px;border: 1px solid white;z-index: 10000;}.jqsfield { color: white;font: 10px arial, san serif;text-align: left;}
#   </style>
#   <script async="" src="https://www.googletagservices.com/tag/js/gpt.js" type="text/javascript">
#   </script>
#   <link as="script" href="https://adservice.google.co.kr/adsid/integrator.js?domain=www.op.gg" rel="preload"/>
#   <script src="https://adservice.google.co.kr/adsid/integrator.js?domain=www.op.gg" type="text/javascript">
#   </script>
#   <link as="script" href="https://adservice.google.com/adsid/integrator.js?domain=www.op.gg" rel="preload"/>
#   <script src="https://adservice.google.com/adsid/integrator.js?domain=www.op.gg" type="text/javascript">
#   </script>
#   <script async="" src="https://securepubads.g.doubleclick.net/gpt/pubads_impl_299.js">
#   </script>
#   <link href="http://tpc.googlesyndication.com/safeframe/1-0-31/html/container.html" rel="prefetch"/>
#   <style type="text/css">
#    .fb_hidden{position:absolute;top:-10000px;z-index:10001}.fb_reposition{overflow:hidden;position:relative}.fb_invisible{display:none}.fb_reset{background:none;border:0;border-spacing:0;color:#000;cursor:auto;direction:ltr;font-family:"lucida grande", tahoma, verdana, arial, sans-serif;font-size:11px;font-style:normal;font-variant:normal;font-weight:normal;letter-spacing:normal;line-height:1;margin:0;overflow:visible;padding:0;text-align:left;text-decoration:none;text-indent:0;text-shadow:none;text-transform:none;visibility:visible;white-space:normal;word-spacing:normal}.fb_reset&gt;div{overflow:hidden}@keyframes fb_transform{from{opacity:0;transform:scale(.95)}to{opacity:1;transform:scale(1)}}.fb_animate{animation:fb_transform .3s forwards}
# .fb_dialog{background:rgba(82, 82, 82, .7);position:absolute;top:-10000px;z-index:10001}.fb_dialog_advanced{border-radius:8px;padding:10px}.fb_dialog_content{background:#fff;color:#373737}.fb_dialog_close_icon{background:url(https://static.xx.fbcdn.net/rsrc.php/v3/yq/r/IE9JII6Z1Ys.png) no-repeat scroll 0 0 transparent;cursor:pointer;display:block;height:15px;position:absolute;right:18px;top:17px;width:15px}.fb_dialog_mobile .fb_dialog_close_icon{left:5px;right:auto;top:5px}.fb_dialog_padding{background-color:transparent;position:absolute;width:1px;z-index:-1}.fb_dialog_close_icon:hover{background:url(https://static.xx.fbcdn.net/rsrc.php/v3/yq/r/IE9JII6Z1Ys.png) no-repeat scroll 0 -15px transparent}.fb_dialog_close_icon:active{background:url(https://static.xx.fbcdn.net/rsrc.php/v3/yq/r/IE9JII6Z1Ys.png) no-repeat scroll 0 -30px transparent}.fb_dialog_iframe{line-height:0}.fb_dialog_content .dialog_title{background:#6d84b4;border:1px solid #365899;color:#fff;font-size:14px;font-weight:bold;margin:0}.fb_dialog_content .dialog_title&gt;span{background:url(https://static.xx.fbcdn.net/rsrc.php/v3/yd/r/Cou7n-nqK52.gif) no-repeat 5px 50%;float:left;padding:5px 0 7px 26px}body.fb_hidden{height:100%;left:0;margin:0;overflow:visible;position:absolute;top:-10000px;transform:none;width:100%}.fb_dialog.fb_dialog_mobile.loading{background:url(https://static.xx.fbcdn.net/rsrc.php/v3/ya/r/3rhSv5V8j3o.gif) white no-repeat 50% 50%;min-height:100%;min-width:100%;overflow:hidden;position:absolute;top:0;z-index:10001}.fb_dialog.fb_dialog_mobile.loading.centered{background:none;height:auto;min-height:initial;min-width:initial;width:auto}.fb_dialog.fb_dialog_mobile.loading.centered #fb_dialog_loader_spinner{width:100%}.fb_dialog.fb_dialog_mobile.loading.centered .fb_dialog_content{background:none}.loading.centered #fb_dialog_loader_close{clear:both;color:#fff;display:block;font-size:18px;padding-top:20px}#fb-root #fb_dialog_ipad_overlay{background:rgba(0, 0, 0, .4);bottom:0;left:0;min-height:100%;position:absolute;right:0;top:0;width:100%;z-index:10000}#fb-root #fb_dialog_ipad_overlay.hidden{display:none}.fb_dialog.fb_dialog_mobile.loading iframe{visibility:hidden}.fb_dialog_mobile .fb_dialog_iframe{position:sticky;top:0}.fb_dialog_content .dialog_header{background:linear-gradient(from(#738aba), to(#2c4987));border-bottom:1px solid;border-color:#1d3c78;box-shadow:white 0 1px 1px -1px inset;color:#fff;font:bold 14px Helvetica, sans-serif;text-overflow:ellipsis;text-shadow:rgba(0, 30, 84, .296875) 0 -1px 0;vertical-align:middle;white-space:nowrap}.fb_dialog_content .dialog_header table{height:43px;width:100%}.fb_dialog_content .dialog_header td.header_left{font-size:12px;padding-left:5px;vertical-align:middle;width:60px}.fb_dialog_content .dialog_header td.header_right{font-size:12px;padding-right:5px;vertical-align:middle;width:60px}.fb_dialog_content .touchable_button{background:linear-gradient(from(#4267B2), to(#2a4887));background-clip:padding-box;border:1px solid #29487d;border-radius:3px;display:inline-block;line-height:18px;margin-top:3px;max-width:85px;padding:4px 12px;position:relative}.fb_dialog_content .dialog_header .touchable_button input{background:none;border:none;color:#fff;font:bold 12px Helvetica, sans-serif;margin:2px -12px;padding:2px 6px 3px 6px;text-shadow:rgba(0, 30, 84, .296875) 0 -1px 0}.fb_dialog_content .dialog_header .header_center{color:#fff;font-size:16px;font-weight:bold;line-height:18px;text-align:center;vertical-align:middle}.fb_dialog_content .dialog_content{background:url(https://static.xx.fbcdn.net/rsrc.php/v3/y9/r/jKEcVPZFk-2.gif) no-repeat 50% 50%;border:1px solid #4a4a4a;border-bottom:0;border-top:0;height:150px}.fb_dialog_content .dialog_footer{background:#f5f6f7;border:1px solid #4a4a4a;border-top-color:#ccc;height:40px}#fb_dialog_loader_close{float:left}.fb_dialog.fb_dialog_mobile .fb_dialog_close_button{text-shadow:rgba(0, 30, 84, .296875) 0 -1px 0}.fb_dialog.fb_dialog_mobile .fb_dialog_close_icon{visibility:hi ...
# .fb_iframe_widget{display:inline-block;position:relative}.fb_iframe_widget span{display:inline-block;position:relative;text-align:justify}.fb_iframe_widget iframe{position:absolute}.fb_iframe_widget_fluid_desktop,.fb_iframe_widget_fluid_desktop span,.fb_iframe_widget_fluid_desktop iframe{max-width:100%}.fb_iframe_widget_fluid_desktop iframe{min-width:220px;position:relative}.fb_iframe_widget_lift{z-index:1}.fb_iframe_widget_fluid{display:inline}.fb_iframe_widget_fluid span{width:100%}
#   </style>
#  </head>
#  <!--[if IE 7]>
# <body class="ie7 "><![endif]-->
#  <!--[if IE 8]>
# <body class="ie8 "><![endif]-->
#  <!--[if IE 9]>
# <body class="ie9 "><![endif]-->
#  <!--[if gt IE 9]><!-->
#  <body class="">
#   <!--<![endif]-->
#   <div class="l-wrap l-wrap--summoner">
#    <div class="l-header">
#     <div class="header">
#      <ul class="sites">
#       <li class="site site--current site--border" data-site="lol">
#        <a href="/">
#         <img alt="" class="site__logo" src="//opgg-static.akamaized.net/images/logo/logo-lol.png"/>
#         <span class="site__name">
#          <img src="//opgg-static.akamaized.net/images/logo/l_logo.png"/>
#         </span>
#        </a>
#       </li>
#       <li class="site" data-site="pubg">
#        <a href="https://pubg.op.gg" target="_blank">
#         <img alt="" class="site__logo" src="//opgg-static.akamaized.net/images/logo/logo-pubg-small.png"/>
#         <span class="site__name">
#          배틀그라운드
#         </span>
#        </a>
#       </li>
#       <li class="site" data-site="overwatch">
#        <a href="https://overwatch.op.gg" target="_blank">
#         <img alt="" class="site__logo" src="//opgg-static.akamaized.net/images/logo/logo-overwatch-small.png"/>
#         <span class="site__name">
#          오버워치
#         </span>
#        </a>
#       </li>
#       <li class="site" data-site="cr">
#        <a href="http://cr.op.gg" target="_blank">
#         <img alt="" class="site__logo" src="//opgg-static.akamaized.net/images/logo/logo-cr-small.png"/>
#         <span class="site__name">
#          클래시 로얄
#         </span>
#         <span>
#          <img src="//opgg-static.akamaized.net/images/baby_dragon_7_9dir8tiles_run2.gif" style="vertical-align: top; margin-left: 10px; margin-top: -10px;"/>
#         </span>
#        </a>
#       </li>
#       <li class="site" data-site="fortnite">
#        <a href="https://fortnite.op.gg" target="_blank">
#         <img alt="logo-fortnite-small" class="site__logo" src="//opgg-static.akamaized.net/images/logo/logo-fortnite-small.png"/>
#         <span class="site__name">
#          포트나이트
#         </span>
#         <img src="//opgg-static.akamaized.net/images/icon-beta.png" style="margin-left: 8px; vertical-align: middle;"/>
#        </a>
#       </li>
#      </ul>
#      <ul class="gnb-list">
#       <li class="gnb-list-item gnb-list-item__search">
#        <form action="/summoner/" method="get">
#         <input autocomplete="off" class="_suggest" name="userName" placeholder="소환사명, 소환사명, ..." type="text"/>
#         <button>
#          <img height="14" src="//opgg-static.akamaized.net/images/site/btn-gnb-search@2x.png"/>
#         </button>
#        </form>
#        <div class="summoner-search-history" style="display: none;">
#         <div class="tabWrap _recognized">
#          <ul class="summoner-search-history__title tabHeaders">
#           <li class="tabHeader active" data-tab-show-class="summoner-search-history--recent">
#            <a href="javascript:;">
#             최근검색
#            </a>
#           </li>
#           <li class="tabHeader" data-tab-show-class="summoner-search-history--favorite">
#            <a href="javascript:;">
#             즐겨찾기
#            </a>
#           </li>
#          </ul>
#          <div class="tabItems">
#           <div class="tabItem summoner-search-history--recent" style="display: block;">
#            <div class="RecentSummonerListWrap">
#             <div class="summoner-search-history__list RecentSummonerList" style="display: block;">
#              <div class="Item ">
#               <a class="Link" href="/summoner/userName=%ED%99%A9%ED%86%A0%EB%A7%A4%ED%8A%B8">
#                황토매트
#               </a>
#               <div class="Actions">
#                <a class="Action Add" href="#" onclick="$.OP.GG.common.SummonerHistory.Favorite.toggle('황토매트'); return false;">
#                </a>
#                <a class="Action Delete" href="#" onclick="$.OP.GG.common.SummonerHistory.History.remove('황토매트'); return false;">
#                </a>
#               </div>
#              </div>
#             </div>
#             <div class="summoner-search-history__message NotFound" style="display: none;">
#              <span>
#               <img class="Image" height="16" src="//opgg-static.akamaized.net/images/site/icon-history-info@2x.png"/>
#               최근에 본 소환사가 없습니다.
#              </span>
#             </div>
#            </div>
#           </div>
#           <div class="tabItem summoner-search-history--favorite" style="display: none;">
#            <div class="FavoriteSummonerListWrap">
#             <div class="summoner-search-history__list FavoriteSummonerList" style="display: none;">
#             </div>
#             <div class="summoner-search-history__message NotFound">
#              <span>
#               <img class="Image" height="16" src="//opgg-static.akamaized.net/images/site/icon-history-info@2x.png"/>
#               관심있는 소환사에
#               <i class="__spSite __spSite-100">
#               </i>
#               즐겨찾기를 하여 편리하게 정보를 받아보세요.
#              </span>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="autocomplete-suggestions" style="position: absolute; display: none; width: 260px; max-height: 1000px; z-index: 9999;">
#        </div>
#       </li>
#       <li class="gnb-list-item gnb-list-item__setting">
#        <button class="gnb-btn gnb-btn-setting" onclick="$.OP.GG.layout.regionLanguage.open();">
#         <span class="gnb-btn-setting__server">
#          KR
#         </span>
#         <span class="gnb-btn-setting__lang">
#          Korean
#         </span>
#         <span class="gnb-btn-setting__icon">
#          <i class="__spSite __spSite-78">
#          </i>
#         </span>
#        </button>
#       </li>
#       <li class="gnb-list-item gnb-list-item__login">
#        <a class="gnb-btn-login" href="https://member.op.gg?redirect_url=http%3A%2F%2Fwww.op.gg%2Fsummoner%2FuserName%3D%25ED%2599%25A9%25ED%2586%25A0%25EB%25A7%25A4%25ED%258A%25B8">
#         로그인
#        </a>
#       </li>
#      </ul>
#     </div>
#    </div>
#    <div class="l-menu">
#     <ul class="menu">
#      <li class="menu__item ">
#       <a class="target=" href="/">
#        홈
#       </a>
#      </li>
#      <li class="menu__item ">
#       <a class="target=" href="/champion/statistics">
#        챔피언 분석
#       </a>
#      </li>
#      <li class="menu__item ">
#       <a class="target=" href="/statistics/">
#        통계
#       </a>
#      </li>
#      <li class="menu__item ">
#       <a class="target=" href="/ranking/">
#        랭킹
#       </a>
#      </li>
#      <li class="menu__item ">
#       <a class="target=" href="/spectate/">
#        프로관전
#       </a>
#      </li>
#      <li class="menu__item ">
#       <a class="target=_blank" href="http://talk.op.gg/s/lol">
#        커뮤니티
#       </a>
#      </li>
#      <li class="menu__item ">
#       <a class="urf" href="/urf" target="">
#        우르프
#        <b style="background: #d17202; color: #FFF; padding: 2px 3px 2px 3px; font-size: 9px; font-family: Tahoma;">
#         Event
#        </b>
#       </a>
#      </li>
#     </ul>
#    </div>
#    <div class="alert">
#     <div class="alert__item ">
#      <a href="http://www.op.gg/urf" onclick="$.OP.GG.tracker.combine.sendEvent(['FB'], 'Index', 'clickURF');" style="" target="">
#       U.R.F 최고 티어 챔피언은? U.R.F 특집 챔피언 분석 페이지에서 만나보세요!​
#      </a>
#     </div>
#    </div>
#    <div class="l-container">
#     <div class="SummonerLayoutWrap">
#      <div class="SummonerLayout tabWrap _recognized">
#       <div class="Header">
#        <script>
#         $(function(){
# 		$.OP.GG.common.SummonerHistory.History.add('황토매트');
#
# 		$.OP.GG.common.SummonerHistory.Favorite.currentSummonerName = '황토매트';
# 		$.OP.GG.common.SummonerHistory.Favorite.loadCurrentSummoner();
#
#
# //			$("input[type=text]")
# //					.on('blur', function(){
# //						$.OP.GG.summoner.renewBtn.preventReload = false;
# //					})
# //					.on('focus', function(){
# //						$.OP.GG.summoner.renewBtn.preventReload = true;
# //					});
# 	});
#        </script>
#        <div class="PastRank">
#         <ul class="PastRankList">
#          <li class="Item tip" title="Silver 5 59LP">
#           <b>
#            S5
#           </b>
#           Silver
#          </li>
#          <li class="Item tip" title="Silver 5 15LP">
#           <b>
#            S6
#           </b>
#           Silver
#          </li>
#          <li class="Item tip" title="Bronze 4 0LP">
#           <b>
#            S7
#           </b>
#           Bronze
#          </li>
#          <li class="Item tip" title="Bronze 1 31LP">
#           <b>
#            S8
#           </b>
#           Bronze
#          </li>
#         </ul>
#        </div>
#        <div class="Face">
#         <div class="ProfileIcon">
#          <div class="borderImage" style="background-image: url(//opgg-static.akamaized.net/images/borders2/bronze.png);">
#          </div>
#          <img class="ProfileImage" src="//opgg-static.akamaized.net/images/profile_icons/profileIcon3879.jpg"/>
#          <span class="Level tip" title="레벨">
#           70
#          </span>
#         </div>
#        </div>
#        <div class="Profile">
#         <div class="Information">
#          <span class="Name">
#           황토매트
#          </span>
#          <a class="FavoriteButton" href="#" id="FavoriteButton" onclick="$.OP.GG.common.SummonerHistory.Favorite.toggle('황토매트'); return false;">
#           <span class="deactive __spSite __spSite-101" style="">
#           </span>
#           <span class="active __spSite __spSite-102" style="display: none;">
#           </span>
#           즐겨찾기
#          </a>
#          <div class="Rank">
#           <div class="LadderRank">
#            <a class="tip Link" href="/ranking/ladder/summonerName=%ED%99%A9%ED%86%A0%EB%A7%A4%ED%8A%B8" target="_blank" title="래더 랭킹 목록에서 보기">
#             래더 랭킹
#             <span class="ranking">
#              713,407
#             </span>
#             위 (상위 87%)
#            </a>
#           </div>
#          </div>
#         </div>
#         <div class="Buttons">
#          <button class="Button SemiRound Green" id="SummonerRefreshButton" onclick="$.OP.GG.summoner.renewBtn.start(this, '1221663');">
#           갱신됨
#          </button>
#          <button class="Button SemiRound White" onclick="$.OP.GG.summoner.openLpHistoryGraph('황토매트', '#ExtraView');">
#           티어 그래프
#          </button>
#         </div>
#        </div>
#        <div class="LastUpdate">
#         최근 업데이트:
#         <span class="_timeago _timeCountAssigned tip" data-datetime="1549300167" data-interval="60" data-type="" title="2019년 2월 5일 오전 2시 09분">
#          몇초 후
#         </span>
#        </div>
#        <!-- 175.223.48.29 -->
#       </div>
#       <div id="ExtraView">
#       </div>
#       <div class="Menu">
#        <dl class="MenuList tabHeaders">
#         <dd class="Item tabHeader active" data-tab-show-class="summonerLayout-summary">
#          <a href="/summoner/userName=%ED%99%A9%ED%86%A0%EB%A7%A4%ED%8A%B8">
#           종합
#          </a>
#         </dd>
#         <dd class="Item tabHeader" data-tab-show-class="summonerLayout-champions">
#          <a href="/summoner/champions/userName=%ED%99%A9%ED%86%A0%EB%A7%A4%ED%8A%B8">
#           챔피언
#          </a>
#         </dd>
#         <dd class="Item tabHeader inGame" data-tab-always-force-load="true" data-tab-show-class="summonerLayout-spectator">
#          <a class="SpectateTabButton" href="#">
#           <i class="icon">
#           </i>
#           <span class="text">
#            인게임 정보
#           </span>
#          </a>
#         </dd>
#        </dl>
#       </div>
#       <div class="life-owner LifeOwnerSummonerTopCenter">
#        <!-- OP.GG 2 - 970x250 Fixed (5ba366a846e0fb0001bca397) - 970x250 - Place in <BODY> of page where ad should appear -->
#        <div class="vm-placement" data-google-query-id="CK-r9fnIouACFUgPKgodiQwKQw" data-id="5ba366a846e0fb0001bca397" data-pos="0" id="5ba366a846e0fb0001bca397-0" style='width: 970px; height: 250px; background: url("https://hb.vntsm.com/assets/op_loader.gif") center center no-repeat rgb(242, 242, 242); border: 1px solid rgb(213, 216, 216); position: relative; margin: 0px auto; overflow: hidden; max-width: 970px;'>
#         <div id="google_ads_iframe_/21726375739/VM_5a8460b346e0fb0001fc3bac_0__container__" style="border: 0pt none; display: block; margin: 0px auto;">
#          <iframe data-google-container-id="d" data-load-complete="true" frameborder="0" height="250" id="google_ads_iframe_/21726375739/VM_5a8460b346e0fb0001fc3bac_0" marginheight="0" marginwidth="0" name="google_ads_iframe_/21726375739/VM_5a8460b346e0fb0001fc3bac_0" scrolling="no" srcdoc="" style="border: 0px; vertical-align: bottom;" title="3rd party ad content" width="970">
#          </iframe>
#         </div>
#        </div>
#        <!-- / OP.GG 2 - 970x250 Fixed (5ba366a846e0fb0001bca397) -->
#       </div>
#       <div class="ContentWrap tabItems" id="SummonerLayoutContent">
#        <div class="opgg__notice-summoner-top">
#        </div>
#        <div class="tabItem Content SummonerLayoutContent summonerLayout-summary" data-tab-data-url="/summoner/userName=%ED%99%A9%ED%86%A0%EB%A7%A4%ED%8A%B8" data-tab-is-loaded-already="true" data-tab-spinner-height="800" style="display: block;">
#         <div class="SideContent">
#          <div class="TierBox Box">
#           <div class="SummonerRatingMedium">
#            <div class="Medal tip" title="솔랭">
#             <img class="Image" src="//opgg-static.akamaized.net/images/medals/bronze_2.png"/>
#            </div>
#            <div class="TierRankInfo">
#             <div class="RankType">
#              솔로랭크
#             </div>
#             <div class="Position">
#              <b>
#               미드
#              </b>
#              총 26게임
#             </div>
#             <div class="TierRank">
#              Bronze 2
#             </div>
#             <div class="TierInfo">
#              <span class="LeaguePoints">
#               15 LP
#              </span>
#              /
#              <span class="WinLose">
#               <span class="wins">
#                14승
#               </span>
#               <span class="losses">
#                12패
#               </span>
#               <br/>
#               <span class="winratio">
#                승률 54%
#               </span>
#              </span>
#             </div>
#             <div class="LeagueName">
#             </div>
#            </div>
#           </div>
#           <div class="SummonerRatingLine">
#            <img class="Medal" src="//opgg-static.akamaized.net/images/medals/bronze_3.png"/>
#            <div class="TierRank">
#             <div class="Position">
#              탑
#             </div>
#             <div class="TierLeaguePoint">
#              <div class="Tier">
#               Bronze 3
#              </div>
#              <div class="LeaguePoints">
#               66
#                 LP
#              </div>
#             </div>
#            </div>
#            <div class="WinLose">
#             <span class="wins">
#              3승
#             </span>
#             <span class="losses">
#              6패
#             </span>
#             <br/>
#             <span class="winratio">
#              33%
#             </span>
#            </div>
#           </div>
#           <div class="SummonerRatingLine">
#            <img class="Medal" src="//opgg-static.akamaized.net/images/medals/bronze_4.png"/>
#            <div class="TierRank">
#             <div class="Position">
#              원딜
#             </div>
#             <div class="TierLeaguePoint">
#              <div class="Tier">
#               Bronze 4
#              </div>
#              <div class="LeaguePoints">
#               78
#                 LP
#              </div>
#             </div>
#            </div>
#            <div class="WinLose">
#             <span class="wins">
#              7승
#             </span>
#             <span class="losses">
#              13패
#             </span>
#             <br/>
#             <span class="winratio">
#              35%
#             </span>
#            </div>
#           </div>
#          </div>
#          <div class="sub-tier">
#           <img class="Image sub-tier__medal" src="//opgg-static.akamaized.net/images/medals/default.png"/>
#           <div class="sub-tier__info unranked">
#            <div class="sub-tier__rank-type">
#             자유 5:5 랭크
#            </div>
#            <div class="sub-tier__rank-tier unranked">
#             Unranked
#            </div>
#           </div>
#          </div>
#          <div class="Box tabWrap stats-box _recognized">
#           <div class="Tab">
#            <ul class="TabList tabHeaders">
#             <li class="Item tabHeader active" data-tab-show-class="overview-stats--all" data-type="Total">
#              <a href="javascript:;">
#               S9
# 																						전체
#              </a>
#             </li>
#             <li class="Item tabHeader" data-tab-show-class="overview-stats--soloranked" data-type="Solo">
#              <a href="javascript:;">
#               솔로랭크
#              </a>
#             </li>
#             <li class="Item tabHeader" data-tab-show-class="overview-stats--flexranked5v5" data-type="5vs5">
#              <a href="javascript:;">
#               자유랭크
#               <br/>
#               5v5
#              </a>
#             </li>
#             <li class="Item tabHeader" data-tab-show-class="overview-stats--flexranked3v3" data-type="3vs3">
#              <a href="javascript:;">
#               자유랭크
#               <br/>
#               3v3
#              </a>
#             </li>
#            </ul>
#           </div>
#           <div class="Content tabItems">
#            <div class="MostChampionContent tabItem overview-stats--all" style="display: block;">
#             <div class="MostChampionContent" data-last-info="7" data-season="13" data-summoner-id="1221663">
#              <div class="ChampionBox Ranked">
#               <div class="Face" title="아리">
#                <a href="/champion/ahri/statistics" target="_blank">
#                 <img alt="아리" class="ChampionImage" src="//opgg-static.akamaized.net/images/lol/champion/Ahri.png?image=w_45&amp;v=15354684000" width="45"/>
#                </a>
#               </div>
#               <div class="ChampionInfo">
#                <div class="ChampionName" title="아리">
#                 <a href="/champion/ahri/statistics" target="_blank">
#                  아리
#                 </a>
#                </div>
#                <div class="ChampionMinionKill tip" title="평균 CS (CS/분)">
#                 CS 134.5 (4.6)
#                </div>
#               </div>
#               <div class="PersonalKDA">
#                <div class="KDA green tip" title="(K 7.4 + A 8.85) / D 4.9">
#                 <span class="KDA">
#                  3.32:1
#                 </span>
#                 <span class="Text">
#                  평점
#                 </span>
#                </div>
#                <div class="KDAEach">
#                 <span class="Kill">
#                  7.4
#                 </span>
#                 <span class="Bar">
#                  /
#                 </span>
#                 <span class="Death">
#                  4.9
#                 </span>
#                 <span class="Bar">
#                  /
#                 </span>
#                 <span class="Assist">
#                  8.9
#                 </span>
#                </div>
#               </div>
#               <div class="Played">
#                <div class="WinRatio red tip" title="승률">
#                 60%
#                </div>
#                <div class="Title">
#                 20 게임
#                </div>
#               </div>
#              </div>
#              <div class="ChampionBox Ranked">
#               <div class="Face" title="징크스">
#                <a href="/champion/jinx/statistics" target="_blank">
#                 <img alt="징크스" class="ChampionImage" src="//opgg-static.akamaized.net/images/lol/champion/Jinx.png?image=w_45&amp;v=15354684000" width="45"/>
#                </a>
#               </div>
#               <div class="ChampionInfo">
#                <div class="ChampionName" title="징크스">
#                 <a href="/champion/jinx/statistics" target="_blank">
#                  징크스
#                 </a>
#                </div>
#                <div class="ChampionMinionKill tip" title="평균 CS (CS/분)">
#                 CS 169.3 (5.6)
#                </div>
#               </div>
#               <div class="PersonalKDA">
#                <div class="KDA normal tip" title="(K 5.67 + A 7.58) / D 4.75">
#                 <span class="KDA">
#                  2.79:1
#                 </span>
#                 <span class="Text">
#                  평점
#                 </span>
#                </div>
# ...
# 		});
# 			});
#         </script>
#         <!-- 175.223.48.29 -->
#        </div>
#        <div class="tabItem Content SummonerLayoutContent summonerLayout-champions" data-tab-data-url="/summoner/champions/userName=%ED%99%A9%ED%86%A0%EB%A7%A4%ED%8A%B8" data-tab-spinner-height="800" style="display: none;">
#        </div>
#        <div class="tabItem Content SummonerLayoutContent summonerLayout-league" data-tab-data-url="/summoner/league/userName=%ED%99%A9%ED%86%A0%EB%A7%A4%ED%8A%B8" data-tab-spinner-height="800" style="display: none;">
#        </div>
#        <div class="tabItem Content SummonerLayoutContent summonerLayout-rune" data-tab-data-url="/summoner/rune/userName=%ED%99%A9%ED%86%A0%EB%A7%A4%ED%8A%B8" data-tab-spinner-height="800" style="display: none;">
#        </div>
#        <div class="tabItem Content SummonerLayoutContent summonerLayout-mastery" data-tab-data-url="/summoner/mastery/userName=%ED%99%A9%ED%86%A0%EB%A7%A4%ED%8A%B8" data-tab-spinner-height="800" style="display: none;">
#        </div>
#        <div class="tabItem Content SummonerLayoutContent summonerLayout-spectator" data-tab-data-url="/summoner/spectator/userName=%ED%99%A9%ED%86%A0%EB%A7%A4%ED%8A%B8" data-tab-spinner-height="800" style="display: none;">
#        </div>
#        <div class="tabItem Content SummonerLayoutContent summonerLayout-plus" data-tab-data-url="/summoner/plus/userName=%ED%99%A9%ED%86%A0%EB%A7%A4%ED%8A%B8" data-tab-spinner-height="800" style="display: none;">
#        </div>
#        <div class="opgg__notice-summoner-bottom">
#        </div>
#       </div>
#       <div class="life-owner BigLifeOwner">
#        <!-- Venatus Market v3 - OP.GG - 728x90 Dynamic -->
#        <div class="vm-placement" data-google-query-id="CPq19vnIouACFRq7lgod_6IFsQ" data-id="5a84644f46e0fb0001d74d3c" data-pos="2" id="5a84644f46e0fb0001d74d3c-2" style='background: url("https://hb.vntsm.com/assets/op_loader.gif") center center no-repeat rgb(242, 242, 242); border: 1px solid rgb(213, 216, 216); position: relative; margin: 0px auto; overflow: hidden; max-width: 970px;'>
#         <div id="google_ads_iframe_/21726375739/VM_5a8460b346e0fb0001fc3bac_2__container__" style="border: 0pt none; display: block; margin: 0px auto;">
#          <iframe data-google-container-id="h" data-load-complete="true" frameborder="0" height="250" id="google_ads_iframe_/21726375739/VM_5a8460b346e0fb0001fc3bac_2" marginheight="0" marginwidth="0" name="google_ads_iframe_/21726375739/VM_5a8460b346e0fb0001fc3bac_2" scrolling="no" srcdoc="" style="border: 0px; vertical-align: bottom;" title="3rd party ad content" width="970">
#          </iframe>
#         </div>
#        </div>
#        <!-- / Venatus Market v3 - OP.GG - 728x90 Dynamic -->
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="l-footer">
#     <div class="footer">
#      <ul class="footer__links">
#       <li class="footer__links__item">
#        <a href="/about/">
#         About OP.GG
#        </a>
#       </li>
#       <li class="footer__links__item">
#        <a href="/about/logos">
#         로고 히스토리
#        </a>
#       </li>
#       <li class="footer__links__item">
#        <a href="/about/privacy/">
#         개인정보처리방침
#        </a>
#       </li>
#       <li class="footer__links__item">
#        <a href="https://opggkr.helpscoutdocs.com/collection/121-opgg" target="_blank">
#         도움말
#        </a>
#       </li>
#       <li class="footer__links__item">
#        <a href="mailto:contact@op.gg">
#         제휴
#        </a>
#       </li>
#       <li class="footer__links__item">
#        <a href="mailto:service@op.gg">
#         문의/피드백
#        </a>
#       </li>
#       <li class="footer__links__item">
#        <a href="http://log.op.gg/op-gg-recruit-wanted/" target="_blank">
#         채용
#        </a>
#       </li>
#      </ul>
#      <div class="footer__copyright">
#       © 2012-2019
#                         OP.GG.
#                                                     Data based on League of Legends
#                             Korea.
#      </div>
#      <ul class="footer__sns">
#       <li class="footer__sns__item footer__sns__item--twitter">
#        <a href="http://twitter.com/globalopgg/" target="_blank">
#         <i>
#          Twitter
#         </i>
#        </a>
#       </li>
#       <li class="footer__sns__item footer__sns__item--instagram">
#        <a href="https://www.instagram.com/opgginc/" target="_blank">
#         <i>
#          Instagram
#         </i>
#        </a>
#       </li>
#       <li class="footer__sns__item footer__sns__item--facebook">
#        <a href="https://www.facebook.com/lolopgg/" target="_blank">
#         <i>
#          Facebook
#         </i>
#        </a>
#       </li>
#      </ul>
#     </div>
#    </div>
#    <div class="adsbygoogle" id="adsense" style="width: 1px; height: 1px;">
#    </div>
#   </div>
#   <script type="text/javascript">
#    (function(i, s, o, g, r, a, m){
# 		i['GoogleAnalyticsObject'] = r;
# 		i[r] = i[r] || function(){
# 			(i[r].q = i[r].q || []).push(arguments)
# 		}, i[r].l = 1 * new Date();
# 		a = s.createElement(o),
# 			m = s.getElementsByTagName(o)[0];
# 		a.async = 1;
# 		a.src = g;
# 		m.parentNode.insertBefore(a, m)
# 	})(window, document, 'script', '//www.google-analytics.com/analytics.js', 'ga');
#
#
# 	ga('create', 'UA-37377845-1', 'www.op.gg');
# 	ga('send', 'event', 'pageView', '/summoner/summary', window.location.hostname);
# 		ga('set', 'dimension1', 'summoner');
# 			ga('set', 'dimension2', 'summary');
# 		ga('send', 'pageview', 'summoner/userName=%ED%99%A9%ED%86%A0%EB%A7%A4%ED%8A%B8');
#
# 	var sc_project = 8630180;
# 	var sc_invisible = 1;
# 	var sc_security = "e6464510";
#
# 	(function(){
# 		var s = document.getElementsByTagName('script')[0];
# 		var sc = document.createElement('script');
# 		sc.type = 'text/javascript';
# 		sc.async = true;
# 		sc.src = ('https:' == document.location.protocol ? 'https://secure' : 'http://www') + '.statcounter.com/counter/counter.js';
#
# 		s.parentNode.insertBefore(sc, s);
# 	})();
#   </script>
#   <!-- Global site tag (gtag.js) - Google Analytics -->
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-37377845-18">
#   </script>
#   <script>
#    window.dataLayer = window.dataLayer || [];
# 	function gtag(){dataLayer.push(arguments);}
# 	gtag('js', new Date());
#
# 	gtag('config', 'UA-37377845-18');
#   </script>
#   <script src="//wcs.naver.net/wcslog.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    if (!wcs_add) var wcs_add = {};
# 	wcs_add["wa"] = "55c48ac9e22bec";
# 	wcs_do();
#   </script>
#   <!--[if gte IE 9]><!-->
#   <script>
#    !function(e, o, n){
# 			window.HSCW = o, window.HS = n, n.beacon = n.beacon || {};
# 			var t = n.beacon;
# 			t.userConfig = {}, t.readyQueue = [], t.config = function(e){
# 				this.userConfig = e
# 			}, t.ready = function(e){
# 				this.readyQueue.push(e)
# 			}, o.config = {
# 				icon: 'message',
# 				color: '#1d2e51',
# 				docs: {enabled:(BrowserDetect.browser === 'Chrome') ? !0 : !1, baseUrl: '//opggkr.helpscoutdocs.com/'},
# 				contact: {enabled: !0, formId: "57ee6a3e-4d51-11e6-aae8-0a7d6919297d"},
# 				translation: {
# 					attachFileLabel: 'File'
# 				},
# 				attachment: true,
# 			};
# 			var r = e.getElementsByTagName("script")[0], c = e.createElement("script");
# 			c.type = "text/javascript", c.async = !0, c.src = "https://djtflbt20bdde.cloudfront.net/", r.parentNode.insertBefore(c, r)
# 		}(document, window.HSCW || {}, window.HS || {});
#   </script>
#   <script>
#    if(BrowserDetect.browser === 'Chrome') {
# 				HS.beacon.config({
# 					icon: 'message',
# 					color: '#1d2e51',
# 					translation: {
# 						attachFileLabel: 'File'
# 					},
# 					topics: [
# 						{val: 'summonerPage', label: '소환사페이지'},
# 						// {val: 'mmr', label: 'MMR' },
# 						{val: 'proMatches', label: '관전하기'},
# 						{val: 'champions', label: '챔피언분석'},
# 						{val: 'Mobile', label: '모바일'},
# 						{val: 'Membership', label: '멤버십'},
# 						{val: 'others', label: '기타'},
# 					],
# 					attachment: true,
# 				});
# 				HS.beacon.ready(function() {
# 	  									HS.beacon['suggest']([
# 						'5b29b9fc0428632c466b1731',
# 						'5b29ba3b0428632c466b1735',
# 						'5b57fdd42c7d3a03f89cf598',
# 						'5b29b9be2c7d3a0fa9a3318d',
# 						'5b29c26f2c7d3a0fa9a331c2',
# 						'5b29c49e2c7d3a0fa9a331d2',
# 						'5b29b9a00428632c466b172d',
# 						'5b29c09f0428632c466b174b',
# 					]);
# 	  								})
# 			}
#   </script>
#   <!--<![endif]-->
#   <script type="text/javascript">
#    window.NREUM||(NREUM={});NREUM.info={"beacon":"bam.nr-data.net","licenseKey":"8159f4d5fa","applicationID":"78634178","transactionName":"b1ZTYBdWWxVWUUZcV1YcckEWQ1oLGEFHWFVXXVRGSg==","queueTime":0,"applicationTime":1428,"atts":"QxFQFl9MSBs=","errorBeacon":"bam.nr-data.net","agent":""}
#   </script>
#   <!-- Venatus Market v3 -->
#   <script>
#    (function(){
# 			document.write('&lt;div id="vmv3-ad-manager" style="display:none"&gt;&lt;/div&gt;');
# 			document
# 				.getElementById("vmv3-ad-manager")
# 				.innerHTML = '&lt;iframe id="vmv3-frm" src="javascript:\'&lt;html&gt;&lt;body&gt;&lt;/body&gt;&lt;/html&gt;\'" width="0" height="0" data-mode="scan" data-site-id="5a8460b346e0fb0001fc3bac"&gt;&lt;/iframe&gt;';
# 			var loaderFrame = document.getElementById("vmv3-frm");
# 			var loaderFrameWindow = loaderFrame.contentWindow ? loaderFrame.contentWindow : loaderFrame.contentDocument;
# 			loaderFrameWindow.document.open();
# 			loaderFrameWindow.document.write('&lt;scr' + 'ipt src="//hb.vntsm.com/v3/live/ad-manager.min.js" type="text/javascript" async onerror="window.parent.lifeOnwer();"&gt;' + '&lt;/scr' + 'ipt&gt;');
# 			loaderFrameWindow.document.close();
# 		})();
#   </script>
#   <div id="vmv3-ad-manager" style="display:none">
#    <iframe data-mode="scan" data-site-id="5a8460b346e0fb0001fc3bac" height="0" id="vmv3-frm" src="javascript:'&lt;html&gt;&lt;body&gt;&lt;/body&gt;&lt;/html&gt;'" width="0">
#    </iframe>
#   </div>
#   <!-- / Venatus Market v3 -->
#   <script>
#    window.lifeOnwer = function(){
# 			this.randAdIdx = '622776085';
# 			this.showAd = function(element, size){
# 				if (size === "skyscraper") {
# 					this.showAdSkyscraper();
# 					return;
# 				}
# 				element.innerHTML = this.getAdHTML(size);
# 				element.classList.remove('vm-placement');
# 			};
#
# 			this.showAdSkyscraper = function(){
# 				if (this.getMobileOS() !== "unknown") {
# 					return;
# 				}
#
# 				var elementLeft = document.createElement("div");
# 				elementLeft.innerHTML = this.getAdHTML("skyscraper");
# 				elementLeft.setAttribute('style', 'position: absolute; left: 50%; top: 372px; margin-left: -725px;');
# 				document.body.appendChild(elementLeft);
#
# 				var elementRight = document.createElement("div");
# 				elementRight.innerHTML = this.getAdHTML("skyscraper");
# 				elementRight.setAttribute('style', 'position: absolute; right: 50%; top: 372px; margin-right: -725px;');
# 				document.body.appendChild(elementRight);
#
# 				$(elementRight).scrollToFixed({
# 					marginTop: 60
# 				});
# 			};
#
# 			this.getAdHTML = function(size){
# 				var lang = (this.getLang() === 'ko_KR' ? 'ko' : 'en');
# 				return "&lt;a href=\"" + this.getAdLink(this.adIndex) + "\" target=\"_blank\" class=\"lifeOnwer-" + randAdIdx + "\"&gt;" +
# 					"&lt;img src='//opgg-static.akamaized.net/images/lifeowner/opgg/" + lang + "/" + adIndex + "-" + size + ".png'&gt;" +
# 					"&lt;/a&gt;";
# 			};
# 			this.getAdLink = function(adIndex){
# 				var linkKey = this.getMobileOS() + '-' + adIndex;
# 				switch (linkKey) {
# 					case "Android-1":
# 						return "market://details?id=gg.op.lol.android&amp;referrer=utm_source%3Dopgg%26utm_medium%3Dbanner01%26utm_content%3Dapp";
# 					case "Android-2":
# 						return "market://details?id=gg.op.lol.android&amp;referrer=utm_source%3Dopgg%26utm_medium%3Dbanner02%26utm_content%3Dlol";
# 					case "Android-3":
# 						return "market://details?id=gg.op.lol.android&amp;referrer=utm_source%3Dopgg%26utm_medium%3banner03%26utm_content%3Dpubg";
# 					case "unknown-1":
# 						return "https://play.google.com/store/apps/details?id=gg.op.lol.android&amp;referrer=utm_source%3Dopgg%26utm_medium%3Dbanner01%26utm_content%3Dapp";
# 					case "unknown-2":
# 						return "https://play.google.com/store/apps/details?id=gg.op.lol.android&amp;referrer=utm_source%3Dopgg%26utm_medium%3Dbanner02%26utm_content%3Dlol";
# 					case "unknown-3":
# 						return "https://play.google.com/store/apps/details?id=gg.op.lol.android&amp;referrer=utm_source%3Dopgg%26utm_medium%3Dbanner03%26utm_content%3Dpubg";
# 					default:
# 						return "itms-apps://itunes.apple.com/kr/app/apple-store/id605722237";
# 				}
# 			};
# 			this.getMobileOS = function(){
# 				var userAgent = navigator.userAgent || navigator.vendor;
#
# 				if (/android/i.test(userAgent)) {
# 					return "Android";
# 				}
#
# 				if (/iPad|iPhone|iPod/.test(userAgent)) {
# 					return "iOS";
# 				}
#
# 				return "unknown";
# 			};
# 			this.getLang = function(){
# 				return document.documentElement.lang || "en";
# 			};
#
# 			this.slots = [
# 				{
# 					'id': '5a84644f46e0fb0001d74d3c',
# 					'size': '970x90'
# 				},
# 				{
# 					'id': '5a84640c46e0fb0001fc3bb0',
# 					'size': '300x250'
# 				},
# 				{
# 					'id': '5a8462a746e0fb0001bf35aa',
# 					'size': 'skyscraper'
# 				},
# 			];
# 			this.getCookie = function(name){
# 				var match = document.cookie.match(new RegExp('(^| )' + name + '=([^;]+)'));
# 				if (match) return match[2];
# 			};
# 			this.bindClickEvent = function(){
# 				$(".lifeOnwer-" + randAdIdx).click(function(evt){
# 					$.OP.GG.tracker.combine.sendEvent(['FB'], 'Opgg', 'ClickAd', {
# 						Location: location_,
# 						subLocation: subLocation,
# 						BannerType: adIndex
# 					});
# 				});
# 			};
#
# 			this.adIndex = Math.floor(Math.random() * (this.getMobileOS() === "iOS" ? 2 : 3)) + 1;
# 			this.location_ = "summoner";
# 			this.subLocation = "summary";
#
#
# 			slots.forEach(function(slot){
# 				if (self.getMobileOS() === "unknown" &amp;&amp; slot.size === "300x250") {
# 					return;
# 				}
# 				var element = document.querySelector('.vm-placement[data-id="' + slot.id + '"]');
# 				if (element) {
# 					self.showAd(element, slot.size);
# 				}
# 			});
# 			this.bindClickEvent();
# 		};
#   </script>
#   <!-- Venatus Market Placement (OP.GG 2 - Rich Media  - 1x1) -->
#   <div class="vm-placement" data-id="5a8462a746e0fb0001bf35aa" data-pos="3" data-top-space="372" id="5a8462a746e0fb0001bf35aa-3" style='display: none; background: url("https://hb.vntsm.com/assets/op_loader.gif") center center no-repeat rgb(242, 242, 242); border: 1px solid rgb(213, 216, 216);'>
#   </div>
#   <!-- / Venatus Market Placement (OP.GG 2 - Rich Media  - 1x1) -->
#   <style>
#    .vm-skin, .vm-footer {
# 			z-index: 10 !important;
# 		}
#   </style>
#   <!-- 175.223.48.29 -->
#   <style>
#    body.tablesorter-disableSelection { -ms-user-select: none; -moz-user-select: -moz-none;-khtml-user-select: none; -webkit-user-select: none; user-select: none; }.tablesorter-resizable-container { position: relative; height: 1px; }.tablesorter-resizable-handle { position: absolute; display: inline-block; width: 8px;top: 1px; cursor: ew-resize; z-index: 3; user-select: none; -moz-user-select: none; }
#   </style>
#   <div class=" fb_reset" id="fb-root">
#    <div style="position: absolute; top: -10000px; width: 0px; height: 0px;">
#     <div>
#      <iframe allow="encrypted-media" allowfullscreen="true" allowtransparency="true" aria-hidden="true" frameborder="0" id="fb_xdm_frame_https" name="fb_xdm_frame_https" scrolling="no" src="https://staticxx.facebook.com/connect/xd_arbiter/r/GMRn6XEBZ06.js?version=44#channel=f2fc743dc948044&amp;origin=http%3A%2F%2Fwww.op.gg" style="border: none;" tabindex="-1" title="Facebook Cross Domain Communication Frame">
#      </iframe>
#     </div>
#     <div>
#     </div>
#    </div>
#   </div>
#   <div id="hs-beacon">
#    <div data-reactroot="">
#     <iframe style="background: transparent; border: none; bottom: 12px; height: 80px; position: fixed; right: 18px; top: auto; width: 80px; z-index: 1050;">
#     </iframe>
#     <iframe style="border: none; bottom: 89px; height: 0px; position: fixed; right: 15px; top: auto; width: 450px; z-index: 1050;">
#     </iframe>
#    </div>
#   </div>
#   <div class="vm-skin vm-skin-left" style="width: 0px; margin-top: 10px; top: 372px; left: 0px; position: fixed; overflow: hidden; z-index: 10000;">
#   </div>
#   <iframe id="google_osd_static_frame_6872435428685" name="google_osd_static_frame" style="display: none; width: 0px; height: 0px;">
#   </iframe>
#  </body>
# </html>

# %% [markdown]
# ## 랭크게임 티어와 랭킹알아보기

# %%
import re #정규식
from IPython.core.interactiveshell import InteractiveShell 
InteractiveShell.ast_node_interactivity = "all" # all 이면 여러개를 출력할 수 있도록 해줌

# %%
TierImage = soup.find('div','Medal').find('img','Image')
TierImage = TierImage['src']
TierImage = "https:" + TierImage
soup.find('div','Medal') #티어 이미지
# Out:
# <div class="Medal tip" title="솔랭">
# <img class="Image" src="//opgg-static.akamaized.net/images/medals/bronze_2.png"/>
# </div>

# %%
try:
    soup.find('div','LadderRank') #래더 랭크
    LadderRank = soup.find('div','LadderRank').get_text()
    LadderRank = re.split(('\n|\t'), LadderRank)
    LadderRank = "".join(LadderRank)
except:
    LadderRank = '랭크기록이 없습니다.'
# Out:
# <div class="LadderRank">
# <a class="tip Link" href="/ranking/ladder/summonerName=%ED%99%A9%ED%86%A0%EB%A7%A4%ED%8A%B8" target="_blank" title="래더 랭킹 목록에서 보기">
# 						래더 랭킹 <span class="ranking">713,407</span>위 (상위 87%)
# 					</a>
# </div>

# %%
soup.find('div','SummonerRatingMedium') #랭크게임 정보
SummonerRatingMedium = soup.find('div','SummonerRatingMedium').get_text()
SummonerRatingMedium = re.split(('\n|\t'), SummonerRatingMedium)
SummonerRatingMedium = " ".join(SummonerRatingMedium)
# Out:
# <div class="SummonerRatingMedium">
# <div class="Medal tip" title="솔랭">
# <img class="Image" src="//opgg-static.akamaized.net/images/medals/bronze_2.png"/>
# </div>
# <div class="TierRankInfo">
# <div class="RankType">솔로랭크</div>
# <div class="Position">
# <b>미드</b> 총 26게임
# 			</div>
# <div class="TierRank">Bronze 2</div>
# <div class="TierInfo">
# <span class="LeaguePoints">
# 				15 LP
# 			</span>
# 							/
# 						<span class="WinLose">
# <span class="wins">14승</span>
# <span class="losses">12패</span>
# <br/>
# <span class="winratio">승률 54%</span>
# </span>
# </div>
# <div class="LeagueName">
# </div>
# </div>
# </div>

# %%
from IPython.display import Image
from IPython.core.display import HTML #이미지 출력
Image(url= TierImage)
username
LadderRank
SummonerRatingMedium
# Out:
# <img src="https://opgg-static.akamaized.net/images/medals/bronze_2.png"/>
# '황토매트'
# '래더 랭킹 713,407위 (상위 87%)'
# '     솔로랭크  미드 총 26게임     Bronze 2       15 LP            /        14승 12패  승률 54%      '

# %% [markdown]
# ## 모스트 챔피언 분석하기

# %%
soup.find('div','MostChampionContent')
# Out:
# <div class="MostChampionContent tabItem overview-stats--all" style="display: block;">
# <div class="MostChampionContent" data-last-info="7" data-season="13" data-summoner-id="1221663">
# <div class="ChampionBox Ranked">
# <div class="Face" title="아리">
# <a href="/champion/ahri/statistics" target="_blank">
# <img alt="아리" class="ChampionImage" src="//opgg-static.akamaized.net/images/lol/champion/Ahri.png?image=w_45&amp;v=15354684000" width="45"/>
# </a>
# </div>
# <div class="ChampionInfo">
# <div class="ChampionName" title="아리">
# <a href="/champion/ahri/statistics" target="_blank">
# 					아리
# 				</a>
# </div>
# <div class="ChampionMinionKill tip" title="평균 CS (CS/분)">
# 									CS 134.5 (4.6)
# 							</div>
# </div>
# <div class="PersonalKDA">
# <div class="KDA green tip" title="(K 7.4 + A 8.85) / D 4.9">
# <span class="KDA">3.32:1</span>
# <span class="Text">평점</span>
# </div>
# <div class="KDAEach">
# <span class="Kill">7.4</span>
# <span class="Bar">/</span>
# <span class="Death">4.9</span>
# <span class="Bar">/</span>
# <span class="Assist">8.9</span>
# </div>
# </div>
# <div class="Played">
# <div class="WinRatio red tip" title="승률">
# 					60%
# 				</div>
# <div class="Title">20 게임</div>
# </div>
# </div>
# <div class="ChampionBox Ranked">
# <div class="Face" title="징크스">
# <a href="/champion/jinx/statistics" target="_blank">
# <img alt="징크스" class="ChampionImage" src="//opgg-static.akamaized.net/images/lol/champion/Jinx.png?image=w_45&amp;v=15354684000" width="45"/>
# </a>
# </div>
# <div class="ChampionInfo">
# <div class="ChampionName" title="징크스">
# <a href="/champion/jinx/statistics" target="_blank">
# 					징크스
# 				</a>
# </div>
# <div class="ChampionMinionKill tip" title="평균 CS (CS/분)">
# 									CS 169.3 (5.6)
# 							</div>
# </div>
# <div class="PersonalKDA">
# <div class="KDA normal tip" title="(K 5.67 + A 7.58) / D 4.75">
# <span class="KDA">2.79:1</span>
# <span class="Text">평점</span>
# </div>
# <div class="KDAEach">
# <span class="Kill">5.7</span>
# <span class="Bar">/</span>
# <span class="Death">4.8</span>
# <span class="Bar">/</span>
# <span class="Assist">7.6</span>
# </div>
# </div>
# <div class="Played">
# <div class="WinRatio normal tip" title="승률">
# 					33%
# 				</div>
# <div class="Title">12 게임</div>
# </div>
# </div>
# <div class="ChampionBox Ranked">
# <div class="Face" title="오른">
# <a href="/champion/ornn/statistics" target="_blank">
# <img alt="오른" class="ChampionImage" src="//opgg-static.akamaized.net/images/lol/champion/Ornn.png?image=w_45&amp;v=15354684000" width="45"/>
# </a>
# </div>
# <div class="ChampionInfo">
# <div class="ChampionName" title="오른">
# <a href="/champion/ornn/statistics" target="_blank">
# 					오른
# 				</a>
# </div>
# <div class="ChampionMinionKill tip" title="평균 CS (CS/분)">
# 									CS 141.4 (4.7)
# 							</div>
# </div>
# <div class="PersonalKDA">
# <div class="KDA green tip" title="(K 4.44 + A 9) / D 4.22">
# <span class="KDA">3.18:1</span>
# <span class="Text">평점</span>
# </div>
# <div class="KDAEach">
# <span class="Kill">4.4</span>
# <span class="Bar">/</span>
# <span class="Death">4.2</span>
# <span class="Bar">/</span>
# <span class="Assist">9.0</span>
# </div>
# </div>
# <div class="Played">
# <div class="WinRatio normal tip" title="승률">
# 					33%
# 				</div>
# <div class="Title">9 게임</div>
# </div>
# </div>
# <div class="ChampionBox Ranked">
# <div class="Face" title="레오나">
# <a href="/champion/leona/statistics" target="_blank">
# <img alt="레오나" class="ChampionImage" src="//opgg-static.akamaized.net/images/lol/champion/Leona.png?image=w_45&amp;v=15354684000" width="45"/>
# </a>
# </div>
# <div class="ChampionInfo">
# <div class="ChampionName" title="레오나">
# <a href="/champion/leona/statistics" target="_blank">
# 					레오나
# 				</a>
# </div>
# <div class="ChampionMinionKill tip" title="평균 CS (CS/분)">
# 									CS 48.8 (2.0)
# 							</div>
# </div>
# <div class="PersonalKDA">
# <div class="KDA orange tip" title="(K 2.2 + A 11.8) / D 2.4">
# <span class="KDA">5.83:1</span>
# <span class="Text">평점</span>
# </div>
# <div class="KDAEach">
# <span class="Kill">2.2</span>
# <span class="Bar">/</span>
# <span class="Death">2.4</span>
# <span class="Bar">/</span>
# <span class="Assist">11.8</span>
# </div>
# </div>
# <div class="Played">
# <div class="WinRatio red tip" title="승률">
# 					80%
# 				</div>
# <div class="Title">5 게임</div>
# </div>
# </div>
# <div class="ChampionBox Ranked">
# <div class="Face" title="트리스타나">
# <a href="/champion/tristana/statistics" target="_blank">
# <img alt="트리스타나" class="ChampionImage" src="//opgg-static.akamaized.net/images/lol/champion/Tristana.png?image=w_45&amp;v=15354684000" width="45"/>
# </a>
# </div>
# <div class="ChampionInfo">
# <div class="ChampionName" title="트리스타나">
# <a href="/champion/tristana/statistics" target="_blank">
# 					트리스타나
# 				</a>
# </div>
# <div class="ChampionMinionKill tip" title="평균 CS (CS/분)">
# 									CS 129.0 (5.1)
# 							</div>
# </div>
# <div class="PersonalKDA">
# <div class="KDA normal tip" title="(K 4.4 + A 5) / D 5.4">
# <span class="KDA">1.74:1</span>
# <span class="Text">평점</span>
# </div>
# <div class="KDAEach">
# <span class="Kill">4.4</span>
# <span class="Bar">/</span>
# <span class="Death">5.4</span>
# <span class="Bar">/</span>
# <span class="Assist">5.0</span>
# </div>
# </div>
# <div class="Played">
# <div class="WinRatio normal tip" title="승률">
# 					40%
# 				</div>
# <div class="Title">5 게임</div>
# </div>
# </div>
# <div class="ChampionBox Ranked">
# <div class="Face" title="카시오페아">
# <a href="/champion/cassiopeia/statistics" target="_blank">
# <img alt="카시오페아" class="ChampionImage" src="//opgg-static.akamaized.net/images/lol/champion/Cassiopeia.png?image=w_45&amp;v=15354684000" width="45"/>
# </a>
# </div>
# <div class="ChampionInfo">
# <div class="ChampionName" title="카시오페아">
# <a href="/champion/cassiopeia/statistics" target="_blank">
# 					카시오페아
# 				</a>
# </div>
# <div class="ChampionMinionKill tip" title="평균 CS (CS/분)">
# 									CS 182.8 (7.1)
# 							</div>
# </div>
# <div class="PersonalKDA">
# <div class="KDA normal tip" title="(K 8 + A 5.4) / D 4.6">
# <span class="KDA">2.91:1</span>
# <span class="Text">평점</span>
# </div>
# <div class="KDAEach">
# <span class="Kill">8.0</span>
# <span class="Bar">/</span>
# <span class="Death">4.6</span>
# <span class="Bar">/</span>
# <span class="Assist">5.4</span>
# </div>
# </div>
# <div class="Played">
# <div class="WinRatio normal tip" title="승률">
# 					40%
# 				</div>
# <div class="Title">5 게임</div>
# </div>
# </div>
# <div class="ChampionBox Ranked">
# <div class="Face" title="시비르">
# <a href="/champion/sivir/statistics" target="_blank">
# <img alt="시비르" class="ChampionImage" src="//opgg-static.akamaized.net/images/lol/champion/Sivir.png?image=w_45&amp;v=15354684000" width="45"/>
# </a>
# </div>
# <div class="ChampionInfo">
# <div class="ChampionName" title="시비르">
# <a href="/champion/sivir/statistics" target="_blank">
# 					시비르
# 				</a>
# </div>
# <div class="ChampionMinionKill tip" title="평균 CS (CS/분)">
# 									CS 234.3 (7.1)
# 							</div>
# </div>
# <div class="PersonalKDA">
# <div class="KDA green tip" title="(K 5 + A 8) / D 4.33">
# <span class="KDA">3.00:1</span>
# <span class="Text">평점</span>
# </div>
# <div class="KDAEach">
# <span class="Kill">5.0</span>
# <span class="Bar">/</span>
# <span class="Death">4.3</span>
# <span class="Bar">/</span>
# <span class="Assist">8.0</span>
# </div>
# </div>
# <div class="Played">
# <div class="WinRatio normal tip" title="승률">
# 					33%
# 				</div>
# <div class="Title">3 게임</div>
# </div>
# </div>
# <div class="MoreButton">
# <a class="Action" href="/summoner/champions/userName=%ED%99%A9%ED%86%A0%EB%A7%A4%ED%8A%B8">더 보기 + 다른 시즌 보기</a>
# </div></div> </div>

# %%
Champ = [] ; CS = [] ; KDARatio = [] ; tmp = [] ; K = [] ; D = [] ; A = [] ; WinRatio = [] ; PlayedGames = []
span = ['Kill','Death','Assist','KDA']
dict_tmp = {'ChampionName':Champ,'ChampionMinionKill':CS,'KDA':KDARatio,'Kill':K,'Death':D,'Assist':A, 
            'WinRatio':WinRatio,'Title':PlayedGames}

for x,y in dict_tmp.items():
    if x in span:
        tmp = soup.find('div','MostChampionContent').find_all('span',x)
    else:
        tmp = soup.find('div','MostChampionContent').find_all('div',x)
    for i in tmp:
        tmp = re.split(('\n|\t'),i.get_text())
        tmp = [n for n in tmp if n][0]
        y.append(tmp)
    y
# Out:
# ['아리', '징크스', '오른', '레오나', '트리스타나', '카시오페아', '시비르']
# ['CS 134.5 (4.6)',
#  'CS 169.3 (5.6)',
#  'CS 141.4 (4.7)',
#  'CS 48.8 (2.0)',
#  'CS 129.0 (5.1)',
#  'CS 182.8 (7.1)',
#  'CS 234.3 (7.1)']
# ['3.32:1', '2.79:1', '3.18:1', '5.83:1', '1.74:1', '2.91:1', '3.00:1']
# ['7.4', '5.7', '4.4', '2.2', '4.4', '8.0', '5.0']
# ['4.9', '4.8', '4.2', '2.4', '5.4', '4.6', '4.3']
# ['8.9', '7.6', '9.0', '11.8', '5.0', '5.4', '8.0']
# ['60%', '33%', '33%', '80%', '40%', '40%', '33%']
# ['20 게임', '12 게임', '9 게임', '5 게임', '5 게임', '5 게임', '3 게임']

# %%
InteractiveShell.ast_node_interactivity = "last" 

MostChampionContent_df = {'Champ':Champ, 'CS':CS, 'KDARatio':KDARatio, 'K':K,'D':D,'A':A
                          , 'WinRatio':WinRatio, 'PlayedGames':PlayedGames}
MCC_df = pd.DataFrame(MostChampionContent_df)
MCC_df.set_index('Champ',inplace=True)
print('가장 많이 플레이한 챔피언')
MCC_df
# Out:
# 가장 많이 플레이한 챔피언
#                    CS KDARatio    K    D     A WinRatio PlayedGames
# Champ
# 아리     CS 134.5 (4.6)   3.32:1  7.4  4.9   8.9      60%       20 게임
# 징크스    CS 169.3 (5.6)   2.79:1  5.7  4.8   7.6      33%       12 게임
# 오른     CS 141.4 (4.7)   3.18:1  4.4  4.2   9.0      33%        9 게임
# 레오나     CS 48.8 (2.0)   5.83:1  2.2  2.4  11.8      80%        5 게임
# 트리스타나  CS 129.0 (5.1)   1.74:1  4.4  5.4   5.0      40%        5 게임
# 카시오페아  CS 182.8 (7.1)   2.91:1  8.0  4.6   5.4      40%        5 게임
# 시비르    CS 234.3 (7.1)   3.00:1  5.0  4.3   8.0      33%        3 게임

# %%
KDARatio_fl = [] ; WinRatio_fl = []
for i in KDARatio:
    tmp = re.split((':1|%'),i)
    tmp = [n for n in tmp if n][0]
    KDARatio_fl.append(tmp)
for i in WinRatio:
    tmp = re.split((':1|%'),i)
    tmp = [n for n in tmp if n][0]
    WinRatio_fl.append(tmp)
CS_new = []
n = 0
while n < len(list(MCC_df.index)):
    sw = 0
    k = ''
    tmp = MCC_df['CS'][n]
    for i in tmp:
        if i == '(':
            sw = 1
        if sw == 1:
            k += i
    CS_new.append(k.strip('(|)'))
    n += 1

ForGragh = {'Champ':Champ,'CS':CS_new,'KDARatio':KDARatio_fl, 'WinRatio':WinRatio_fl}
ForGragh = pd.DataFrame(ForGragh)
ForGragh['KDARatio'] = ForGragh['KDARatio'].astype(float)
ForGragh['WinRatio'] = ForGragh['WinRatio'].astype(float)
ForGragh['CS'] = ForGragh['CS'].astype(float)
ForGragh = ForGragh.set_index('Champ')
plt.figure()
plt.subplot(311)
ForGragh['KDARatio'].plot(kind='barh', grid=True, figsize=(15,15))
plt.xlabel('KDARatio')
plt.subplot(312)
ForGragh['WinRatio'].plot(kind='barh', grid=True, figsize=(15,15))
plt.xlabel('WinRatio')
plt.subplot(313)
ForGragh['CS'].plot(kind='barh', grid=True, figsize=(15,15))
plt.xlabel('CS')
plt.show()

# %% [markdown]
# ## 최근 100경기 분석하기

# %%
soup.find('div','GameItemList').find_all('div','GameItemWrap')
# Out:
# [<div class="GameItemWrap">
#  <div class="GameItem Win " data-game-id="3528506167" data-game-result="win" data-game-time="1549298778" data-summoner-id="1221663">
#  <div class="Content">
#  <div class="GameStats">
#  <div class="GameType">
#  					솔랭
#  				</div>
#  <div class="TimeStamp"><span class="_timeago _timeCountAssigned tip" data-datetime="1549298778" data-interval="60" data-type="" title="2019년 2월 5일 오전 1시 46분">23분 전</span></div>
#  <div class="Bar"></div>
#  <div class="GameResult">
#  											승리									</div>
#  <div class="GameLength">29분 21초</div>
#  </div>
#  <div class="GameSettingInfo">
#  <div class="ChampionImage">
#  <a href="/champion/cassiopeia/statistics" target="_blank"><img alt="카시오페아" class="Image" src="//opgg-static.akamaized.net/images/lol/champion/Cassiopeia.png?image=w_46&amp;v=15354684000"/></a>
#  </div>
#  <div class="SummonerSpell">
#  <div class="Spell">
#  <img alt="정화" class="Image tip" src="//opgg-static.akamaized.net/images/lol/spell/SummonerBoost.png?image=w_22&amp;v=15354684000" title="&lt;b style='color: #ffc659'&gt;정화&lt;/b&gt;&lt;br&gt;&lt;span&gt;챔피언에 걸린 모든 이동 불가와 (제압 및 공중으로 띄우는 효과 제외) 소환사 주문에 의한 해로운 효과를 제거하고 새로 적용되는 이동 불가 효과들의 지속 시간을 3초간 65% 감소시킵니다.&lt;/span&gt;"/>
#  </div>
#  <div class="Spell">
#  <img alt="점멸" class="Image tip" src="//opgg-static.akamaized.net/images/lol/spell/SummonerFlash.png?image=w_22&amp;v=15354684000" title="&lt;b style='color: #ffc659'&gt;점멸&lt;/b&gt;&lt;br&gt;&lt;span&gt;커서 방향으로 챔피언이 짧은 거리를 순간이동합니다.&lt;/span&gt;"/>
#  </div>
#  </div>
#  <div class="Runes">
#  <div class="Rune">
#  <img alt="신비로운 유성" class="Image tip" src="//opgg-static.akamaized.net/images/lol/perk/8229.png?image=w_22&amp;v=1" title="&lt;b style='color: #ffc659'&gt;신비로운 유성&lt;/b&gt;&lt;br&gt;&lt;span&gt;챔피언에게 스킬로 피해를 주면 해당 위치에 유성을 불러옵니다. 신비로운 유성이 재사용 대기 중일 경우 남은 재사용 대기시간이 감소합니다.&lt;br&gt;&lt;br&gt;&lt;lol-uikit-tooltipped-keyword key='LinkTooltip_Description_AdaptiveDmg'&gt;&lt;font color='#48C4B7'&gt;적응형 피해&lt;/font&gt;&lt;/lol-uikit-tooltipped-keyword&gt;: 레벨에 따라 30 ~ 100 (&lt;scaleAP&gt;+주문력의 0.2&lt;/scaleAP&gt; 및 &lt;scaleAD&gt;+추가 공격력의 0.35&lt;/scaleAD&gt;)&lt;br&gt;재사용 대기시간: 20 ~ 8초&lt;br&gt;&lt;rules&gt;&lt;br&gt;재사용 대기시간 감소:&lt;br&gt;단일 대상 스킬: 20%&lt;br&gt;광역 스킬: 10%&lt;br&gt;지속 피해 스킬: 5%&lt;br&gt;&lt;/rules&gt;&lt;/span&gt;"/>
#  </div>
#  <div class="Rune">
#  <img alt="지배" class="Image tip" src="//opgg-static.akamaized.net/images/lol/perkStyle/8100.png?image=w_22&amp;v=2" title="&lt;b style='color: #ffc659'&gt;지배&lt;/b&gt;&lt;br&gt;&lt;span&gt;강력한 피해와 빠른 접근&lt;/span&gt;"/>
#  </div>
#  </div>
#  <div class="ChampionName">
#  <a href="/champion/cassiopeia/statistics" target="_blank">카시오페아</a>
#  </div>
#  </div>
#  <div class="KDA">
#  <div class="KDA">
#  <span class="Kill">7</span> /
#  					<span class="Death">5</span> /
#  					<span class="Assist">12</span>
#  </div>
#  <div class="KDARatio">
#  <span class="KDARatio ">3.80:1</span> 평점				</div>
#  <div class="Badge"><span class="Text MVP">MVP</span></div>
#  </div>
#  <div class="Stats">
#  <div class="Level">
#  					레벨15
#  				</div>
#  <div class="CS">
#  <span class="CS tip" title="미니언 150  + 몬스터 36&lt;br&gt;분당CS 6.3개">186 (6.3)</span> CS
#  				</div>
#  <div class="CKRate tip" title="킬관여율">
#  						킬관여 54%
#  					</div>
#  <div class="MMR">매치 평균 <b>Bronze 3</b></div>
#  </div>
#  <div class="Items">
#  <div class="ItemList">
#  <div class="Item">
#  <img alt="라바돈의 죽음모자" class="Image tip" src="//opgg-static.akamaized.net/images/lol/item/3089.png?image=w_22&amp;v=15367644000" title="&lt;b style='color: #00cfbc'&gt;라바돈의 죽음모자&lt;/b&gt;&lt;br&gt;&lt;span&gt;주문력이 대폭 상승합니다.&lt;/span&gt;&lt;br&gt;&lt;span&gt;&lt;stats&gt;주문력 +120  &lt;/stats&gt;&lt;br&gt;&lt;br&gt;&lt;unique&gt;고유 지속 효과:&lt;/unique&gt; 주문력이 40% 상승합니다.&lt;/span&gt;&lt;br&gt;&lt;span&gt;가격:&lt;/span&gt; &lt;span style='color: #ffc659'&gt;3600 (1100)&lt;/span&gt;"/>
#  </div>
#  <div class="Item">
#  <img alt="충전형 물약" class="Image tip" src="//opgg-static.akamaized.net/images/lol/item/2031.png?image=w_22&amp;v=15367644000" title="&lt;b style='color: #00cfbc'&gt;충전형 물약&lt;/b&gt;&lt;br&gt;&lt;span&gt;일정 시간 동안 체력이 회복되며, 상점에 가면 다시 충전됩니다.&lt;/span&gt;&lt;br&gt;&lt;span&gt;&lt;groupLimit&gt;한 번에 한 종류의 회복 물약만 소지할 수 있습니다.&lt;/groupLimit&gt;&lt;br&gt;&lt;br&gt;&lt;active&gt;고유 사용 효과:&lt;/active&gt; 충전량을 1회 소모해 12초 동안 125의 체력을 회복합니다. 상점 방문 시 2회의 충전량이 다시 채워집니다.&lt;/span&gt;&lt;br&gt;&lt;span&gt;가격:&lt;/span&gt; &lt;span style='color: #ffc659'&gt;150 (150)&lt;/span&gt;"/>
#  </div>
#  <div class="Item">
#  <img alt="대천사의 포옹" class="Image tip" src="//opgg-static.akamaized.net/images/lol/item/3040.png?image=w_22&amp;v=15367644000" title="&lt;b style='color: #00cfbc'&gt;대천사의 포옹&lt;/b&gt;&lt;br&gt;&lt;span&gt;&lt;stats&gt;주문력 +50&lt;br&gt;&lt;mana&gt;마나 +1400&lt;/mana&gt;&lt;br&gt;재사용 대기시간 감소 +10%&lt;/stats&gt;&lt;br&gt;&lt;br&gt;&lt;unique&gt;고유 지속 효과 - 가속:&lt;/unique&gt; 재사용 대기시간이 추가로 10% 감소합니다.&lt;br&gt;&lt;mana&gt;&lt;unique&gt;고유 지속 효과 - 경탄:&lt;/unique&gt; 최대 마나의 3%만큼 주문력이 오릅니다. 마나를 소모하면 소모량의 25%를 돌려받습니다.&lt;/mana&gt;&lt;br&gt;&lt;active&gt;고유 사용 효과 - 마나 보호막:&lt;/active&gt; 현재 마나의 15%를 소모하여 2초 동안 150 + 마나 소모량에 해당하는 피해를 흡수하는 보호막을 씌웁니다. (재사용 대기시간 120초)&lt;/span&gt;&lt;br&gt;&lt;span&gt;가격:&lt;/span&gt; &lt;span style='color: #ffc659'&gt;3200 (3200)&lt;/span&gt;"/>
#  </div>
#  <div class="Item">
#  <img alt="망원형 개조" class="Image tip" src="//opgg-static.akamaized.net/images/lol/item/3363.png?image=w_22&amp;v=15367644000" title="&lt;b style='color: #00cfbc'&gt;망원형 개조&lt;/b&gt;&lt;br&gt;&lt;span&gt;설치 범위가 증가하며 대상 지역을 드러내 줍니다.&lt;/span&gt;&lt;br&gt;&lt;span&gt;&lt;levelLimit&gt;업그레이드하려면 9레벨 이상이 되어야 합니다.&lt;/levelLimit&gt;&lt;br&gt;&lt;groupLimit&gt;장신구 소지 개수는 1개로 제한됩니다.&lt;/groupLimit&gt;&lt;br&gt;&lt;br&gt;&lt;font color='#FFFFFF'&gt;와드 토템&lt;/font&gt; 장신구 업그레이드 시:&lt;br&gt;&lt;br&gt;&lt;stats&gt;&lt;font color='#00FF00'&gt;+&lt;/font&gt; 설치 가능 범위 대폭(+650%) 증가&lt;br&gt;&lt;font color='#00FF00'&gt;+&lt;/font&gt; 지속 시간 제한 없음, 와드 설치 개수 제한에 관계 없음&lt;br&gt;&lt;font color='#FF0000'&gt;-&lt;/font&gt; &lt;font color='#FF6600'&gt;재사용 대기시간 10% 증가&lt;/font&gt;&lt;br&gt;&lt;font color='#FF0000'&gt;-&lt;/font&gt; &lt;font color='#FF6600'&gt;누구나 볼 수 있는 와드로, 파괴 가능하고 아군의 대상으로 지정 불가&lt;/font&gt;&lt;br&gt;&lt;font color='#FF0000'&gt;-&lt;/font&gt; &lt;font color='#FF6600'&gt;와드 시야 범위 45% 감소&lt;/font&gt;&lt;br&gt;&lt;font color='#FF0000'&gt;-&lt;/font&gt; &lt;font color='#FF6600'&gt;상점 방문 시 충전되지 않음&lt;/font&gt;&lt;/stats&gt;&lt;/span&gt;"/>
#  </div>
#  <div class="Item">
#  <img alt="암흑의 인장" class="Image tip" src="//opgg-static.akamaized.net/images/lol/item/1082.png?image=w_22&amp;v=15367644000" title="&lt;b style='color: #00cfbc'&gt;암흑의 인장&lt;/b&gt;&lt;br&gt;&lt;span&gt;주문력과 마나가 상승하며 적을 처치할 때마다 더욱 강력해집니다.&lt;/span&gt;&lt;br&gt;&lt;span&gt;&lt;stats&gt;주문력 +15&lt;br&gt;물약 회복량 증가 +25%&lt;br&gt;&lt;mana&gt;마나 +100&lt;/mana&gt;&lt;/stats&gt;&lt;br&gt;&lt;br&gt;&lt;unique&gt;고유 지속 효과 - 두려움:&lt;/unique&gt; 영광 중첩 하나 당 주문력이 3만큼 상승합니다. &lt;br&gt;&lt;unique&gt;고유 지속 효과 - 절체절명:&lt;/unique&gt; 적 챔피언을 처치할 때마다 영광 중첩 2회, 어시스트를 올릴 때마다 영광 중첩 1회가 쌓이고 중첩은 최대 10회까지 쌓을 수 있습니다. 사망 시 중첩 4회가 사라집니다.&lt;/span&gt;&lt;br&gt;&lt;span&gt;가격:&lt;/span&gt; &lt;span style='color: #ffc659'&gt;350 (350)&lt;/span&gt;"/>
#  </div>
#  <div class="Item">
#  <div class="Image NoItem"></div>
#  </div>
#  <div class="Item">
#  <img alt="라일라이의 수정홀" class="Image tip" src="//opgg-static.akamaized.net/images/lol/item/3116.png?image=w_22&amp;v=15367644000" title="&lt;b style='color: #00cfbc'&gt;라일라이의 수정홀&lt;/b&gt;&lt;br&gt;&lt;span&gt;스킬 및 마법 피해를 입히면 적이 둔화에 걸립니다.&lt;/span&gt;&lt;br&gt;&lt;span&gt;&lt;stats&gt;체력 +300&lt;br&gt;주문력 +90&lt;/stats&gt;&lt;br&gt;&lt;br&gt;&lt;unique&gt;고유 지속 효과:&lt;/unique&gt; 스킬 또는 마법 피해를 입히면 1초 동안 적의 이동 속도가 20% 감소합니다.&lt;/span&gt;&lt;br&gt;&lt;span&gt;가격:&lt;/span&gt; &lt;span style='color: #ffc659'&gt;2600 (915)&lt;/span&gt;"/>
#  </div>
#  <button class="Button OpenBuildButton tip" title="빌드" type="button">
#  <img class="On" src="//opgg-static.akamaized.net/css3/sprite/images/icon-buildblue-p.png"/>
#  <img class="Off" src="//opgg-static.akamaized.net/css3/sprite/images/icon-buildblue-p.png"/>
#  </button>
#  </div>
#  <div class="Trinket">
#  <img src="//opgg-static.akamaized.net/images/site/summoner/icon-ward-blue.png"/>
#  												제어 와드 <span class="wards vision">2</span></div>
#  </div>
#  <div class="FollowPlayers Names">
#  <div class="Team">
#  <div class="Summoner ">
#  <div class="ChampionImage">
#  <div class="Image16 __sprite __spc16 __spc16-28 tip" title="피오라">피오라</div>
#  <div class="Image20 __sprite __spc20 __spc20-28 tip" title="피오라">피오라</div>
#  </div>
#  <div class="SummonerName">
#  <a class="Link" href="//www.op.gg/summoner/userName=%ED%91%B8%EB%A5%B8%EC%B2%AD%EB%A3%A1" target="_blank">푸른청룡</a>
#  </div>
#  </div>
#  <div class="Summoner ">
#  <div class="ChampionImage">
#  <div class="Image16 __sprite __spc16 __spc16-134 tip" title="신 짜오">신 짜오</div>
#  <div class="Image20 __sprite __spc20 __spc20-134 tip" title="신 짜오">신 짜오</div>
#  </div>
#  <div class="SummonerName">
#  <a class="Link" href="//www.op.gg/summoner/userName=%EC%B2%AD%EC%A3%BC%EB%8F%84%ED%86%A0%EB%A6%AC" target="_blank">청주도토리</a>
#  </div>
#  </div>
#  <div class="Summoner ">
#  <div class="ChampionImage">
#  <div class="Image16 __sprite __spc16 __spc16-2 tip" title="아칼리">아칼리</div>
#  <div class="Image20 __sprite __spc20 __spc20-2 tip" title="아칼리">아칼리</div>
#  </div>
#  <div class="SummonerName">
#  <a class="Link" href="//www.op.gg/summoner/userName=%EC%A0%95%EC%9D%B8%EB%AC%B5" target="_blank">정 인 묵</a>
#  </div>
#  </div>
#  <div class="Summoner ">
#  <div class="ChampionImage">
#  <div class="Image16 __sprite __spc16 __spc16-103 tip" title="시비르">시비르</div>
#  <div class="Image20 __sprite __spc20 __spc20-103 tip" title="시비르">시비르</div>
#  </div>
#  <div class="SummonerName">
#  <a class="Link" href="//www.op.gg/summoner/userName=bj%EA%B9%80%EC%9D%B8%ED%98%B8" target="_blank">BJ김인호</a>
#  </div>
#  </div>
#  <div class="Summoner ">
#  <div class="ChampionImage">
#  <div class="Image16 __sprite __spc16 __spc16-41 tip" title="잔나">잔나</div>
#  <div class="Image20 __sprite __spc20 __spc20-41 tip" title="잔나">잔나</div>
#  </div>
#  <div class="SummonerName">
#  <a class="Link" href="//www.op.gg/summoner/userName=%ED%83%80%EC%9D%BC%EB%B3%B4%EC%88%98" target="_blank">타일보수</a>
#  </div>
#  </div>
#  </div>
#  <div class="Team">
#  <div class="Summoner ">
#  <div class="ChampionImage">
#  <div class="Image16 __sprite __spc16 __spc16-97 tip" title="세주아니">세주아니</div>
#  <div class="Image20 __sprite __spc20 __spc20-97 tip" title="세주아니">세주아니</div>
#  </div>
#  <div class="SummonerName">
#  <a class="Link" href="//www.op.gg/summoner/userName=%EC%8B%A0%EC%84%A0%ED%95%9C%EB%8F%84%EB%9D%BC%EC%A7%80%EB%B0%B0%EC%A6%99" target="_blank">신선한도라지배즙</a>
#  </div>
#  </div>
#  <div class="Summoner ">
#  <div class="ChampionImage">
#  <div class="Image16 __sprite __spc16 __spc16-130 tip" title="볼리베어">볼리베어</div>
#  <div class="Image20 __sprite __spc20 __spc20-130 tip" title="볼리베어">볼리베어</div>
#  </div>
#  <div class="SummonerName">
#  <a class="Link" href="//www.op.gg/summoner/userName=%EC%A7%B1%EC%A7%B1%EC%A0%95%ED%99%98123" target="_blank">짱짱정환123</a>
#  </div>
#  </div>
#  <div class="Summoner Requester">
#  <div class="ChampionImage">
#  <div class="Image16 __sprite __spc16 __spc16-16 tip" title="카시오페아">카시오페아</div>
#  <div class="Image20 __sprite __spc20 __spc20-16 tip" title="카시오페아">카시오페아</div>
#  </div>
#  <div class="SummonerName">
#  <a class="Link" href="//www.op.gg/summoner/userName=%ED%99%A9%ED%86%A0%EB%A7%A4%ED%8A%B8" target="_blank">황토매트</a>
#  </div>
#  </div>
#  <div class="Summoner ">
#  <div class="ChampionImage">
#  <div class="Image16 __sprite __spc16 __spc16-26 tip" title="이즈리얼">이즈리얼</div>
#  <div class="Image20 __sprite __spc20 __spc20-26 tip" title="이즈리얼">이즈리얼</div>
#  </div>
#  <div class="SummonerName">
#  <a class="Link" href="//www.op.gg/summoner/userName=%ED%95%A9%EC%9D%B4%EC%9C%A1%EC%B2%9C%EC%9B%90" target="_blank">합이육천원</a>
#  </div>
#  </div>
#  <div class="Summoner ">
#  <div class="ChampionImage">
#  <div class="Image16 __sprite __spc16 __spc16-87 tip" title="파이크">파이크</div>
#  <div class="Image20 __sprite __spc20 __spc20-87 tip" title="파이크">파이크</div>
#  </div>
#  <div class="SummonerName">
#  <a class="Link" href="//www.op.gg/summoner/userName=kilersong" target="_blank">kilersong</a>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="StatsButton">
#  <div class="Content">
#  <div class="Item">
#  <a class="Button MatchDetail" href="javascript:;">
#  <span class="__spSite __spSite-194 Off"></span>
#  <span class="__spSite __spSite-193 On"></span>
#  </a>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="GameDetail"></div>
#  </div>
#  </div>, <div class="GameItemWrap">
#  <div class="GameItem Win " data-game-id="3528480173" data-game-result="win" data-game-time="1549296595" data-summoner-id="1221663">
#  <div class="Content">
#  <div class="GameStats">
#  <div class="GameType">
#  					솔랭
#  				</div>
#  <div class="TimeStamp"><span class="_timeago _timeCountAssigned tip" data-datetime="1549296595" data-interval="60" data-type="" title="2019년 2월 5일 오전 1시 10분">한시간 전</span></div>
#  <div class="Bar"></div>
#  <div class="GameResult">
#  											승리									</div>
#  <div class="GameLength">20분 13초</div>
#  </div>
#  <div class="GameSettingInfo">
#  <div class="ChampionImage">
#  <a href="/champion/cassiopeia/statistics" target="_blank"><img alt="카시오페아" class="Image" src="//opgg-static.akamaized.net/images/lol/champion/Cassiopeia.png?image=w_46&amp;v=15354684000"/></a>
#  </div>
#  <div class="SummonerSpell">
#  <div class="Spell">
#  <img alt="정화" class="Image tip" src="//opgg-static.akamaized.net/images/lol/spell/SummonerBoost.png?image=w_22&amp;v=15354684000" title="&lt;b style='color: #ffc659'&gt;정화&lt;/b&gt;&lt;br&gt;&lt;span&gt;챔피언에 걸린 모든 이동 불가와 (제압 및 공중으로 띄우는 효과 제외) 소환사 주문에 의한 해로운 효과를 제거하고 새로 적용되는 이동 불가 효과들의 지속 시간을 3초간 65% 감소시킵니다.&lt;/span&gt;"/>
#  </div>
#  <div class="Spell">
#  <img alt="점멸" class="Image tip" src="//opgg-static.akamaized.net/images/lol/spell/SummonerFlash.png?image=w_22&amp;v=15354684000" title="&lt;b style='color: #ffc659'&gt;점멸&lt;/b&gt;&lt;br&gt;&lt;span&gt;커서 방향으로 챔피언이 짧은 거리를 순간이동합니다.&lt;/span&gt;"/>
#  </div>
#  </div>
#  <div class="Runes">
#  <div class="Rune">
#  <img alt="신비로운 유성" class="Image tip" src="//opgg-static.akamaized.net/images/lol/perk/8229.png?image=w_22&amp;v=1" title="&lt;b style='color: #ffc659'&gt;신비로운 유성&lt;/b&gt;&lt;br&gt;&lt;span&gt;챔피언에게 스킬로 피해를 주면 해당 위치에 유성을 불러옵니다. 신비로운 유성이 재사용 대기 중일 경우 남은 재사용 대기시간이 감소합니다.&lt;br&gt;&lt;br&gt;&lt;lol-uikit-tooltipped-keyword key='LinkTooltip_Description_AdaptiveDmg'&gt;&lt;font color='#48C4B7'&gt;적응형 피해&lt;/font&gt;&lt;/lol-uikit-tooltipped-keyword&gt;: 레벨에 따라 30 ~ 100 (&lt;scaleAP&gt;+주문력의 0.2&lt;/scaleAP&gt; 및 &lt;scaleAD&gt;+추가 공격력의 0.35&lt;/scaleAD&gt;)&lt;br&gt;재사용 대기시간: 20 ~ 8초&lt;br&gt;&lt;rules&gt;&lt;br&gt;재사용 대기시간 감소:&lt;br&gt;단일 대상 스킬: 20%&lt;br&gt;광역 스킬: 10%&lt;br&gt;지속 피해 스킬: 5%&lt;br&gt;&lt;/rules&gt;&lt;/span&gt;"/>
#  </div>
#  <div class="Rune">
#  <img alt="지배" class="Image tip" src="//opgg-static.akamaized.net/images/lol/perkStyle/8100.png?image=w_22&amp;v=2" title="&lt;b style='color: #ffc659'&gt;지배&lt;/b&gt;&lt;br&gt;&lt;span&gt;강력한 피해와 빠른 접근&lt;/span&gt;"/>
#  </div>
#  </div>
#  <div class="ChampionName">
#  <a href="/champion/cassiopeia/statistics" target="_blank">카시오페아</a>
#  </div>
#  </div>
#  <div class="KDA">
#  <div class="KDA">
#  <span class="Kill">6</span> /
#  					<span class="Death">0</span> /
#  					<span class="Assist">4</span>
#  </div>
#  <div class="KDARatio">
#  <span class="KDARatio perfect">Perfect</span> 평점				</div>
#  <div class="Badge"><span class="Text MVP">MVP</span></div>
#  </div>
#  <div class="Stats">
#  <div class="Level">
#  					레벨13
#  				</div>
#  <div class="CS">
#  <span class="CS tip" title="미니언 146  + 몬스터 25&lt;br&gt;분당CS 8.5개">171 (8.5)</span> CS
#  				</div>
#  <div class="CKRate tip" title="킬관여율">
#  						킬관여 56%
#  					</div>
#  <div class="MMR">매치 평균 <b>Bronze 2</b></div>
#  </div>
#  <div class="Items">
#  <div class="ItemList">
#  <div class="Item">
#  <img alt="리안드리의 고통" class="Image tip" src="//opgg-static.akamaized.net/images/lol/item/3151.png?image=w_22&amp;v=15367644000" title="&lt;b style='color: #00cfbc'&gt;리안드리의 고통&lt;/b&gt;&lt;br&gt;&lt;span&gt;스킬 공격으로 피해를 입히면 적이 불에 타서 체력의 일정 비율을 잃습니다.&lt;/span&gt;&lt;br&gt;&lt;span&gt;&lt;stats&gt;주문력 +75&lt;br&gt;체력 +300&lt;/stats&gt;&lt;br&gt;&lt;br&gt;&lt;unique&gt;고유 지속 효과 - 광기:&lt;/unique&gt; 적 챔피언과 전투 시 매초 2%의 추가 피해를 입힙니다. (최대 10%)&lt;br&gt;&lt;unique&gt;고유 지속 효과 - 고통:&lt;/unique&gt; 스킬 공격에 맞은 적에게 3초에 걸쳐 매초 대상의 최대 체력의 1.5%에 해당하는 초당 추가 마법 피해를 입힙니다. 이 추가 피해량은 &lt;a href=&quot;#&quot;&gt;이동 방해&lt;/a&gt;에 걸린 유닛에게는 2.5%로 증가됩니다.&lt;/span&gt;&lt;br&gt;&lt;span&gt;가격:&lt;/span&gt; &lt;span style='color: #ffc659'&gt;3100 (750)&lt;/span&gt;"/>
#  </div>
#  <div class="Item">
#  <img alt="충전형 물약" class="Image tip" src="//opgg-static.akamaized.net/images/lol/item/2031.png?image=w_22&amp;v=15367644000" title="&lt;b style='color: #00cfbc'&gt;충전형 물약&lt;/b&gt;&lt;br&gt;&lt;span&gt;일정 시간 동안 체력이 회복되며, 상점에 가면 다시 충전됩니다.&lt;/span&gt;&lt;br&gt;&lt;span&gt;&lt;groupLimit&gt;한 번에 한 종류의 회복 물약만 소지할 수 있습니다.&lt;/groupLimit&gt;&lt;br&gt;&lt;br&gt;&lt;active&gt;고유 사용 효과:&lt;/active&gt; 충전량을 1회 소모해 12초 동안 125의 체력을 회복합니다. 상점 방문 시 2회의 충전량이 다시 채워집니다.&lt;/span&gt;&lt;br&gt;&lt;span&gt;가격:&lt;/span&gt; &lt;span style='color: #ffc659'&gt;150 (150)&lt;/span&gt;"/>
#  </div>
#  <div class="Item">
#  <img alt="대천사의 포옹" class="Image tip" src="//opgg-static.akamaized.net/images/lol/item/3040.png?image=w_22&amp;v=15367644000" title="&lt;b style='color: #00cfbc'&gt;대천사의 포옹&lt;/b&gt;&lt;br&gt;&lt;span&gt;&lt;stats&gt;주문력 +50&lt;br&gt;&lt;mana&gt;마나 +1400&lt;/mana&gt;&lt;br&gt;재사용 대기시간 감소 +10%&lt;/stats&gt;&lt;br&gt;&lt;br&gt;&lt;unique&gt;고유 지속 효과 - 가속:&lt;/unique&gt; 재사용 대기시간이 추가로 10% 감소합니다.&lt;br&gt;&lt;mana&gt;&lt;unique&gt;고유 지속 효과 - 경탄:&lt;/unique&gt; 최대 마나의 3%만큼 주문력이 오릅니다. 마나를 소모하면 소모량의 25%를 돌려받습니다.&lt;/mana&gt;&lt;br&gt;&lt;active&gt;고유 사용 효과 - 마나 보호막:&lt;/active&gt; 현재 마나의 15%를 소모하여 2초 동안 150 + 마나 소모량에 해당하는 피해를 흡수하는 보호막을 씌웁니다. (재사용 대기시간 120초)&lt;/span&gt;&lt;br&gt;&lt;span&gt;가격:&lt;/span&gt; &lt;span style='color: #ffc659'&gt;3200 (3200)&lt;/span&gt;"/>
#  </div>
#  <div class="Item">
#  <img alt="와드 토템 (장신구)" class="Image tip" src="//opgg-static.akamaized.net/images/lol/item/3340.png?image=w_22&amp;v=15367644000" title="&lt;b style='color: #00cfbc'&gt;와드 토템 (장신구)&lt;/b&gt;&lt;br&gt;&lt;span&gt;주기적으로 투명 와드를 설치합니다.&lt;/span&gt;&lt;br&gt;&lt;span&gt;&lt;groupLimit&gt;장신구 소지 개수는 1개로 제한됩니다.&lt;/groupLimit&gt;&lt;br&gt;&lt;br&gt;&lt;active&gt;사용 시:&lt;/active&gt; 충전량을 1회 소모하여 &lt;scaleLevel&gt;90 ~ 120&lt;/scaleLevel&gt;초 동안 주변을 드러내 주는 보이지 않는 &lt;font color='#BBFFFF'&gt;투명 와드&lt;/font&gt;를 설치합니다. &lt;br&gt;&lt;br&gt;매 &lt;scaleLevel&gt;240 ~ 120&lt;/scaleLevel&gt;초마다 1회 충전되며 최대 2회까지 충전됩니다.&lt;br&gt;&lt;br&gt;와드 지속 시간과 충전 주기는 레벨이 오를수록 향상됩니다.&lt;br&gt;&lt;br&gt;&lt;rules&gt;(플레이어당 맵에 설치할 수 있는 &lt;font color='#BBFFFF'&gt;투명 와드&lt;/font&gt;는 3개로 제한됩니다.)&lt;/rules&gt;&lt;/span&gt;"/>
#  </div>
#  <div class="Item">
#  <img alt="암흑의 인장" class="Image tip" src="//opgg-static.akamaized.net/images/lol/item/1082.png?image=w_22&amp;v=15367644000" title="&lt;b style='color: #00cfbc'&gt;암흑의 인장&lt;/b&gt;&lt;br&gt;&lt;span&gt;주문력과 마나가 상승하며 적을 처치할 때마다 더욱 강력해집니다.&lt;/span&gt;&lt;br&gt;&lt;span&gt;&lt;stats&gt;주문력 +15&lt;br&gt;물약 회복량 증가 +25%&lt;br&gt;&lt;mana&gt;마나 +100&lt;/mana&gt;&lt;/stats&gt;&lt;br&gt;&lt;br&gt;&lt;unique&gt;고유 지속 효과 - 두려움:&lt;/unique&gt; 영광 중첩 하나 당 주문력이 3만큼 상승합니다. &lt;br&gt;&lt;unique&gt;고유 지속 효과 - 절체절명:&lt;/unique&gt; 적 챔피언을 처치할 때마다 영광 중첩 2회, 어시스트를 올릴 때마다 영광 중첩 1회가 쌓이고 중첩은 최대 10회까지 쌓을 수 있습니다. 사망 시 중첩 4회가 사라집니다.&lt;/span&gt;&lt;br&gt;&lt;span&gt;가격:&lt;/span&gt; &lt;span style='color: #ffc659'&gt;350 (350)&lt;/span&gt;"/>
#  </div>
#  <div class="Item">
#  <div class="Image NoItem"></div>
#  </div>
#  <div class="Item">
#  <div class="Image NoItem"></div>
#  </div>
#  <button class="Button OpenBuildButton tip" title="빌드" type="button">
#  <img class="On" src="//opgg-static.akamaized.net/css3/sprite/images/icon-buildblue-p.png"/>
#  <img class="Off" src="//opgg-static.akamaized.net/css3/sprite/images/icon-buildblue-p.png"/>
#  </button>
#  </div>
#  <div class="Trinket">
#  <img src="//opgg-static.akamaized.net/images/site/summoner/icon-ward-blue.png"/>
#  												제어 와드 <span class="wards vision">2</span></div>
#  </div>
#  <div class="FollowPlayers Names">
#  <div class="Team">
#  <div class="Summoner ">
#  <div class="ChampionImage">
#  <div class="Image16 __sprite __spc16 __spc16-55 tip" title="케넨">케넨</div>
#  <div class="Image20 __sprite __spc20 __spc20-55 tip" title="케넨">케넨</div>
#  </div>
#  <div class="SummonerName">
#  <a class="Link" href="//www.op.gg/summoner/userName=%EC%96%B4%EB%A0%A4%EC%9B%8C22" target="_blank">어려워22</a>
#  </div>
#  </div>
#  <div class="Summoner ">
#  <div class="ChampionImage">
#  <div class="Image16 __sprite __spc16 __spc16-130 tip" title="볼리베어">볼리베어</div>
#  <div class="Image20 __sprite __spc20 __spc20-130 tip" title="볼리베어">볼리베어</div>
#  </div>
#  <div class="SummonerName">
#  <a class="Link" href="//www.op.gg/summoner/userName=%EC%A7%B1%EC%A7%B1%EC%A0%95%ED%99%98123" target="_blank">짱짱정환123</a>
#  </div>
#  </div>
#  <div class="Summoner Requester">
#  <div class="ChampionImage">
#  <div class="Image16 __sprite __spc16 __spc16-16 tip" title="카시오페아">카시오페아</div>
#  <div class="Image20 __sprite __spc20 __spc20-16 tip" title="카시오페아">카시오페아</div>
#  </div>
#  <div class="SummonerName">
#  <a class="Link" href="//www.op.gg/summoner/userName=%ED%99%A9%ED%86%A0%EB%A7%A4%ED%8A%B8" target="_blank">황토매트</a>
#  </div>
#  </div>
#  <div class="Summoner ">
#  <div class="ChampionImage">
#  <div class="Image16 __sprite __spc16 __spc16-124 tip" title="베인">베인</div>
#  <div class="Image20 __sprite __spc20 __spc20-124 tip" title="베인">베인</div>
#  </div>
#  <div class="SummonerName">
#  <a class="Link" href="//www.op.gg/summoner/userName=%EC%8A%88%ED%8D%BC%EB%A9%94%EC%B9%B4" target="_blank">슈퍼메카</a>
#  </div>
#  </div>
#  <div class="Summoner ">
#  <div class="ChampionImage">
#  <div class="Image16 __sprite __spc16 __spc16-87 tip" title="파이크">파이크</div>
#  <div class="Image20 __sprite __spc20 __spc20-87 tip" title="파이크">파이크</div>
#  </div>
#  <div class="SummonerName">
#  <a class="Link" href="//www.op.gg/summoner/userName=4%EA%B7%B8%EB%9E%A9" target="_blank">4 그랩</a>
#  </div>
#  </div>
#  </div>
#  <div class="Team">
#  <div class="Summoner ">
#  <div class="ChampionImage">
#  <div class="Image16 __sprite __spc16 __spc16-128 tip" title="빅토르">빅토르</div>
#  <div class="Image20 __sprite __spc20 __spc20-128 tip" title="빅토르">빅토르</div>
#  </div>
#  <div class="SummonerName">
#  <a class="Link" href="//www.op.gg/summoner/userName=%EB%9C%A8%EA%B1%B0%EC%9A%B4%EA%B5%B0%EB%A7%8C%EB%91%90" target="_blank">뜨거운군만두</a>
#  </div>
#  </div>
#  <div class="Summoner ">
#  <div class="ChampionImage">
#  <div class="Image16 __sprite __spc16 __spc16-72 tip" title="오공">오공</div>
#  <div class="Image20 __sprite __spc20 __spc20-72 tip" title="오공">오공</div>
#  </div>
#  <div class="SummonerName">
#  <a class="Link" href="//www.op.gg/summoner/userName=%EB%82%A8%EC%9E%90%ED%83%91%EC%86%94" target="_blank">남자탑솔</a>
#  </div>
#  </div>
#  <div class="Summoner ">
#  <div class="ChampionImage">
#  <div class="Image16 __sprite __spc16 __spc16-133 tip" title="제라스">제라스</div>
#  <div class="Image20 __sprite __spc20 __spc20-133 tip" title="제라스">제라스</div>
#  </div>
#  <div class="SummonerName">
#  <a class="Link" href="//www.op.gg/summoner/userName=%EB%8C%80%EC%97%AC%EC%9A%A9%EC%95%84%EC%9D%B4%EB%94%94" target="_blank">대여용 아이디</a>
#  </div>
#  </div>
#  <div class="Summoner ">
#  <div class="ChampionImage">
#  <div class="Image16 __sprite __spc16 __spc16-26 tip" title="이즈리얼">이즈리얼</div>
#  <div class="Image20 __sprite __spc20 __spc20-26 tip" title="이즈리얼">이즈리얼</div>
#  </div>
#  <div class="SummonerName">
#  <a class="Link" href="//www.op.gg/summoner/userName=%EC%A3%BD%EB%8A%94%EA%B1%B0%EC%98%88%EC%88%A0%EC%9E%847" target="_blank">죽는거예술임7</a>
#  </div>
#  </div>
#  <div class="Summoner ">
#  <div class="ChampionImage">
#  <div class="Image16 __sprite __spc16 __spc16-71 tip" title="미스 포츈">미스 포츈</div>
#  <div class="Image20 __sprite __spc20 __spc20-71 tip" title="미스 포츈">미스 포츈</div>
#  </div>
#  <div class="SummonerName">
#  <a class="Link" href="//www.op.gg/summoner/userName=%EB%82%A0%EB%9D%BC%EB%9E%84%EB%9D%BC" target="_blank">날라랄라</a>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="StatsButton">
#  <div class="Content">
#  <div class="Item">
#  <a class="Button MatchDetail" href="javascript:;">
#  <span class="__spSite __spSite-194 Off"></span>
#  <span class="__spSite __spSite-193 On"></span>
#  </a>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="GameDetail"></div>
#  </div>
#  </div>, <div class="GameItemWrap">
#  <div class="GameItem Lose " data-game-id="3528348333" data-game-result="lose" data-game-time="1549294916" data-summoner-id="1221663">
#  <div class="Content">
#  <div class="GameStats">
#  <div class="GameType">
#  					솔랭
#  				</div>
#  <div class="TimeStamp"><span class="_timeago _timeCountAssigned tip" data-datetime="1549294916" data-interval="60" data-type="" title="2019년 2월 5일 오전 12시 42분">한시간 전</span></div>
#  <div class="Bar"></div>
#  <div class="GameResult">
#  											패배									</div>
#  <div class="GameLength">35분 9초</div>
#  </div>
#  <div class="GameSettingInfo">
#  <div class="ChampionImage">
#  <a href="/champion/ryze/statistics" target="_blank"><img alt="라이즈" class="Image" src="//opgg-static.akamaized.net/images/lol/champion/Ryze.png?image=w_46&amp;v=15354684000"/></a>
#  </div>
#  <div class="SummonerSpell">
#  <div class="Spell">
#  <img alt="정화" class="Image tip" src="//opgg-static.akamaized.net/images/lol/spell/SummonerBoost.png?image=w_22&amp;v=15354684000" title="&lt;b style='color: #ffc659'&gt;정화&lt;/b&gt;&lt;br&gt;&lt;span&gt;챔피언에 걸린 모든 이동 불가와 (제압 및 공중으로 띄우는 효과 제외) 소환사 주문에 의한 해로운 효과를 제거하고 새로 적용되는 이동 불가 효과들의 지속 시간을 3초간 65% 감소시킵니다.&lt;/span&gt;"/>
#  </div>
#  <div class="Spell">
#  <img alt="점멸" class="Image tip" src="//opgg-static.akamaized.net/images/lol/spell/SummonerFlash.png?image=w_22&amp;v=15354684000" title="&lt;b style='color: #ffc659'&gt;점멸&lt;/b&gt;&lt;br&gt;&lt;span&gt;커서 방향으로 챔피언이 짧은 거리를 순간이동합니다.&lt;/span&gt;"/>
#  </div>
#  </div>
#  <div class="Runes">
#  <div class="Rune">
#  <img alt="난입" class="Image tip" src="//opgg-static.akamaized.net/images/lol/perk/8230.png?image=w_22&amp;v=1" title="&lt;b style='color: #ffc659'&gt;난입&lt;/b&gt;&lt;br&gt;&lt;span&gt;3초 안에 한 챔피언에게 기본 공격 3회 또는 &lt;b&gt;개별&lt;/b&gt; 스킬 3회를 적중시키면 레벨에 따라 25 ~ 40%의 이동 속도와 75%의 둔화 저항 효과를 얻습니다.&lt;br&gt;&lt;br&gt;지속시간: 3초&lt;br&gt;재사용 대기시간: 15초&lt;/span&gt;"/>
#  </div>
#  <div class="Rune">
#  <img alt="지배" class="Image tip" src="//opgg-static.akamaized.net/images/lol/perkStyle/8100.png?image=w_22&amp;v=2" title="&lt;b style='color: #ffc659'&gt;지배&lt;/b&gt;&lt;br&gt;&lt;span&gt;강력한 피해와 빠른 접근&lt;/span&gt;"/>
#  </div>
#  </div>
#  <div class="ChampionName">
#  <a href="/champion/ryze/statistics" target="_blank">라이즈</a>
#  </div>
#  </div>
#  <div class="KDA">
#  <div class="KDA">
#  <span class="Kill">13</span> /
#  					<span class="Death">3</span> /
#  					<span class="Assist">1</span>
#  </div>
#  <div class="KDARatio">
#  <span class="KDARatio ">4.67:1</span> 평점				</div>
#  <div class="MultiKill">
#  <span class="Kill">트리플킬</span>
#  </div>
#  <div class="Badge"><span class="Text ACE">ACE</span></div>
#  </div>
#  <div class="Stats">
#  <div class="Level">
#  					레벨18
#  				</div>
#  <div class="CS">
#  <span class="CS tip" title="미니언 254  + 몬스터 34&lt;br&gt;분당CS 8.2개">288 (8.2)</span> CS
#  				</div>
#  <div class="CKRate tip" title="킬관여율">
#  						킬관여 67%
#  					</div>
#  <div class="MMR">매치 평균 <b>Bronze 2</b></div>
#  </div>
#  <div class="Items">
#  <div class="ItemList">
#  <div class="Item">
#  <img alt="모렐로노미콘" class="Image tip" src="//opgg-static.akamaized.net/images/lol/item/3165.png?image=w_22&amp;v=15367644000" title="&lt;b style='color: #00cfbc'&gt;모렐로노미콘&lt;/b&gt;&lt;br&gt;&lt;span&gt;마법 피해량이 증가합니다.&lt;/span&gt;&lt;br&gt;&lt;span&gt;&lt;stats&gt;주문력 +70&lt;br&gt;체력 +300&lt;/stats&gt;&lt;br&gt;&lt;br&gt;&lt;unique&gt;고유 지속 효과- 죽음의 감촉:&lt;/unique&gt; &lt;a href=&quot;#&quot;&gt;마법 관통력&lt;/a&gt; +15&lt;br&gt;&lt;unique&gt;고유 지속 효과- 저주받은 일격:&lt;/unique&gt; 챔피언에게 마법 피해를 가하면 3초 동안 &lt;a href=&quot;#&quot;&gt;고통스러운 상처&lt;/a&gt; 효과를 적용합니다.&lt;/span&gt;&lt;br&gt;&lt;span&gt;가격:&lt;/span&gt; &lt;span style='color: #ffc659'&gt;3000 (550)&lt;/span&gt;"/>
#  </div>
#  <div class="Item">
#  <img alt="라바돈의 죽음모자" class="Image tip" src="//opgg-static.akamaized.net/images/lol/item/3089.png?image=w_22&amp;v=15367644000" title="&lt;b style='color: #00cfbc'&gt;라바돈의 죽음모자&lt;/b&gt;&lt;br&gt;&lt;span&gt;주문력이 대폭 상승합니다.&lt;/span&gt;&lt;br&gt;&lt;span&gt;&lt;stats&gt;주문력 +120  &lt;/stats&gt;&lt;br&gt;&lt;br&gt;&lt;unique&gt;고유 지속 효과:&lt;/unique&gt; 주문력이 40% 상승합니다.&lt;/span&gt;&lt;br&gt;&lt;span&gt;가격:&lt;/span&gt; &lt;span style='color: #ffc659'&gt;3600 (1100)&lt;/span&gt;"/>
#  </div>
#  <div class="Item">
#  <img alt="대천사의 포옹" class="Image tip" src="//opgg-static.akamaized.net/images/lol/item/3040.png?image=w_22&amp;v=15367644000" title="&lt;b style='color: #00cfbc'&gt;대천사의 포옹&lt;/b&gt;&lt;br&gt;&lt;span&gt;&lt;stats&gt;주문력 +50&lt;br&gt;&lt;mana&gt;마나 +1400&lt;/mana&gt;&lt;br&gt;재사용 대기시간 감소 +10%&lt;/stats&gt;&lt;br&gt;&lt;br&gt;&lt;unique&gt;고유 지속 효과 - 가속:&lt;/unique&gt; 재사용 대기시간이 추가로 10% 감소합니다.&lt;br&gt;&lt;mana&gt;&lt;unique&gt;고유 지속 효과 - 경탄:&lt;/unique&gt; 최대 마나의 3%만큼 주문력이 오릅니다. 마나를 소모하면 소모량의 25%를 돌려받습니다.&lt;/mana&gt;&lt;br&gt;&lt;active&gt;고유 사용 효과 - 마나 보호막:&lt;/active&gt; 현재 마나의 15%를 소모하여 2초 동안 150 + 마나 소모량에 해당하는 피해를 흡수하는 보호막을 씌웁니다. (재사용 대기시간 120초)&lt;/span&gt;&lt;br&gt;&lt;span&gt;가격:&lt;/span&gt; &lt;span style='color: #ffc659'&gt;3200 (3200)&lt;/span&gt;"/>
#  </div>
#  <div class="Item">
#  <img alt="망원형 개조" class="Image tip" src="//opgg-static.akamaized.net/images/lol/item/3363.png?image=w_22&amp;v=15367644000" title="&lt;b style='color: #00cfbc'&gt;망원형 개조&lt;/b&gt;&lt;br&gt;&lt;span&gt;설치 범위가 증가하며 대상 지역을 드러내 줍니다.&lt;/span&gt;&lt;br&gt;&lt;span&gt;&lt;levelLimit&gt;업그레이드하려면 9레벨 이상이 되어야 합니다.&lt;/levelLimit&gt;&lt;br&gt;&lt;groupLimit&gt;장신구 소지 개수는 1개로 제한됩니다.&lt;/groupLimit&gt;&lt;br&gt;&lt;br&gt;&lt;font color='#FFFFFF'&gt;와드 토템&lt;/font&gt; 장신구 업그레이드 시:&lt;br&gt;&lt;br&gt;&lt;stats&gt;&lt;font color='#00FF00'&gt;+&lt;/font&gt; 설치 가능 범위 대폭(+650%) 증가&lt;br&gt;&lt;font color='#00FF00'&gt;+&lt;/font&gt; 지속 시간 제한 없음, 와드 설치 개수 제한에 관계 없음&lt;br&gt;&lt;font color='#FF0000'&gt;-&lt;/font&gt; &lt;font color='#FF6600'&gt;재사용 대기시간 10% 증가&lt;/font&gt;&lt;br&gt;&lt;font color='#FF0000'&gt;-&lt;/font&gt; &lt;font color='#FF6600'&gt;누구나 볼 수 있는 와드로, 파괴 가능하고 아군의 대상으로 지정 불가&lt;/font&gt;&lt;br&gt;&lt;font color='#FF0000'&gt;-&lt;/font&gt; &lt;font color='#FF6600'&gt;와드 시야 범위 45% 감소&lt;/font&gt;&lt;br&gt;&lt;font color='#FF0000'&gt;-&lt;/font&gt; &lt;font color='#FF6600'&gt;상점 방문 시 충전되지 않음&lt;/font&gt;&lt;/stats&gt;&lt;/span&gt;"/>
#  </div>
#  <div class="Item">
#  <img alt="명석함의 아이오니아 장화" class="Image tip" src="//opgg-static.akamaized.net/images/lol/item/3158.png?image=w_22&amp;v=15367644000" title="&lt;b style='color: #00cfbc'&gt;명석함의 아이오니아 장화&lt;/b&gt;&lt;br&gt;&lt;span&gt;이동 속도와 재사용 대기시간 감소율이 증가합니다.&lt;/span&gt;&lt;br&gt;&lt;span&gt;&lt;groupLimit&gt;1개만 구입 가능합니다.&lt;/groupLimit&gt;&lt;br&gt;&lt;br&gt;&lt;unique&gt;고유 지속 효과:&lt;/unique&gt; 재사용 대기시간 감소 +10%&lt;br&gt;&lt;unique&gt;고유 지속 효과 - 이동 속도 향상:&lt;/unique&gt; 이동 속도 +45&lt;br&gt;&lt;unique&gt;고유 지속 효과:&lt;/unique&gt; 소환사 주문의 재사용 대기시간을 10%만큼 줄입니다.&lt;br&gt;&lt;br&gt;&lt;br&gt;&lt;rules&gt;&lt;font color='#FDD017'&gt;CLE 20년 12월 10일 남부 지방의 패권을 두고 벌어진 녹서스와의 재경합에서 아이오니아의 승리를 기념하는 헌정 아이템입니다.''&lt;/font&gt;&lt;/rules&gt;&lt;/span&gt;&lt;br&gt;&lt;span&gt;가격:&lt;/span&gt; &lt;span style='color: #ffc659'&gt;900 (600)&lt;/span&gt;"/>
#  </div>
#  <div class="Item">
#  <img alt="공허의 지팡이" class="Image tip" src="//opgg-static.akamaized.net/images/lol/item/3135.png?image=w_22&amp;v=15367644000" title="&lt;b style='color: #00cfbc'&gt;공허의 지팡이&lt;/b&gt;&lt;br&gt;&lt;span&gt;마법 피해량이 증가합니다.&lt;/span&gt;&lt;br&gt;&lt;span&gt;&lt;stats&gt;주문력 +70&lt;/stats&gt;&lt;br&gt;&lt;br&gt;&lt;unique&gt;고유 지속 효과 - 분해:&lt;/unique&gt; &lt;a href=&quot;#&quot;&gt;마법 관통력&lt;/a&gt; +40%&lt;/span&gt;&lt;br&gt;&lt;span&gt;가격:&lt;/span&gt; &lt;span style='color: #ffc659'&gt;2650 (1365)&lt;/span&gt;"/>
#  </div>
#  <div class="Item">
#  <img alt="암흑의 인장" class="Image tip" src="//opgg-static.akamaized.net/images/lol/item/1082.png?image=w_22&amp;v=15367644000" title="&lt;b style='color: #00cfbc'&gt;암흑의 인장&lt;/b&gt;&lt;br&gt;&lt;span&gt;주문력과 마나가 상승하며 적을 처치할 때마다 더욱 강력해집니다.&lt;/span&gt;&lt;br&gt;&lt;span&gt;&lt;stats&gt;주문력 +15&lt;br&gt;물약 회복량 증가 +25%&lt;br&gt;&lt;mana&gt;마나 +100&lt;/mana&gt;&lt;/stats&gt;&lt;br&gt;&lt;br&gt;&lt;unique&gt;고유 지속 효과 - 두려움:&lt;/unique&gt; 영광 중첩 하나 당 주문력이 3만큼 상승합니다. &lt;br&gt;&lt;unique&gt;고유 지속 효과 - 절체절명:&lt;/unique&gt; 적 챔피언을 처치할 때마다 영광 중첩 2회, 어시스트를 올릴 때마다 영광 중첩 1회가 쌓이고 중첩은 최대 10회까지 쌓을 수 있습니다. 사망 시 중첩 4회가 사라집니다.&lt;/span&gt;&lt;br&gt;&lt;span&gt;가격:&lt;/span&gt; &lt;span style='color: #ffc659'&gt;350 (350)&lt;/span&gt;"/>
#  </div>
#  <button class="Button OpenBuildButton tip" title="빌드" type="button">
#  <img class="On" src="//opgg-static.akamaized.net/css3/sprite/images/icon-buildred-p.png"/>
#  <img class="Off" src="//opgg-static.akamaized.net/css3/sprite/images/icon-buildred-p.png"/>
#  </button>
#  </div>
#  <div class="Trinket">
#  <img src="//opgg-static.akamaized.net/images/site/summoner/icon-ward-red.png"/>
#  												제어 와드 <span class="wards vision">2</span></div>
#  </div>
#  <div class="FollowPlayers Names">
#  <div class="Team">
#  <div class="Summoner ">
#  <div class="ChampionImage">
#  <div class="Image16 __sprite __spc16 __spc16-122 tip" title="우르곳">우르곳</div>
#  <div class="Image20 __sprite __spc20 __spc20-122 tip" title="우르곳">우르곳</div>
#  </div>
#  <div class="SummonerName">
#  <a class="Link" href="//www.op.gg/summoner/userName=%EB%80%A8%EB%80%A8%EC%8A%A4%ED%83%80" target="_blank">뀨뀨스타</a>
#  </div>
#  </div>
#  <div class="Summoner ">
#  <div class="ChampionImage">
#  <div class="Image16 __sprite __spc16 __spc16-130 tip" title="볼리베어">볼리베어</div>
#  <div class="Image20 __sprite __spc20 __spc20-130 tip" title="볼리베어">볼리베어</div>
#  </div>
#  <div class="SummonerName">
#  <a class="Link" href="//www.op.gg/summoner/userName=%EC%A7%B1%EC%A7%B1%EC%A0%95%ED%99%98123" target="_blank">짱짱정환123</a>
#  </div>
#  </div>
#  <div class="Summoner Requester">
#  <div class="ChampionImage">
#  <div class="Image16 __sprite __spc16 __spc16-96 tip" title="라이즈">라이즈</div>
#  <div class="Image20 __sprite __spc20 __spc20-96 tip" title="라이즈">라이즈</div>
#  </div>
#  <div class="SummonerName">
#  <a class="Link" href="//www.op.gg/summoner/userName=%ED%99%A9%ED%86%A0%EB%A7%A4%ED%8A%B8" target="_blank">황토매트</a>
#  </div>
#  </div>
#  <div class="Summoner ">
#  <div class="ChampionImage">
#  <div class="Image16 __sprite __spc16 __spc16-71 tip" title="미스 포츈">미스 포츈</div>
#  <div class="Image20 __sprite __spc20 __spc20-71 tip" title="미스 포츈">미스 포츈</div>
#  </div>
#  <div class="SummonerName">
#  <a class="Link" href="//www.op.gg/summoner/userName=%EA%B8%B0%EC%96%B5%ED%8C%8C%EA%B4%B4%EC%9E%90" target="_blank">기억파괴자</a>
#  </div>
#  </div>
#  <div class="Summoner ">
#  <div class="ChampionImage">
#  <div class="Image16 __sprite __spc16 __spc16-49 tip" title="카르마">카르마</div>
#  <div class="Image20 __sprite __spc20 __spc20-49 tip" title="카르마">카르마</div>
#  </div>
#  <div class="SummonerName">
#  <a class="Link" href="//www.op.gg/summoner/userName=%EA%B8%80%EC%8E%84%EB%AC%B4%EA%B1%B0%EB%82%98" target="_blank">글쎄 무거나</a>
#  </div>
#  </div>
#  </div>
#  <div class="Team">
#  <div class="Summoner ">
#  <div class="ChampionImage">
#  <div class="Image16 __sprite __spc16 __spc16-110 tip" title="탐 켄치">탐 켄치</div>
#  <div class="Image20 __sprite __spc20 __spc20-110 tip" title="탐 켄치">탐 켄치</div>
#  </div>
#  <div class="SummonerName">
#  <a class="Link" href="//www.op.gg/summoner/userName=7304" target="_blank">7304</a>
#  </div>
#  </div>
#  <div class="Summoner ">
#  <div class="ChampionImage">
#  <div class="Image16 __sprite __spc16 __spc16-114 tip" title="티모">티모</div>
#  <div class="Image20 __sprite __spc20 __spc20-114 tip" title="티모">티모</div>
#  </div>
#  <div class="SummonerName">
#  <a class="Link" href="//www.op.gg/summoner/userName=infocar" target="_blank">Infocar</a>
#  </div>
#  </div>
#  <div class="Summoner ">
#  <div class="ChampionImage">
#  <div class="Image16 __sprite __spc16 __spc16-125 tip" title="베이가">베이가</div>
#  <div class="Image20 __sprite __spc20 __spc20-125 tip" title="베이가">베이가</div>
#  </div>
#  <div class="SummonerName">
#  <a class="Link" href="//www.op.gg/summoner/userName=%EB%B8%8C%EB%9D%BC%EC%9D%B4%EC%96%B8%ED%8A%B8%ED%96%89" target="_blank">브라이언트행</a>
#  </div>
#  </div>
#  <div class="Summoner ">
#  <div class="ChampionImage">
#  <div class="Image16 __sprite __spc16 __spc16-26 tip" title="이즈리얼">이즈리얼</div>
#  <div class="Image20 __sprite __spc20 __spc20-26 tip" title="이즈리얼">이즈리얼</div>
#  </div>
#  <div class="SummonerName">
#  <a class="Link" href="//www.op.gg/summoner/userName=%EA%B9%8C%EA%BC%AC%EC%9D%B4" target="_blank">까꼬이</a>
#  </div>
#  </div>
#  <div class="Summoner ">
#  <div class="ChampionImage">
#  <div class="Image16 __sprite __spc16 __spc16-66 tip" title="럭스">럭스</div>
#  <div class="Image20 __sprite __spc20 __spc20-66 tip" title="럭스">럭스</div>
#  </div>
#  <div class="SummonerName">
#  <a class="Link" href="//www.op.gg/summoner/userName=re%EC%A4%91%EB%94%B1" target="_blank">re중딱</a>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="StatsButton">
#  <div class="Content">
#  <div class="Item">
#  <a class="Button MatchDetail" href="javascript:;">
#  <span class="__spSite __spSite-198 Off"></span>
#  <span class="__spSite __spSite-197 On"></span>
#  </a>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="GameDetail"></div>
#  </div>
#  </div>, <div class="GameItemWrap">
#  <div class="GameItem Win " data-game-id="3528195055" data-game-result="win" data-game-time="1549292306" data-summoner-id="1221663">
#  <div class="Content">
#  <div class="GameStats">
#  <div class="GameType">
#  					솔랭
#  				</div>
#  <div class="TimeStamp"><span class="_timeago _timeCountAssigned tip" data-datetime="1549292306" data-interval="60" data-type="" title="2019년 2월 4일 오후 11시 58분">2시간 전</span></div>
#  <div class="Bar"></div>
#  <div class="GameResult">
#  											승리									</div>
#  <div class="GameLength">35분 38초</div>
#  </div>
#  <div class="GameSettingInfo">
#  <div class="ChampionImage">
#  <a href="/champion/ryze/statistics" target="_blank"><img alt="라이즈" class="Image" src="//opgg-static.akamaized.net/images/lol/champion/Ryze.png?image=w_46&amp;v=15354684000"/></a>
#  </div>
#  <div class="SummonerSpell">
#  <div class="Spell">
#  <img alt="순간이동" class="Image tip" src="//opgg-static.akamaized.net/images/lol/spell/SummonerTeleport.png?image=w_22&amp;v=15354684000" title="&lt;b style='color: #ffc659'&gt;순간이동&lt;/b&gt;&lt;br&gt;&lt;span&gt;4초 동안 정신을 집중한 다음, 챔피언이 지정한 아군 구조물, 미니언, 혹은 와드로 순간이동합니다.&lt;/span&gt;"/>
#  </div>
#  <div class="Spell">
#  <img alt="점멸" class="Image tip" src="//opgg-static.akamaized.net/images/lol/spell/SummonerFlash.png?image=w_22&amp;v=15354684000" title="&lt;b style='color: #ffc659'&gt;점멸&lt;/b&gt;&lt;br&gt;&lt;span&gt;커서 방향으로 챔피언이 짧은 거리를 순간이동합니다.&lt;/span&gt;"/>
#  </div>
#  </div>
#  <div class="Runes">
#  <div class="Rune">
#  <img alt="난입" class="Image tip" src="//opgg-static.akamaized.net/images/lol/perk/8230.png?image=w_22&amp;v=1" title="&lt;b style='color: #ffc659'&gt;난입&lt;/b&gt;&lt;br&gt;&lt;span&gt;3초 안에 한 챔피언에게 기본 공격 3회 또는 &lt;b&gt;개별&lt;/b&gt; 스킬 3회를 적중시키면 레벨에 따라 25 ~ 40%의 이동 속도와 75%의 둔화 저항 효과를 얻습니다.&lt;br&gt;&lt;br&gt;지속시간: 3초&lt;br&gt;재사용 대기시간: 15초&lt;/span&gt;"/>
#  </div>
#  <div class="Rune">
#  <img alt="지배" class="Image tip" src="//opgg-static.akamaized.net/images/lol/perkStyle/8100.png?image=w_22&amp;v=2" title="&lt;b style='color: #ffc659'&gt;지배&lt;/b&gt;&lt;br&gt;&lt;span&gt;강력한 피해와 빠른 접근&lt;/span&gt;"/>
#  </div>
#  </div>
#  <div class="ChampionName">
#  <a href="/champion/ryze/statistics" target="_blank">라이즈</a>
#  </div>
#  </div>
#  <div class="KDA">
#  <div class="KDA">
#  <span class="Kill">22</span> /
#  					<span class="Death">6</span> /
#  					<span class="Assist">14</span>
#  </div>
#  <div class="KDARatio">
#  <span class="KDARatio ">6.00:1</span> 평점				</div>
#  <div class="MultiKill">
#  <span class="Kill">쿼드라킬</span>
#  </div>
#  </div>
#  <div class="Stats">
#  <div class="Level">
#  					레벨18
#  				</div>
#  <div class="CS">
#  <span class="CS tip" title="미니언 188  + 몬스터 48&lt;br&gt;분당CS 6.6개">236 (6.6)</span> CS
#  				</div>
#  <div class="CKRate tip" title="킬관여율">
#  						킬관여 73%
#  					</div>
#  <div class="MMR">매치 평균 <b>Bronze 3</b></div>
#  </div>
#  <div class="Items">
#  <div class="ItemList">
#  <div class="Item">
#  <img alt="존야의 모래시계" class="Image tip" src="//opgg-static.akamaized.net/images/lol/item/3157.png?image=w_22&amp;v=15367644000" title="&lt;b style='color: #00cfbc'&gt;존야의 모래시계&lt;/b&gt;&lt;br&gt;&lt;span&gt;사용하면 아무런 행동도 취할 수 없는 대신 공격도 받지 않는 무적 상태가 됩니다.&lt;/span&gt;&lt;br&gt;&lt;span&gt;&lt;stats&gt;주문력 +75&lt;br&gt;방어력 +45&lt;br&gt;재사용 대기시간 감소 +10%&lt;/stats&gt;&lt;br&gt;&lt;br&gt;&lt;active&gt;고유 사용 효과 - 경직:&lt;/active&gt; 챔피언이 2.5초 동안 아무런 행동도 취할 수 없는 대신 공격도 받지 않는 무적 상태가 됩니다. (재사용 대기시간 120초)&lt;/span&gt;&lt;br&gt;&lt;span&gt;가격:&lt;/span&gt; &lt;span style='color: #ffc659'&gt;2900 (300)&lt;/span&gt;"/>
#  </div>
#  <div class="Item">
#  <img alt="라바돈의 죽음모자" class="Image tip" src="//opgg-static.akamaized.net/images/lol/item/3089.png?image=w_22&amp;v=15367644000" title="&lt;b style='color: #00cfbc'&gt;라바돈의 죽음모자&lt;/b&gt;&lt;br&gt;&lt;span&gt;주문력이 대폭 상승합니다.&lt;/span&gt;&lt;br&gt;&lt;span&gt;&lt;stats&gt;주문력 +120  &lt;/stats&gt;&lt;br&gt;&lt;br&gt;&lt;unique&gt;고유 지속 효과:&lt;/unique&gt; 주문력이 40% 상승합니다.&lt;/span&gt;&lt;br&gt;&lt;span&gt;가격:&lt;/span&gt; &lt;span style='color: #ffc659'&gt;3600 (1100)&lt;/span&gt;"/>
#  </div>
#  <div class="Item">
#  <img alt="대천사의 포옹" class="Image tip" src="//opgg-static.akamaized.net/images/lol/item/3040.png?image=w_22&amp;v=15367644000" title="&lt;b style='color: #00cfbc'&gt;대천사의 포옹&lt;/b&gt;&lt;br&gt;&lt;span&gt;&lt;stats&gt;주문력 +50&lt;br&gt;&lt;mana&gt;마나 +1400&lt;/mana&gt;&lt;br&gt;재사용 대기시간 감소 +10%&lt;/stats&gt;&lt;br&gt;&lt;br&gt;&lt;unique&gt;고유 지속 효과 - 가속:&lt;/unique&gt; 재사용 대기시간이 추가로 10% 감소합니다.&lt;br&gt;&lt;mana&gt;&lt;unique&gt;고유 지속 효과 - 경탄:&lt;/unique&gt; 최대 마나의 3%만큼 주문력이 오릅니다. 마나를 소모하면 소모량의 25%를 돌려받습니다.&lt;/mana&gt;&lt;br&gt;&lt;active&gt;고유 사용 효과 - 마나 보호막:&lt;/active&gt; 현재 마나의 15%를 소모하여 2초 동안 150 + 마나 소모량에 해당하는 피해를 흡수하는 보호막을 씌웁니다. (재사용 대기시간 120초)&lt;/span&gt;&lt;br&gt;&lt;span&gt;가격:&lt;/span&gt; &lt;span style='color: #ffc659'&gt;3200 (3200)&lt;/span&gt;"/>
#  </div>
#  <div class="Item">
#  <img alt="망원형 개조" class="Image tip" src="//opgg-static.akamaized.net/images/lol/item/3363.png?image=w_22&amp;v=15367644000" title="&lt;b style='color: #00cfbc'&gt;망원형 개조&lt;/b&gt;&lt;br&gt;&lt;span&gt;설치 범위가 증가하며 대상 지역을 드러내 줍니다.&lt;/span&gt;&lt;br&gt;&lt;span&gt;&lt;levelLimit&gt;업그레이드하려면 9레벨 이상이 되어야 합니다.&lt;/levelLimit&gt;&lt;br&gt;&lt;groupLimit&gt;장신구 소지 개수는 1개로 제한됩니다.&lt;/groupLimit&gt;&lt;br&gt;&lt;br&gt;&lt;font color='#FFFFFF'&gt;와드 토템&lt;/font&gt; 장신구 업그레이드 시:&lt;br&gt;&lt;br&gt;&lt;stats&gt;&lt;font color='#00FF00'&gt;+&lt;/font&gt; 설치 가능 범위 대폭(+650%) 증가&lt;br&gt;&lt;font color='#00FF00'&gt;+&lt;/font&gt; 지속 시간 제한 없음, 와드 설치 개수 제한에 관계 없음&lt;br&gt;&lt;font color='#FF0000'&gt;-&lt;/font&gt; &lt;font color='#FF6600'&gt;재사용 대기시간 10% 증가&lt;/font&gt;&lt;br&gt;&lt;font color='#FF0000'&gt;-&lt;/font&gt; &lt;font color='#FF6600'&gt;누구나 볼 수 있는 와드로, 파괴 가능하고 아군의 대상으로 지정 불가&lt;/font&gt;&lt;br&gt;&lt;font color='#FF0000'&gt;-&lt;/font&gt; &lt;font color='#FF6600'&gt;와드 시야 범위 45% 감소&lt;/font&gt;&lt;br&gt;&lt;font color='#FF0000'&gt;-&lt;/font&gt; &lt;font color='#FF6600'&gt;상점 방문 시 충전되지 않음&lt;/font&gt;&lt;/stats&gt;&lt;/span&gt;"/>
#  </div>
#  <div class="Item">
#  <img alt="메자이의 영혼약탈자" class="Image tip" src="//opgg-static.akamaized.net/images/lol/item/3041.png?image=w_22&amp;v=15367644000" title="&lt;b style='color: #00cfbc'&gt;메자이의 영혼약탈자&lt;/b&gt;&lt;br&gt;&lt;span&gt;챔피언을 처치하거나 어시스트를 올릴 경우, 주문력이 오릅니다.&lt;/span&gt;&lt;br&gt;&lt;span&gt;&lt;stats&gt;주문력 +20&lt;br&gt;&lt;mana&gt;마나 +200&lt;/mana&gt;&lt;/stats&gt;&lt;br&gt;&lt;br&gt;&lt;unique&gt;고유 지속 효과 - 두려움:&lt;/unique&gt; 영광 중첩 하나 당 주문력이 +5만큼 상승합니다. 10 중첩 이상일 때 이동 속도가 10% 상승합니다.&lt;br&gt;&lt;unique&gt;고유 지속 효과 - 절체절명:&lt;/unique&gt; 적 챔피언을 처치할 때마다 영광 중첩 4회, 어시스트를 올릴 때마다 영광 중첩 2회가 쌓이고 중첩은 최대 25회까지 쌓을 수 있습니다. 사망 시 중첩 10회가 사라집니다.&lt;/span&gt;&lt;br&gt;&lt;span&gt;가격:&lt;/span&gt; &lt;span style='color: #ffc659'&gt;1400 (1050)&lt;/span&gt;"/>
#  </div>
#  <div class="Item">
#  <img alt="마법사의 신발" class="Image tip" src="//opgg-static.akamaized.net/images/lol/item/3020.png?image=w_22&amp;v=15367644000" title="&lt;b style='color: #00cfbc'&gt;마법사의 신발&lt;/b&gt;&lt;br&gt;&lt;span&gt;이동 속도와 마법 피해량이 증가합니다.&lt;/span&gt;&lt;br&gt;&lt;span&gt;&lt;groupLimit&gt;1개만 구입 가능합니다.&lt;/groupLimit&gt;&lt;br&gt;&lt;br&gt;&lt;stats&gt;&lt;a href=&quot;#&quot;&gt;마법 관통력&lt;/a&gt; +18&lt;/stats&gt;&lt;br&gt;&lt;br&gt;&lt;unique&gt;고유 지속 효과 - 이동 속도 향상:&lt;/unique&gt; 이동 속도 +45&lt;/span&gt;&lt;br&gt;&lt;span&gt;가격:&lt;/span&gt; &lt;span style='color: #ffc659'&gt;1100 (800)&lt;/span&gt;"/>
#  </div>
#  <div class="Item">
#  <img alt="모렐로노미콘" class="Image tip" src="//opgg-static.akamaized.net/images/lol/item/3165.png?image=w_22&amp;v=15367644000" title="&lt;b style='color: #00cfbc'&gt;모렐로노미콘&lt;/b&gt;&lt;br&gt;&lt;span&gt;마법 피해량이 증가합니다.&lt;/span&gt;&lt;br&gt;&lt;span&gt;&lt;stats&gt;주문력 +70&lt;br&gt;체력 +300&lt;/stats&gt;&lt;br&gt;&lt;br&gt;&lt;unique&gt;고유 지속 효과- 죽음의 감촉:&lt;/unique&gt; &lt;a href=&quot;#&quot;&gt;마법 관통력&lt;/a&gt; +15&lt;br&gt;&lt;unique&gt;고유 지속 효과- 저주받은 일격:&lt;/unique&gt; 챔피언에게 마법 피해를 가하면 3초 동안 &lt;a href=&quot;#&quot;&gt;고통스러운 상처&lt;/a&gt; 효과를 적용합니다.&lt;/span&gt;&lt;br&gt;&lt;span&gt;가격:&lt;/span&gt; &lt;span style='color: #ffc659'&gt;3000 (550)&lt;/span&gt;"/>
#  </div>
#  <button class="Button OpenBuildButton tip" title="빌드" type="button">
#  <img class="On" src="//opgg-static.akamaized.net/css3/sprite/images/icon-buildblue-p.png"/>
#  <img class="Off" src="//opgg-static.akamaized.net/css3/sprite/images/icon-buildblue-p.png"/>
#  </button>
#  </div>
#  <div class="Trinket">
#  <img src="//opgg-static.akamaized.net/images/site/summoner/icon-ward-blue.png"/>
#  												제어 와드 <span class="wards vision">4</span></div>
#  </div>
#  <div class="FollowPlayers Names">
#  <div class="Team">
#  <div class="Summoner ">
#  <div class="ChampionImage">
#  <div class="Image16 __sprite __spc16 __spc16-84 tip" title="오른">오른</div>
#  <div class="Image20 __sprite __spc20 __spc20-84 tip" title="오른">오른</div>
#  </div>
#  <div class="SummonerName">
#  <a class="Link" href="//www.op.gg/summoner/userName=zirung" target="_blank">zirung</a>
#  </div>
#  </div>
#  <div class="Summoner ">
#  <div class="ChampionImage">
#  <div class="Image16 __sprite __spc16 __spc16-72 tip" title="오공">오공</div>
#  <div class="Image20 __sprite __spc20 __spc20-72 tip" title="오공">오공</div>
#  </div>
#  <div class="SummonerName">
#  <a class="Link" href="//www.op.gg/summoner/userName=%EA%B9%80%EC%BF%A0%EC%A7%80" target="_blank">김쿠지</a>
#  </div>
#  </div>
#  <div class="Summoner ">
#  <div class="ChampionImage">
#  <div class="Image16 __sprite __spc16 __spc16-23 tip" title="에코">에코</div>
#  <div class="Image20 __sprite __spc20 __spc20-23 tip" title="에코">에코</div>
#  </div>
#  <div class="SummonerName">
#  <a class="Link" href="//www.op.gg/summoner/userName=%EB%AA%A8%ED%95%B4%EB%A5%BC%EC%82%B4" target="_blank">모해를살</a>
#  </div>
#  </div>
#  <div class="Summoner ">
#  <div class="ChampionImage">
#  <div class="Image16 __sprite __spc16 __spc16-88 tip" title="퀸">퀸</div>
#  <div class="Image20 __sprite __spc20 __spc20-88 tip" title="퀸">퀸</div>
#  </div>
#  <div class="SummonerName">
#  <a class="Link" href="//www.op.gg/summoner/userName=%ED%9D%89%EB%B6%80%EC%99%B8%EA%B3%BC%EB%B4%89%EB%8B%AC%ED%9D%AC" target="_blank">흉부외과봉달희</a>
#  </div>
#  </div>
#  <div class="Summoner ">
#  <div class="ChampionImage">
#  <div class="Image16 __sprite __spc16 __spc16-12 tip" title="브랜드">브랜드</div>
#  <div class="Image20 __sprite __spc20 __spc20-12 tip" title="브랜드">브랜드</div>
#  </div>
#  <div class="SummonerName">
#  <a class="Link" href="//www.op.gg/summoner/userName=admireg" target="_blank">AdmireG</a>
#  </div>
#  </div>
#  </div>
#  <div class="Team">
#  <div class="Summoner ">
#  <div class="ChampionImage">
#  <div class="Image16 __sprite __spc16 __spc16-85 tip" title="판테온">판테온</div>
#  <div class="Image20 __sprite __spc20 __spc20-85 tip" title="판테온">판테온</div>
#  </div>
#  <div class="SummonerName">
#  <a class="Link" href="//www.op.gg/summoner/userName=%EC%B2%9C%EA%B5%AD%EC%9C%BC%EB%A1%9C%EA%B0%80%EB%8A%94%EC%97%B4%EC%B0%A8" target="_blank">천국으로가는열차</a>
#  </div>
#  </div>
#  <div class="Summoner ">
# ...
#  <div class="Image20 __sprite __spc20 __spc20-92 tip" title="레넥톤">레넥톤</div>
#  </div>
#  <div class="SummonerName">
#  <a class="Link" href="//www.op.gg/summoner/userName=theemperror" target="_blank">The Emperror</a>
#  </div>
#  </div>
#  <div class="Summoner ">
#  <div class="ChampionImage">
#  <div class="Image16 __sprite __spc16 __spc16-97 tip" title="세주아니">세주아니</div>
#  <div class="Image20 __sprite __spc20 __spc20-97 tip" title="세주아니">세주아니</div>
#  </div>
#  <div class="SummonerName">
#  <a class="Link" href="//www.op.gg/summoner/userName=%EC%8B%A0%EC%84%B1%EB%AB%99%EA%B0%80%EB%A0%8C" target="_blank">신 성 뫙 가 렌</a>
#  </div>
#  </div>
#  <div class="Summoner ">
#  <div class="ChampionImage">
#  <div class="Image16 __sprite __spc16 __spc16-63 tip" title="리산드라">리산드라</div>
#  <div class="Image20 __sprite __spc20 __spc20-63 tip" title="리산드라">리산드라</div>
#  </div>
#  <div class="SummonerName">
#  <a class="Link" href="//www.op.gg/summoner/userName=%EC%8B%A4%EB%B2%84%ED%95%99%EC%82%B4%EC%9E%90" target="_blank">실버학살자</a>
#  </div>
#  </div>
#  <div class="Summoner ">
#  <div class="ChampionImage">
#  <div class="Image16 __sprite __spc16 __spc16-47 tip" title="카이사">카이사</div>
#  <div class="Image20 __sprite __spc20 __spc20-47 tip" title="카이사">카이사</div>
#  </div>
#  <div class="SummonerName">
#  <a class="Link" href="//www.op.gg/summoner/userName=%EB%B9%84%EB%B2%BC%EC%A3%BD%EC%97%AC" target="_blank">비벼죽여</a>
#  </div>
#  </div>
#  <div class="Summoner ">
#  <div class="ChampionImage">
#  <div class="Image16 __sprite __spc16 __spc16-27 tip" title="피들스틱">피들스틱</div>
#  <div class="Image20 __sprite __spc20 __spc20-27 tip" title="피들스틱">피들스틱</div>
#  </div>
#  <div class="SummonerName">
#  <a class="Link" href="//www.op.gg/summoner/userName=%EB%87%8C%EC%97%90%ED%9E%98%EC%A3%BC%EB%9D%BC" target="_blank">뇌에힘주라</a>
#  </div>
#  </div>
#  </div>
#  <div class="Team">
#  <div class="Summoner ">
#  <div class="ChampionImage">
#  <div class="Image16 __sprite __spc16 __spc16-17 tip" title="초가스">초가스</div>
#  <div class="Image20 __sprite __spc20 __spc20-17 tip" title="초가스">초가스</div>
#  </div>
#  <div class="SummonerName">
#  <a class="Link" href="//www.op.gg/summoner/userName=%EC%A7%B1%EC%A7%B1%EC%A0%95%ED%99%98123" target="_blank">짱짱정환123</a>
#  </div>
#  </div>
#  <div class="Summoner Requester">
#  <div class="ChampionImage">
#  <div class="Image16 __sprite __spc16 __spc16-134 tip" title="신 짜오">신 짜오</div>
#  <div class="Image20 __sprite __spc20 __spc20-134 tip" title="신 짜오">신 짜오</div>
#  </div>
#  <div class="SummonerName">
#  <a class="Link" href="//www.op.gg/summoner/userName=%ED%99%A9%ED%86%A0%EB%A7%A4%ED%8A%B8" target="_blank">황토매트</a>
#  </div>
#  </div>
#  <div class="Summoner ">
#  <div class="ChampionImage">
#  <div class="Image16 __sprite __spc16 __spc16-29 tip" title="피즈">피즈</div>
#  <div class="Image20 __sprite __spc20 __spc20-29 tip" title="피즈">피즈</div>
#  </div>
#  <div class="SummonerName">
#  <a class="Link" href="//www.op.gg/summoner/userName=%EC%A4%80%EB%A7%8C%EC%9D%98%EC%82%AC%EB%9E%91" target="_blank">준만의사랑</a>
#  </div>
#  </div>
#  <div class="Summoner ">
#  <div class="ChampionImage">
#  <div class="Image16 __sprite __spc16 __spc16-116 tip" title="트리스타나">트리스타나</div>
#  <div class="Image20 __sprite __spc20 __spc20-116 tip" title="트리스타나">트리스타나</div>
#  </div>
#  <div class="SummonerName">
#  <a class="Link" href="//www.op.gg/summoner/userName=%EC%88%98%EB%A6%AC%EC%82%B0%ED%8F%AD%EA%B2%A9%EA%B8%B0" target="_blank">수리산폭격기</a>
#  </div>
#  </div>
#  <div class="Summoner ">
#  <div class="ChampionImage">
#  <div class="Image16 __sprite __spc16 __spc16-77 tip" title="노틸러스">노틸러스</div>
#  <div class="Image20 __sprite __spc20 __spc20-77 tip" title="노틸러스">노틸러스</div>
#  </div>
#  <div class="SummonerName">
#  <a class="Link" href="//www.op.gg/summoner/userName=%EC%A3%BC%EB%A8%B9%EA%B0%90%EC%9E%90%EC%95%84" target="_blank">주먹감자아</a>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="StatsButton">
#  <div class="Content">
#  <div class="Item">
#  <a class="Button MatchDetail" href="javascript:;">
#  <span class="__spSite __spSite-198 Off"></span>
#  <span class="__spSite __spSite-197 On"></span>
#  </a>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="GameDetail"></div>
#  </div>
#  </div>, <div class="GameItemWrap">
#  <div class="GameItem Lose " data-game-id="3522826090" data-game-result="lose" data-game-time="1549037905" data-summoner-id="1221663">
#  <div class="Content">
#  <div class="GameStats">
#  <div class="GameType">
#  					솔랭
#  				</div>
#  <div class="TimeStamp"><span class="_timeago _timeCountAssigned tip" data-datetime="1549037905" data-interval="60" data-type="" title="2019년 2월 2일 오전 1시 18분">3일 전</span></div>
#  <div class="Bar"></div>
#  <div class="GameResult">
#  											패배									</div>
#  <div class="GameLength">32분 38초</div>
#  </div>
#  <div class="GameSettingInfo">
#  <div class="ChampionImage">
#  <a href="/champion/xinzhao/statistics" target="_blank"><img alt="신 짜오" class="Image" src="//opgg-static.akamaized.net/images/lol/champion/XinZhao.png?image=w_46&amp;v=15354684000"/></a>
#  </div>
#  <div class="SummonerSpell">
#  <div class="Spell">
#  <img alt="강타" class="Image tip" src="//opgg-static.akamaized.net/images/lol/spell/SummonerSmite.png?image=w_22&amp;v=15354684000" title="&lt;b style='color: #ffc659'&gt;강타&lt;/b&gt;&lt;br&gt;&lt;span&gt;대상 에픽 및 대형/중형 몬스터, 혹은 적 미니언에게 390-1000(챔피언 레벨에 따라 변동)의 고정 피해를 입힙니다. 몬스터에게 사용하면 자신의 최대 체력에 비례해 체력을 회복합니다.&lt;/span&gt;"/>
#  </div>
#  <div class="Spell">
#  <img alt="점멸" class="Image tip" src="//opgg-static.akamaized.net/images/lol/spell/SummonerFlash.png?image=w_22&amp;v=15354684000" title="&lt;b style='color: #ffc659'&gt;점멸&lt;/b&gt;&lt;br&gt;&lt;span&gt;커서 방향으로 챔피언이 짧은 거리를 순간이동합니다.&lt;/span&gt;"/>
#  </div>
#  </div>
#  <div class="Runes">
#  <div class="Rune">
#  <img alt="칼날비" class="Image tip" src="//opgg-static.akamaized.net/images/lol/perk/9923.png?image=w_22&amp;v=1" title="&lt;b style='color: #ffc659'&gt;칼날비&lt;/b&gt;&lt;br&gt;&lt;span&gt;적 챔피언에 대한 3번째 공격까지 공격 속도가 110% 증가합니다.&lt;br&gt;&lt;br&gt;2초 안에 다음 공격을 가하지 못하면 효과가 사라집니다.&lt;br&gt;&lt;br&gt;재사용 대기시간: 전투에서 벗어나 있을 때 4초&lt;br&gt;&lt;br&gt;&lt;rules&gt;기본 공격 모션이 취소될 경우 공격 속도 증가 효과가 적용되는 공격 횟수가 1회 늘어납니다.&lt;br&gt;일시적으로 최고 공격 속도 제한을 초과할 수 있습니다.&lt;/rules&gt;&lt;/span&gt;"/>
#  </div>
#  <div class="Rune">
#  <img alt="정밀" class="Image tip" src="//opgg-static.akamaized.net/images/lol/perkStyle/8000.png?image=w_22&amp;v=2" title="&lt;b style='color: #ffc659'&gt;정밀&lt;/b&gt;&lt;br&gt;&lt;span&gt;공격 강화 및 지속적 피해&lt;/span&gt;"/>
#  </div>
#  </div>
#  <div class="ChampionName">
#  <a href="/champion/xinzhao/statistics" target="_blank">신 짜오</a>
#  </div>
#  </div>
#  <div class="KDA">
#  <div class="KDA">
#  <span class="Kill">1</span> /
#  					<span class="Death">5</span> /
#  					<span class="Assist">7</span>
#  </div>
#  <div class="KDARatio">
#  <span class="KDARatio ">1.60:1</span> 평점				</div>
#  </div>
#  <div class="Stats">
#  <div class="Level">
#  					레벨14
#  				</div>
#  <div class="CS">
#  <span class="CS tip" title="미니언 36  + 몬스터 99&lt;br&gt;분당CS 4.1개">135 (4.1)</span> CS
#  				</div>
#  <div class="CKRate tip" title="킬관여율">
#  						킬관여 40%
#  					</div>
#  <div class="MMR">매치 평균 <b>Bronze 4</b></div>
#  </div>
#  <div class="Items">
#  <div class="ItemList">
#  <div class="Item">
#  <img alt="마법 부여: 용사" class="Image tip" src="//opgg-static.akamaized.net/images/lol/item/1412.png?image=w_22&amp;v=15367644000" title="&lt;b style='color: #00cfbc'&gt;마법 부여: 용사&lt;/b&gt;&lt;br&gt;&lt;span&gt;공격력이 증가하고 재사용 대기시간이 감소합니다.&lt;/span&gt;&lt;br&gt;&lt;span&gt;&lt;stats&gt;공격력 +60&lt;br&gt;재사용 대기시간 감소 +10%&lt;/stats&gt;&lt;br&gt;&lt;br&gt;&lt;groupLimit&gt;골드 획득 아이템이나 정글 아이템은 1개로 소지가 제한됩니다.&lt;/groupLimit&gt;&lt;/span&gt;&lt;br&gt;&lt;span&gt;가격:&lt;/span&gt; &lt;span style='color: #ffc659'&gt;2625 (525)&lt;/span&gt;"/>
#  </div>
#  <div class="Item">
#  <img alt="충전형 물약" class="Image tip" src="//opgg-static.akamaized.net/images/lol/item/2031.png?image=w_22&amp;v=15367644000" title="&lt;b style='color: #00cfbc'&gt;충전형 물약&lt;/b&gt;&lt;br&gt;&lt;span&gt;일정 시간 동안 체력이 회복되며, 상점에 가면 다시 충전됩니다.&lt;/span&gt;&lt;br&gt;&lt;span&gt;&lt;groupLimit&gt;한 번에 한 종류의 회복 물약만 소지할 수 있습니다.&lt;/groupLimit&gt;&lt;br&gt;&lt;br&gt;&lt;active&gt;고유 사용 효과:&lt;/active&gt; 충전량을 1회 소모해 12초 동안 125의 체력을 회복합니다. 상점 방문 시 2회의 충전량이 다시 채워집니다.&lt;/span&gt;&lt;br&gt;&lt;span&gt;가격:&lt;/span&gt; &lt;span style='color: #ffc659'&gt;150 (150)&lt;/span&gt;"/>
#  </div>
#  <div class="Item">
#  <img alt="헤르메스의 발걸음" class="Image tip" src="//opgg-static.akamaized.net/images/lol/item/3111.png?image=w_22&amp;v=15367644000" title="&lt;b style='color: #00cfbc'&gt;헤르메스의 발걸음&lt;/b&gt;&lt;br&gt;&lt;span&gt;이동 속도가 증가하고, 방해 효과의 지속 시간이 줄어듭니다.&lt;/span&gt;&lt;br&gt;&lt;span&gt;&lt;groupLimit&gt;1개만 구입 가능합니다.&lt;/groupLimit&gt;&lt;br&gt;&lt;br&gt;&lt;stats&gt;마법 저항력 +25&lt;/stats&gt;&lt;br&gt;&lt;br&gt;&lt;unique&gt;고유 지속 효과 - 이동 속도 향상:&lt;/unique&gt; 이동 속도 +45&lt;br&gt;&lt;unique&gt;고유 지속 효과 - 강인함:&lt;/unique&gt; 기절, 둔화, 도발, 공포, 침묵, 실명, 변이 및 이동 불가 효과의 지속 시간이 30% 감소합니다.&lt;/span&gt;&lt;br&gt;&lt;span&gt;가격:&lt;/span&gt; &lt;span style='color: #ffc659'&gt;1100 (350)&lt;/span&gt;"/>
#  </div>
#  <div class="Item">
#  <img alt="와드 토템 (장신구)" class="Image tip" src="//opgg-static.akamaized.net/images/lol/item/3340.png?image=w_22&amp;v=15367644000" title="&lt;b style='color: #00cfbc'&gt;와드 토템 (장신구)&lt;/b&gt;&lt;br&gt;&lt;span&gt;주기적으로 투명 와드를 설치합니다.&lt;/span&gt;&lt;br&gt;&lt;span&gt;&lt;groupLimit&gt;장신구 소지 개수는 1개로 제한됩니다.&lt;/groupLimit&gt;&lt;br&gt;&lt;br&gt;&lt;active&gt;사용 시:&lt;/active&gt; 충전량을 1회 소모하여 &lt;scaleLevel&gt;90 ~ 120&lt;/scaleLevel&gt;초 동안 주변을 드러내 주는 보이지 않는 &lt;font color='#BBFFFF'&gt;투명 와드&lt;/font&gt;를 설치합니다. &lt;br&gt;&lt;br&gt;매 &lt;scaleLevel&gt;240 ~ 120&lt;/scaleLevel&gt;초마다 1회 충전되며 최대 2회까지 충전됩니다.&lt;br&gt;&lt;br&gt;와드 지속 시간과 충전 주기는 레벨이 오를수록 향상됩니다.&lt;br&gt;&lt;br&gt;&lt;rules&gt;(플레이어당 맵에 설치할 수 있는 &lt;font color='#BBFFFF'&gt;투명 와드&lt;/font&gt;는 3개로 제한됩니다.)&lt;/rules&gt;&lt;/span&gt;"/>
#  </div>
#  <div class="Item">
#  <img alt="삼위일체" class="Image tip" src="//opgg-static.akamaized.net/images/lol/item/3078.png?image=w_22&amp;v=15367644000" title="&lt;b style='color: #00cfbc'&gt;삼위일체&lt;/b&gt;&lt;br&gt;&lt;span&gt;취급주의: 이 아이템만 갖추면 '엄청난 피해'를 줄 수 있죠...&lt;/span&gt;&lt;br&gt;&lt;span&gt;&lt;stats&gt;체력 +250&lt;br&gt;&lt;mana&gt;마나 +250&lt;/mana&gt;&lt;br&gt;공격력 +25&lt;br&gt;공격 속도 +40%&lt;br&gt;재사용 대기시간 감소 +20%&lt;br&gt;이동 속도 +5%&lt;/stats&gt;&lt;br&gt;&lt;br&gt;&lt;unique&gt;고유 지속 효과 - 격분:&lt;/unique&gt; 기본 공격 시 2초간 이동 속도가 20 상승합니다. 적을 처치하면 이동 속도가 60 상승합니다. 원거리 챔피언의 경우 이동 속도 상승 효과는 절반만 적용됩니다.&lt;br&gt;&lt;unique&gt;고유 지속 효과 - 주문 검:&lt;/unique&gt; 스킬을 사용하고 나면 다음 기본 공격 적중 시 기본 공격력의 200%에 해당하는 추가 물리 피해를 입힙니다. (재사용 대기시간 1.5초)&lt;/span&gt;&lt;br&gt;&lt;span&gt;가격:&lt;/span&gt; &lt;span style='color: #ffc659'&gt;3733 (333)&lt;/span&gt;"/>
#  </div>
#  <div class="Item">
#  <img alt="요림의 주먹" class="Image tip" src="//opgg-static.akamaized.net/images/lol/item/3052.png?image=w_22&amp;v=15367644000" title="&lt;b style='color: #00cfbc'&gt;요림의 주먹&lt;/b&gt;&lt;br&gt;&lt;span&gt;공격력을 올려주며 유닛 처치 시 체력이 중첩됩니다.&lt;/span&gt;&lt;br&gt;&lt;span&gt;&lt;stats&gt;공격력 +15&lt;br&gt;체력 +200&lt;/stats&gt;&lt;br&gt;&lt;br&gt;&lt;unique&gt;고유 지속 효과:&lt;/unique&gt; 유닛을 처치하면 최대 체력이 5 오릅니다. 이 효과는 최대 20번까지 중첩됩니다.&lt;/span&gt;&lt;br&gt;&lt;span&gt;가격:&lt;/span&gt; &lt;span style='color: #ffc659'&gt;1200 (450)&lt;/span&gt;"/>
#  </div>
#  <div class="Item">
#  <img alt="루비 수정" class="Image tip" src="//opgg-static.akamaized.net/images/lol/item/1028.png?image=w_22&amp;v=15367644000" title="&lt;b style='color: #00cfbc'&gt;루비 수정&lt;/b&gt;&lt;br&gt;&lt;span&gt;체력이 증가합니다.&lt;/span&gt;&lt;br&gt;&lt;span&gt;&lt;stats&gt;체력 +150&lt;/stats&gt;&lt;/span&gt;&lt;br&gt;&lt;span&gt;가격:&lt;/span&gt; &lt;span style='color: #ffc659'&gt;400 (400)&lt;/span&gt;"/>
#  </div>
#  <button class="Button OpenBuildButton tip" title="빌드" type="button">
#  <img class="On" src="//opgg-static.akamaized.net/css3/sprite/images/icon-buildred-p.png"/>
#  <img class="Off" src="//opgg-static.akamaized.net/css3/sprite/images/icon-buildred-p.png"/>
#  </button>
#  </div>
#  </div>
#  <div class="FollowPlayers Names">
#  <div class="Team">
#  <div class="Summoner ">
#  <div class="ChampionImage">
#  <div class="Image16 __sprite __spc16 __spc16-137 tip" title="자크">자크</div>
#  <div class="Image20 __sprite __spc20 __spc20-137 tip" title="자크">자크</div>
#  </div>
#  <div class="SummonerName">
#  <a class="Link" href="//www.op.gg/summoner/userName=%EC%A7%B1%EC%A7%B1%EC%A0%95%ED%99%98123" target="_blank">짱짱정환123</a>
#  </div>
#  </div>
#  <div class="Summoner Requester">
#  <div class="ChampionImage">
#  <div class="Image16 __sprite __spc16 __spc16-134 tip" title="신 짜오">신 짜오</div>
#  <div class="Image20 __sprite __spc20 __spc20-134 tip" title="신 짜오">신 짜오</div>
#  </div>
#  <div class="SummonerName">
#  <a class="Link" href="//www.op.gg/summoner/userName=%ED%99%A9%ED%86%A0%EB%A7%A4%ED%8A%B8" target="_blank">황토매트</a>
#  </div>
#  </div>
#  <div class="Summoner ">
#  <div class="ChampionImage">
#  <div class="Image16 __sprite __spc16 __spc16-2 tip" title="아칼리">아칼리</div>
#  <div class="Image20 __sprite __spc20 __spc20-2 tip" title="아칼리">아칼리</div>
#  </div>
#  <div class="SummonerName">
#  <a class="Link" href="//www.op.gg/summoner/userName=%EC%8B%A4%EB%B2%84%ED%95%99%EC%82%B4%EC%9E%90" target="_blank">실버학살자</a>
#  </div>
#  </div>
#  <div class="Summoner ">
#  <div class="ChampionImage">
#  <div class="Image16 __sprite __spc16 __spc16-71 tip" title="미스 포츈">미스 포츈</div>
#  <div class="Image20 __sprite __spc20 __spc20-71 tip" title="미스 포츈">미스 포츈</div>
#  </div>
#  <div class="SummonerName">
#  <a class="Link" href="//www.op.gg/summoner/userName=%EB%B9%84%EB%B2%BC%EC%A3%BD%EC%97%AC" target="_blank">비벼죽여</a>
#  </div>
#  </div>
#  <div class="Summoner ">
#  <div class="ChampionImage">
#  <div class="Image16 __sprite __spc16 __spc16-74 tip" title="모르가나">모르가나</div>
#  <div class="Image20 __sprite __spc20 __spc20-74 tip" title="모르가나">모르가나</div>
#  </div>
#  <div class="SummonerName">
#  <a class="Link" href="//www.op.gg/summoner/userName=xornjs32" target="_blank">xornjs32</a>
#  </div>
#  </div>
#  </div>
#  <div class="Team">
#  <div class="Summoner ">
#  <div class="ChampionImage">
#  <div class="Image16 __sprite __spc16 __spc16-73 tip" title="모데카이저">모데카이저</div>
#  <div class="Image20 __sprite __spc20 __spc20-73 tip" title="모데카이저">모데카이저</div>
#  </div>
#  <div class="SummonerName">
#  <a class="Link" href="//www.op.gg/summoner/userName=%EB%8F%84%EC%8B%9C%EC%9D%98%EC%82%90%EC%97%90%EB%A1%9C" target="_blank">도시의삐에로</a>
#  </div>
#  </div>
#  <div class="Summoner ">
#  <div class="ChampionImage">
#  <div class="Image16 __sprite __spc16 __spc16-80 tip" title="녹턴">녹턴</div>
#  <div class="Image20 __sprite __spc20 __spc20-80 tip" title="녹턴">녹턴</div>
#  </div>
#  <div class="SummonerName">
#  <a class="Link" href="//www.op.gg/summoner/userName=cocoachoco" target="_blank">cocoachoco</a>
#  </div>
#  </div>
#  <div class="Summoner ">
#  <div class="ChampionImage">
#  <div class="Image16 __sprite __spc16 __spc16-68 tip" title="말자하">말자하</div>
#  <div class="Image20 __sprite __spc20 __spc20-68 tip" title="말자하">말자하</div>
#  </div>
#  <div class="SummonerName">
#  <a class="Link" href="//www.op.gg/summoner/userName=%EA%B0%80%EC%86%8C%EB%A1%AD%EB%8B%A4%EB%8B%9D%EA%B2%90" target="_blank">가소롭다닝겐</a>
#  </div>
#  </div>
#  <div class="Summoner ">
#  <div class="ChampionImage">
#  <div class="Image16 __sprite __spc16 __spc16-45 tip" title="진">진</div>
#  <div class="Image20 __sprite __spc20 __spc20-45 tip" title="진">진</div>
#  </div>
#  <div class="SummonerName">
#  <a class="Link" href="//www.op.gg/summoner/userName=%EC%BF%A0%ED%82%A4%EB%B0%8D" target="_blank">쿠키밍</a>
#  </div>
#  </div>
#  <div class="Summoner ">
#  <div class="ChampionImage">
#  <div class="Image16 __sprite __spc16 __spc16-106 tip" title="소라카">소라카</div>
#  <div class="Image20 __sprite __spc20 __spc20-106 tip" title="소라카">소라카</div>
#  </div>
#  <div class="SummonerName">
#  <a class="Link" href="//www.op.gg/summoner/userName=%EC%96%91%EC%84%A0%ED%99%8D" target="_blank">양선홍</a>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="StatsButton">
#  <div class="Content">
#  <div class="Item">
#  <a class="Button MatchDetail" href="javascript:;">
#  <span class="__spSite __spSite-198 Off"></span>
#  <span class="__spSite __spSite-197 On"></span>
#  </a>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="GameDetail"></div>
#  </div>
#  </div>]

# %%
Champ = [] ; GameType = [] ; CS = [] ; KDARatio_ = [] ; tmp = [] ; K = [] ; D = [] ; A = [] 
CKRate_ = [] ; GameResult = [] 
span = ['Kill','Death','Assist','KDARatio','CS','Wards']
dict_tmp = {'ChampionName':Champ,'GameType':GameType,'CS':CS,'KDARatio':KDARatio_,'Kill':K,'Death':D,'Assist':A, 
            'CKRate' : CKRate_,'GameResult':GameResult}

for x,y in dict_tmp.items():
    if x in span:
        tmp = soup.find('div','RealContent').find_all('span',x)
    else:
        tmp = soup.find('div','RealContent').find_all('div',x)
    for i in tmp:
        tmp = re.split(('\n|\t'),i.get_text())
        tmp = [n for n in tmp if n][0]
        y.append(tmp)
tmp = []
for i in K:
    if i < '9999999':
        tmp.append(i)
K = tmp        
KDARatio_ = KDARatio_[1:]
K = K[1:]
D = D[1:]
A = A[1:]

# %%
Recent_Games = {'ChampionName':Champ,'GameType':GameType,'CS':CS,'KDARatio':KDARatio_,'K':K,
                          'D':D,'A':A, 'CKRate' : CKRate_,'GameResult':GameResult}
Recent_Games = pd.DataFrame(Recent_Games)
Recent_Games.set_index('ChampionName',inplace=True)
print('최근 100경기')
Recent_Games
# Out:
# 최근 100경기
#                GameType         CS KDARatio   K   D   A   CKRate GameResult
# ChampionName
# 카시오페아                솔랭  186 (6.3)   3.80:1   7   5  12  킬관여 54%         승리
# 카시오페아                솔랭  171 (8.5)  Perfect   6   0   4  킬관여 56%         승리
# 라이즈                  솔랭  288 (8.2)   4.67:1  13   3   1  킬관여 67%         패배
# 라이즈                  솔랭  236 (6.6)   6.00:1  22   6  14  킬관여 73%         승리
# 카시오페아                솔랭  132 (6.5)   1.60:1   6   5   2  킬관여 67%         패배
# 카시오페아                솔랭  219 (7.6)   2.17:1  11   6   2  킬관여 76%         패배
# 카시오페아                솔랭  206 (6.9)   2.43:1  10   7   7  킬관여 71%         패배
# 아리                   솔랭  132 (3.7)   3.14:1   9   7  13  킬관여 54%         승리
# 아리                   솔랭  168 (4.5)   2.17:1   3   6  10  킬관여 72%         패배
# 아리                   솔랭  198 (4.6)   2.10:1   8  10  13  킬관여 66%         패배
# 아리                   솔랭    5 (1.5)   0.00:1   0   0   0   킬관여 0%       다시하기
# 아리                   솔랭  103 (3.5)   1.33:1   5   9   7  킬관여 63%         패배
# 아리                   솔랭   76 (3.8)   6.50:1   5   2   8  킬관여 52%         승리
# 아리                   솔랭  170 (4.7)   3.75:1  14   8  16  킬관여 57%         승리
# 아리                   솔랭  163 (4.9)   2.50:1   6   6   9  킬관여 56%         패배
# 아리                   솔랭  181 (4.8)   2.83:1  10   6   7  킬관여 49%         승리
# 레오나                  솔랭   38 (1.8)   8.00:1   4   2  12  킬관여 53%         승리
# 아리                   솔랭  146 (6.4)  Perfect   3   0   1  킬관여 80%         패배
# 신 짜오                 솔랭  109 (4.4)   0.75:1   4   8   2  킬관여 60%         패배
# 신 짜오                 솔랭  135 (4.1)   1.60:1   1   5   7  킬관여 40%         패배
# 아리                   솔랭   97 (4.7)  11.50:1   7   2  16  킬관여 61%         승리
# 아리                   솔랭  110 (5.5)   1.25:1   2   4   3  킬관여 24%         승리
# 아리                   솔랭   91 (4.7)   5.00:1   3   2   7  킬관여 50%         승리
# 아리                   솔랭   13 (3.7)   0.00:1   0   0   0   킬관여 0%       다시하기
# 브라움                  솔랭     53 (2)   1.71:1   2   7  10  킬관여 43%         패배
# 브라움                  솔랭     82 (2)   2.08:1   2  12  23  킬관여 63%         승리
# 레오나                  솔랭   43 (2.1)  10.00:1   3   1   7  킬관여 53%         승리
# 아리                   솔랭   96 (4.6)   2.00:1   6   4   2  킬관여 67%         패배
# 아리                   솔랭  226 (5.2)   5.67:1  16   6  18  킬관여 74%         승리
# 아리                   솔랭  159 (5.1)  13.50:1  11   2  16  킬관여 79%         승리
# ...                 ...        ...      ...  ..  ..  ..      ...        ...
# 오른                   솔랭   91 (4.5)   0.20:1   0   5   1  킬관여 11%         패배
# 시비르                  솔랭    193 (6)   4.75:1   3   4  16  킬관여 51%         승리
# 시비르                  솔랭  138 (6.1)   3.67:1   5   3   6  킬관여 41%         승리
# 시비르                  솔랭  182 (7.5)   7.00:1  11   3  10  킬관여 68%         승리
# 시비르                  솔랭    214 (7)   2.67:1  10   6   6  킬관여 67%         패배
# 시비르                  솔랭    141 (5)   4.25:1   4   4  13  킬관여 45%         승리
# 오른                   솔랭  126 (4.3)   1.00:1   1   6   5  킬관여 23%         패배
# 오른                   솔랭  131 (6.5)   6.00:1   3   1   3  킬관여 33%         승리
# 오른                   솔랭  100 (3.7)   2.50:1   3   4   7  킬관여 33%         승리
# 오른                   솔랭   94 (4.3)   2.67:1   3   3   5  킬관여 67%         패배
# 오른                   솔랭  127 (3.4)   2.43:1   3   7  14  킬관여 44%         승리
# 오른                   솔랭  128 (3.9)   3.60:1   4   5  14  킬관여 58%         승리
# 오른                   솔랭  101 (3.7)   2.67:1   4   6  12  킬관여 48%         승리
# 오른                   솔랭  166 (4.9)   5.00:1   1   2   9  킬관여 27%         승리
# 오른                   솔랭  137 (4.7)   6.00:1   3   2   9  킬관여 40%         승리
# 소나                   일반    5 (0.2)   0.50:1   0   2   1  킬관여 17%         패배
# 소라카                  일반      0 (0)   0.00:1   0   4   0   킬관여 0%         패배
# 오른                   솔랭  158 (5.4)   7.33:1   6   3  16  킬관여 56%         승리
# 오른                   솔랭  140 (4.3)  Perfect   6   0  19  킬관여 64%         승리
# 오른                   솔랭  160 (4.8)   1.80:1   3   5   6  킬관여 28%         승리
# 트위치             무작위 총력전   64 (3.5)   4.40:1   8   5  14  킬관여 51%         승리
# 이즈리얼          자유 5:5 랭크    188 (8)   8.00:1   2   1   6  킬관여 35%         승리
# 노틸러스          자유 5:5 랭크  235 (6.5)  12.00:1   3   1   9  킬관여 32%         승리
# 제라스           자유 5:5 랭크  180 (8.3)  10.00:1   5   1   5  킬관여 48%         승리
# 이즈리얼          자유 5:5 랭크  263 (6.7)   2.43:1   6   7  11  킬관여 45%         패배
# 이즈리얼          자유 5:5 랭크  238 (8.2)   1.00:1   3   6   3  킬관여 29%         패배
# 베인                   일반    192 (5)   1.82:1  13  11   7  킬관여 41%         승리
# 베인                   일반  215 (7.1)   6.00:1  15   4   9  킬관여 57%         승리
# 리 신                  일반  191 (4.7)   1.70:1   8  10   9  킬관여 63%         패배
# 제드                   일반  132 (4.4)   1.30:1   6  10   7  킬관여 57%         패배
#
# [100 rows x 8 columns]

# %%
# 분석하기 쉽게 전처리
CS_min = []
n = 0
while n < len(list(Recent_Games.index)):
    sw = 0
    k = ''
    tmp = CS[n]
    for i in tmp:
        if i == '(':
            sw = 1
        if sw == 1:
            k += i
    CS_min.append(k.strip('(|)'))
    n += 1
KDARatio = []
for i in KDARatio_:
    tmp = re.split((':1'),i)
    KDARatio.append(tmp[0])
CKRate = []
for i in CKRate_:
    tmp = re.split(('%|킬관여 '),i)
    CKRate.append(tmp[1])

# %%
Recent_Games2 = {'ChampionName':Champ,'GameType':GameType,'CS_min':CS_min,'KDARatio':KDARatio,'K':K,
                          'D':D,'A':A, 'CKRate' : CKRate,'GameResult':GameResult}
Recent_Games2 = pd.DataFrame(Recent_Games2)
Recent_Games2.set_index('ChampionName',inplace=True)

Recent_Games2['CS_min'] =Recent_Games2['CS_min'].astype(float) 
Recent_Games2['CKRate'] =Recent_Games2['CKRate'].astype(float) 
Recent_Games2['K'] =Recent_Games2['K'].astype(float) 
Recent_Games2['D'] =Recent_Games2['D'].astype(float) 
Recent_Games2['A'] =Recent_Games2['A'].astype(float) 
#Recent_Games2 = Recent_Games2[Recent_Games2['GameResult'] != '다시하기']

Recent_Games2
# Out:
#                GameType  CS_min KDARatio     K     D     A  CKRate GameResult
# ChampionName
# 카시오페아                솔랭     6.3     3.80   7.0   5.0  12.0    54.0         승리
# 카시오페아                솔랭     8.5  Perfect   6.0   0.0   4.0    56.0         승리
# 라이즈                  솔랭     8.2     4.67  13.0   3.0   1.0    67.0         패배
# 라이즈                  솔랭     6.6     6.00  22.0   6.0  14.0    73.0         승리
# 카시오페아                솔랭     6.5     1.60   6.0   5.0   2.0    67.0         패배
# 카시오페아                솔랭     7.6     2.17  11.0   6.0   2.0    76.0         패배
# 카시오페아                솔랭     6.9     2.43  10.0   7.0   7.0    71.0         패배
# 아리                   솔랭     3.7     3.14   9.0   7.0  13.0    54.0         승리
# 아리                   솔랭     4.5     2.17   3.0   6.0  10.0    72.0         패배
# 아리                   솔랭     4.6     2.10   8.0  10.0  13.0    66.0         패배
# 아리                   솔랭     1.5     0.00   0.0   0.0   0.0     0.0       다시하기
# 아리                   솔랭     3.5     1.33   5.0   9.0   7.0    63.0         패배
# 아리                   솔랭     3.8     6.50   5.0   2.0   8.0    52.0         승리
# 아리                   솔랭     4.7     3.75  14.0   8.0  16.0    57.0         승리
# 아리                   솔랭     4.9     2.50   6.0   6.0   9.0    56.0         패배
# 아리                   솔랭     4.8     2.83  10.0   6.0   7.0    49.0         승리
# 레오나                  솔랭     1.8     8.00   4.0   2.0  12.0    53.0         승리
# 아리                   솔랭     6.4  Perfect   3.0   0.0   1.0    80.0         패배
# 신 짜오                 솔랭     4.4     0.75   4.0   8.0   2.0    60.0         패배
# 신 짜오                 솔랭     4.1     1.60   1.0   5.0   7.0    40.0         패배
# 아리                   솔랭     4.7    11.50   7.0   2.0  16.0    61.0         승리
# 아리                   솔랭     5.5     1.25   2.0   4.0   3.0    24.0         승리
# 아리                   솔랭     4.7     5.00   3.0   2.0   7.0    50.0         승리
# 아리                   솔랭     3.7     0.00   0.0   0.0   0.0     0.0       다시하기
# 브라움                  솔랭     2.0     1.71   2.0   7.0  10.0    43.0         패배
# 브라움                  솔랭     2.0     2.08   2.0  12.0  23.0    63.0         승리
# 레오나                  솔랭     2.1    10.00   3.0   1.0   7.0    53.0         승리
# 아리                   솔랭     4.6     2.00   6.0   4.0   2.0    67.0         패배
# 아리                   솔랭     5.2     5.67  16.0   6.0  18.0    74.0         승리
# 아리                   솔랭     5.1    13.50  11.0   2.0  16.0    79.0         승리
# ...                 ...     ...      ...   ...   ...   ...     ...        ...
# 오른                   솔랭     4.5     0.20   0.0   5.0   1.0    11.0         패배
# 시비르                  솔랭     6.0     4.75   3.0   4.0  16.0    51.0         승리
# 시비르                  솔랭     6.1     3.67   5.0   3.0   6.0    41.0         승리
# 시비르                  솔랭     7.5     7.00  11.0   3.0  10.0    68.0         승리
# 시비르                  솔랭     7.0     2.67  10.0   6.0   6.0    67.0         패배
# 시비르                  솔랭     5.0     4.25   4.0   4.0  13.0    45.0         승리
# 오른                   솔랭     4.3     1.00   1.0   6.0   5.0    23.0         패배
# 오른                   솔랭     6.5     6.00   3.0   1.0   3.0    33.0         승리
# 오른                   솔랭     3.7     2.50   3.0   4.0   7.0    33.0         승리
# 오른                   솔랭     4.3     2.67   3.0   3.0   5.0    67.0         패배
# 오른                   솔랭     3.4     2.43   3.0   7.0  14.0    44.0         승리
# 오른                   솔랭     3.9     3.60   4.0   5.0  14.0    58.0         승리
# 오른                   솔랭     3.7     2.67   4.0   6.0  12.0    48.0         승리
# 오른                   솔랭     4.9     5.00   1.0   2.0   9.0    27.0         승리
# 오른                   솔랭     4.7     6.00   3.0   2.0   9.0    40.0         승리
# 소나                   일반     0.2     0.50   0.0   2.0   1.0    17.0         패배
# 소라카                  일반     0.0     0.00   0.0   4.0   0.0     0.0         패배
# 오른                   솔랭     5.4     7.33   6.0   3.0  16.0    56.0         승리
# 오른                   솔랭     4.3  Perfect   6.0   0.0  19.0    64.0         승리
# 오른                   솔랭     4.8     1.80   3.0   5.0   6.0    28.0         승리
# 트위치             무작위 총력전     3.5     4.40   8.0   5.0  14.0    51.0         승리
# 이즈리얼          자유 5:5 랭크     8.0     8.00   2.0   1.0   6.0    35.0         승리
# 노틸러스          자유 5:5 랭크     6.5    12.00   3.0   1.0   9.0    32.0         승리
# 제라스           자유 5:5 랭크     8.3    10.00   5.0   1.0   5.0    48.0         승리
# 이즈리얼          자유 5:5 랭크     6.7     2.43   6.0   7.0  11.0    45.0         패배
# 이즈리얼          자유 5:5 랭크     8.2     1.00   3.0   6.0   3.0    29.0         패배
# 베인                   일반     5.0     1.82  13.0  11.0   7.0    41.0         승리
# 베인                   일반     7.1     6.00  15.0   4.0   9.0    57.0         승리
# 리 신                  일반     4.7     1.70   8.0  10.0   9.0    63.0         패배
# 제드                   일반     4.4     1.30   6.0  10.0   7.0    57.0         패배
#
# [100 rows x 8 columns]

# %% [markdown]
# 100경기 평균 기록

# %%
Total_vic = list(Recent_Games2['GameResult']).count('승리')
Total_def = list(Recent_Games2['GameResult']).count('패배')
Total_wr = Total_vic/(Total_vic+Total_def)*100

Total_wr = round(Total_wr,2)
Total_KDA = round((Recent_Games2['K'].sum()+Recent_Games2['A'].sum())/Recent_Games2['D'].sum(),2)
Total_cs = round(Recent_Games2['CS_min'].mean(),2)
Total_CKRate = round(Recent_Games2['CKRate'].mean(),2)
print("최근 100경기 승률은 {}%이고 평점은 {}점이다. 한 경기당 분당CS는 {}개이고 평균 킬관여율은 {}%이다."
      .format(Total_wr,Total_KDA,Total_cs,Total_CKRate))
# Out:
# 최근 100경기 승률은 52.08%이고 평점은 2.98점이다. 한 경기당 분당CS는 4.93개이고 평균 킬관여율은 49.86%이다.

# %% [markdown]
# 챔피언별 기록

# %%
grouped = Recent_Games2[['CS_min','K','D','A','CKRate']].groupby(level = 0) 
Recent_Games3 = grouped.mean()
Recent_Games3['KDA'] = (Recent_Games3['K']+Recent_Games3['A'])/Recent_Games3['D']
Recent_Games3 = Recent_Games3.applymap(lambda x : round(x,2)) 
Recent_Games3['PlayedGames'] = grouped.count()['CS_min']

# %%
# GameResult 와 index를 key로 만든후 카운트 한다.
grouped2 = Recent_Games2[['K']].groupby([Recent_Games2.index,Recent_Games2['GameResult']]) 
grouped3 = grouped2.count()

WinRatio = []
for tmp in Recent_Games3.index:
    try:
        grouped_vic = grouped3.loc[(tmp,'승리'), 'K'] 
    except:
        grouped_vic = 0
    try:
        grouped_def = grouped3.loc[(tmp,'패배'), 'K'] 
    except:
        grouped_def = 0
    grouped_wr = grouped_vic/(grouped_vic+grouped_def)*100
    grouped_wr = round(grouped_wr,2)
    WinRatio.append(grouped_wr)

# %%
Recent_Games3['WinRatio'] = WinRatio
Recent_Games3
# Out:
#               CS_min      K      D      A  CKRate    KDA  PlayedGames  \
# ChampionName
# 노틸러스            6.50   3.00   1.00   9.00   32.00  12.00            1
# 라이즈             7.40  17.50   4.50   7.50   70.00   5.56            2
# 레오나             2.08   2.20   2.40  11.80   52.60   5.83            5
# 리 신             4.70   8.00  10.00   9.00   63.00   1.70            1
# 베인              6.05  14.00   7.50   8.00   49.00   2.93            2
# 브라움             2.00   2.00   9.50  16.50   53.00   1.95            2
# 소나              0.20   0.00   2.00   1.00   17.00   0.50            1
# 소라카             0.00   0.00   4.00   0.00    0.00   0.00            1
# 시비르             6.65   6.00   4.12   9.38   53.75   3.73            8
# 신 짜오            4.03   3.00   7.67   6.67   49.00   1.26            3
# 아리              4.47   6.73   4.45   8.05   53.05   3.32           22
# 오른              4.58   3.64   3.95   9.14   43.27   3.23           22
# 이즈리얼            7.63   3.67   4.67   6.67   36.33   2.21            3
# 제드              4.40   6.00  10.00   7.00   57.00   1.30            1
# 제라스             8.30   5.00   1.00   5.00   48.00  10.00            1
# 징크스             5.29   4.93   4.07   6.57   54.71   2.82           14
# 카시오페아           7.16   8.00   4.60   5.40   64.80   2.91            5
# 트리스타나           5.32   4.40   5.40   5.00   43.20   1.74            5
# 트위치             3.50   8.00   5.00  14.00   51.00   4.40            1
#
#               WinRatio
# ChampionName
# 노틸러스            100.00
# 라이즈              50.00
# 레오나              80.00
# 리 신               0.00
# 베인              100.00
# 브라움              50.00
# 소나                0.00
# 소라카               0.00
# 시비르              62.50
# 신 짜오              0.00
# 아리               60.00
# 오른               59.09
# 이즈리얼             33.33
# 제드                0.00
# 제라스             100.00
# 징크스              33.33
# 카시오페아            40.00
# 트리스타나            40.00
# 트위치             100.00

# %%
plt.figure()
plt.subplot(311)
Recent_Games3['PlayedGames'].plot(kind='barh', grid=True, figsize=(15,20))
plt.ylabel('PlayedGames')
plt.subplot(323)
Recent_Games3['WinRatio'].plot(kind='barh', grid=True, figsize=(15,20))
plt.ylabel('WinRatio')
plt.subplot(324)
Recent_Games3['KDA'].plot(kind='barh', grid=True, figsize=(15,20))
plt.ylabel('KDA')
plt.subplot(325)
Recent_Games3['CKRate'].plot(kind='barh', grid=True, figsize=(15,20))
plt.ylabel('CKRate')
plt.subplot(326)
Recent_Games3['CS_min'].plot(kind='barh', grid=True, figsize=(15,20))
plt.ylabel('CS_min')
plt.show()

# %%
sns.pairplot(Recent_Games3[Recent_Games3['KDA'] != np.inf], vars=["CS_min", "CKRate", "KDA",'WinRatio'], kind='reg', size=5)
plt.show()
